# %% [raw]
# 처음에 셀레니움으로 브랜드 페이지 열고
# url 을 뷰티숩으로 하나씩 도출
# 각 url에 들어가서 (셀레니움으로 들어가서) 그 안에 내용들을 긁는다.
# 셀레니움으로 리뷰 버튼 클릭
# 뷰티풀숩으로 내용 긁기

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup as bsp
import matplotlib
import matplotlib.pyplot as plt
import sqlite3
import re
from datetime import datetime, timedelta,date
import sys
import time
import click
from selenium.webdriver.common.action_chains import ActionChains
import sqlite3

# %% [markdown]
# ### 향수 구찌 페이지 접속

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bsp
from selenium.webdriver.chrome.options import Options

CHROMEDRIVER_PATH = 'C:/asi/project/chromedriver_win32 (3)/chromedriver' # Windows는 chromedriver_78.exe
WINDOW_SIZE = "1920,1080"
chrome_options = Options()
chrome_options.add_argument(f"--window-size={ WINDOW_SIZE }")
chrome_options.add_argument('Content-Type=application/json; charset=utf-8')
driver = webdriver.Chrome( executable_path=CHROMEDRIVER_PATH, chrome_options=chrome_options )
url = ('https://perfumegraphy.com/product/list.html?cate_no=201')
driver.get(url)

#driver = webdriver.Chrome('C:/asi/project/chromedriver_win32 (3)/chromedriver')
#url = ('https://perfumegraphy.com/product/list.html?cate_no=201')
#driver.get(url)
driver.implicitly_wait(3)
html = driver.page_source
src = bsp(html,'html.parser')
# Out:
# <ipython-input-2-1a2aa6ae436e>:10: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome( executable_path=CHROMEDRIVER_PATH, chrome_options=chrome_options )

# %% [markdown]
# ### 향수 url 하나씩 추출

# %%
perurls = src.select('li.xans-record- > div')
for perurl in perurls :
    urls2 = perurl.select('div.prdImg > a')
    print(urls2)

# %%
perurls = src.select('li.xans-record- > div')
#print(perurls)
for perurl in perurls:
    urls2 = perurl.select('div.prdImg > a')[0]
    homepage = urls2['href']
    productid = homepage.split('/')
    print(productid[3])
    print('#'*100)

# %%
a = homepage.split('/')
a[3]

# %% [markdown]
# ### 각 homepage 내용 긁기

# %%
driver = webdriver.Chrome('C:/asi/project/chromedriver_win32 (3)/chromedriver')
##brand_name = 글자 찾기!!!!! 나중에 name_에 replace부분에 brand_name으로 넣기
for perurl in perurls:
    urls = perurl.select('div.prdImg > a')[0]
    homepage ='https://perfumegraphy.com'+ urls['href']+'#review'
    #print(homepage)
    driver.get(homepage)
    time.sleep(3)
    html = driver.page_source
    src = bsp(html,'html.parser')
    name_ = src.select('div.headingArea > h2')[0].text.replace('구찌','').replace('/','').strip()
    name = re.sub('[a-zA-Z0-9]','',name_)
    realname = re.sub('\+.*','',name).strip()
    time.sleep(3)
    print(src)
    print('#'*100)
    print('#'*100)
    print('#'*100)
#     ul_list = src.select('ul.reviews > li.review')
    
#     for ul in ul_list :
#         reviewa = ul.select('a.js-link-expand')
#         print(reviewa)
        #reviewa.click()
    
#     review =
#     age = 
#     gender = 
    
    #print(realname)
#     brand_name = mains.select('p.product-main-info__brand_name')[0].text.strip()

# %%
for perurl in perurls:
    urls = perurl.select('div.prdImg > a')[0]
    homepage ='https://perfumegraphy.com'+ urls['href']+'#review'
print(homepage)

# %%
driver = webdriver.Chrome('C:/asi/project/chromedriver_win32 (3)/chromedriver')
##brand_name = 글자 찾기!!!!! 나중에 name_에 replace부분에 brand_name으로 넣기
homepage ='http://review4.cre.ma/perfumegraphy.com/products/reviews?product_code=1469&iframe_id=crema-product-reviews-1&widget_id=32&widget_style=&app=0&parent_url=http%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2F&nonmember_token=&secure_device_token=V27fe46a9beacd9408382a8c33619aac056623c68ae3238745492068dceac51019&iframe=1'
#print(homepage)
driver.get(homepage)
time.sleep(3)
html = driver.page_source
src = bsp(html,'html.parser')
# name_ = src.select('div.headingArea > h2')[0].text.replace('구찌','').replace('/','').strip()
# name = re.sub('[a-zA-Z0-9]','',name_)
# realname = re.sub('\+.*','',name).strip()
# time.sleep(3)
print(src)
print('#'*100)
print('#'*100)
print('#'*100)
#     ul_list = src.select('ul.reviews > li.review')
    
#     for ul in ul_list :
#         reviewa = ul.select('a.js-link-expand')
#         print(reviewa)
        #reviewa.click()
    
#     review =
#     age = 
#     gender = 
    
    #print(realname)
#     brand_name = mains.select('p.product-main-info__brand_name')[0].text.strip()

# %%
driver = webdriver.Chrome('C:/asi/project/chromedriver_win32 (3)/chromedriver')
driver.get(url)

# %%
ur = 'https://perfumegraphy.com/product/list.html?cate_no=201/#review'
driver.get(ur)
#res = requests.get(ur, params=params)
time.sleep(3)
html2 = driver.page_source
src = bsp(html2,'html.parser')
ul_list = src.select('ul.reviews  li.review')
for ul in ul_list:
    review = ul.select('a.js-link-expand').text
    print(review)
    https://perfumegraphy.com/product/%EA%B5%AC%EC%B0%8C-%EB%B8%94%EB%A3%B8-%EC%98%A4-%EB%93%9C-%ED%8D%BC%ED%93%B8-3050100ml-%ED%85%8C%EC%8A%A4%ED%84%B0/1469/category/201/display/1/?

# %%
http://review4.cre.ma/perfumegraphy.com/products/reviews?product_code=1469&iframe_id=crema-product-reviews-&widget_id=32&widget_style=&app=0&parent_url=http%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2F&nonmember_token=&secure_device_token=V27fe46a9beacd9408382a8c33619aac056623c68ae3238745492068dceac51019&iframe=1

# %% [markdown]
# ##### 최종완성본!!!!!!!!!!!!!!!!!!

# %%
perurls = src.select('li.xans-record- > div')
for perurl in perurls:
    urls2 = perurl.select('div.prdImg > a')[0]
    homepage = urls2['href']
    productids = homepage.split('/')
    pname_ = productids[2].replace('-','').replace('구찌','').strip()
    pname = re.sub('[a-zA-Z0-9]','',pname_).strip()
    print(pname)
    print('#'*100)

# %%
perurls = src.select('li.xans-record- > div')
for perurl in perurls:
    urls2 = perurl.select('div.prdImg > a')[0]
    homepage = urls2['href']
    productids = homepage.split('/')
    nums = productids[3]
    name_ = productids[2].replace('-','').replace('구찌','').strip()
    name = re.sub('[a-zA-Z0-9]','',name_).strip()
    i = 1
    while True:
        url='http://review4.cre.ma/perfumegraphy.com/products/reviews?app=0&iframe=1&iframe_id=crema-product-reviews-1&page={0}&parent_url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&product_code={1}&secure_device_token=V281c8ef9fe71647c61b7e5908c3e2cd131479b904aa9876805c46f46e9cb0b841&widget_env=100&widget_id=32&widget_style='.format(i,nums)           
        headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36'}
        res = requests.get(url,headers=headers)
        src = res.content.strip()
        htmls = bsp(src, 'html.parser')
        time.sleep(1)
        try :
            review_list=htmls.find_all(attrs={'class':'products_reviews_board_review__message'})
            print(review_list)
            for review in review_list:
                grade = review.select('span.star')
                review_ = review.select('div.products_reviews_board_review__message_expanded')[0].text.strip()
                review1 = re.sub('\([^)]*\)','',review_)
                if len(review.select('div.review_options > div.review_option')) == 3:
                    if review.select('div.review_options > div.review_option > div.review_option__title')[0].text == '연령대':
                        age = review.select('div.review_options > div.review_option > div.review_option__content')[0].text
                        gender = review.select('div.review_options > div.review_option > div.review_option__content')[1].text
                elif len(review.select('div.review_options > div.review_option')) == 2:
                    if review.select('div.review_options > div.review_option > div.review_option__title')[0].text == '연령대':
                        age = review.select('div.review_options > div.review_option > div.review_option__content')[0].text
                        if review.select('div.review_options > div.review_option > div.review_option__title')[1].text == '성별':
                            gender = review.select('div.review_options > div.review_option > div.review_option__content')[1].text
                        else:
                            gender = ''
                    elif review.select('div.review_options > div.review_option > div.review_option__title')[0].text == '성별':
                        gender = review.select('div.review_options > div.review_option > div.review_option__content')[0].text
                        age = ''    
                elif len(review.select('div.review_options > div.review_option')) == 1:
                    if review.select('div.review_options > div.review_option > div.review_option__title')[0].text == '연령대':
                        age = review.select('div.review_options > div.review_option > div.review_option__content')[0].text
                        gender = ''
                    elif review.select('div.review_options > div.review_option > div.review_option__title')[0].text == '성별':
                        gender = review.select('div.review_options > div.review_option > div.review_option__content')[0].text
                        age = ''
                    else :
                        age = ''
                        gender = ''       
                else:
                    age = ''
                    gender = ''  
                print('구찌')
                print(name)
                print(age)
                print(gender)
                print(grade)
                print(review1)
                time.sleep(1)
                print('*'*50)
            if htmls.select('a.pagination__button'):
                print(i)
                i+=1
            else :
                break
        except:
            pass
# Out:
# [<div class="products_reviews_board_review__message">
# <div class="review_options">
# <div class="review_option">
# <div class="review_option__title">연령대</div>
# <div class="review_option__content">20대</div>
# </div>
# <div class="review_option">
# <div class="review_option__title">성별</div>
# <div class="review_option__content">여</div>
# </div>
# <div class="review_option">
# <div class="review_option__title">선택한 옵션</div>
# <div class="review_option__content">
# <span class="review_option__product_option">
# <span class="review_option__product_option_key">용량:</span>
# <span class="review_option__product_option_value">50ml</span>
# </span>
# </div>
# </div>
# </div>
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           선물용으로 너무 좋아요~
#
#
#         </div>
# </div>, <div class="products_reviews_board_review__message">
# <div class="review_options">
# <div class="review_option">
# <div class="review_option__title">연령대</div>
# <div class="review_option__content">30대</div>
# </div>
# <div class="review_option">
# <div class="review_option__title">성별</div>
# <div class="review_option__content">여</div>
# </div>
# <div class="review_option">
# <div class="review_option__title">선택한 옵션</div>
# <div class="review_option__content">
# <span class="review_option__product_option">
# <span class="review_option__product_option_key">용량:</span>
# <span class="review_option__product_option_value">100ml</span>
# </span>
# </div>
# </div>
# </div>
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           배송이 너무 빠르고 맘에들어요 ㅋㅋ 향수가 엄정좋아 사은품도 냄새가 좋아요 굿굿
#
#
#         </div>
# <ul class="products_reviews_board_review__images">
# <li class="products_reviews_board_review__image">
# <a class="js-link-fullscreen-popup" data-url="/perfumegraphy.com/reviews/18156/photo_review_popup?app=0&amp;iframe=1&amp;iframe_id=crema-product-reviews-1&amp;media_index=1&amp;page=1&amp;parent_url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&amp;parent_widget_id=32&amp;product_code=1469&amp;product_id=161&amp;secure_device_token=V281c8ef9fe71647c61b7e5908c3e2cd131479b904aa9876805c46f46e9cb0b841&amp;widget_env=100&amp;widget_style=">
# <img alt="배송이 너무 빠르고 맘에들어요 ㅋㅋ 향수가 엄정좋아 사은품도 냄새가 좋아요 굿굿" class="js-review-image smooth" src="//assets4.cre.ma/p/perfumegraphy-com/reviews/00/00/01/81/56/image1/thumbnail_619159a81d353428.jpg"/>
# </a>
# </li>
# </ul>
# </div>, <div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           친언니 선물해줬어요. 넘버5 100미리사고싶었는데 품절이라. 이걸로샀어요. 향수는 100미리죠ㅋㅋ<br/><br/>(2021-01-15 11:23:01 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# </div>, <div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           리뷰보고선물했는데 너무너무좋데요~<br/><br/>(2021-01-12 22:12:34 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# </div>, <div class="products_reviews_board_review__message">
# <div class="review_options">
# <div class="review_option">
# <div class="review_option__title">선택한 옵션</div>
# <div class="review_option__content">
# <span class="review_option__product_option">
# <span class="review_option__product_option_key">용량:</span>
# <span class="review_option__product_option_value">100ml (24%할인)</span>
# </span>
# </div>
# </div>
# </div>
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           조심스럽게 포장되있는게 얼만큼 신경써서 보냈는지 알겠더라구요 샘플향수도 넘 향이 좋아요  감사합니다
#
#
#         </div>
# <ul class="products_reviews_board_review__images">
# <li class="products_reviews_board_review__image">
# <a class="js-link-fullscreen-popup" data-url="/perfumegraphy.com/reviews/17380/photo_review_popup?app=0&amp;iframe=1&amp;iframe_id=crema-product-reviews-1&amp;media_index=1&amp;page=1&amp;parent_url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&amp;parent_widget_id=32&amp;product_code=1469&amp;product_id=161&amp;secure_device_token=V281c8ef9fe71647c61b7e5908c3e2cd131479b904aa9876805c46f46e9cb0b841&amp;widget_env=100&amp;widget_style=">
# <img alt="조심스럽게 포장되있는게 얼만큼 신경써서 보냈는지 알겠더라구요 샘플향수도 넘 향이 " class="js-review-image smooth" src="//assets4.cre.ma/p/perfumegraphy-com/reviews/00/00/01/73/80/image1/thumbnail_2643a3eb488f303b.jpg"/>
# </a>
# </li>
# </ul>
# </div>]
# 구찌
# 블룸오드퍼퓸테스터
# 20대
# 여
# []
# 선물용으로 너무 좋아요~
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
# 30대
# 여
# []
# 배송이 너무 빠르고 맘에들어요 ㅋㅋ 향수가 엄정좋아 사은품도 냄새가 좋아요 굿굿
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 친언니 선물해줬어요. 넘버5 100미리사고싶었는데 품절이라. 이걸로샀어요. 향수는 100미리죠ㅋㅋ
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 리뷰보고선물했는데 너무너무좋데요~
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 조심스럽게 포장되있는게 얼만큼 신경써서 보냈는지 알겠더라구요 샘플향수도 넘 향이 좋아요  감사합니다
# **************************************************
# 1
# [<div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           향이 아주 여성여성해요 너무 맘에 들어요 나에게 주는 선물 ㅎ<br/><br/><br/>(2020-12-09 21:50:12 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# <ul class="products_reviews_board_review__images">
# <li class="products_reviews_board_review__image">
# <a class="js-link-fullscreen-popup" data-url="/perfumegraphy.com/reviews/16626/photo_review_popup?app=0&amp;iframe=1&amp;iframe_id=crema-product-reviews-1&amp;media_index=1&amp;page=2&amp;parent_url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&amp;parent_widget_id=32&amp;product_code=1469&amp;product_id=161&amp;secure_device_token=V281c8ef9fe71647c61b7e5908c3e2cd131479b904aa9876805c46f46e9cb0b841&amp;widget_env=100&amp;widget_style=">
# <img alt="향이 아주 여성여성해요 너무 맘에 들어요 나에게 주는 선물 ㅎ
# " class="js-review-image smooth" src="//assets4.cre.ma/p/perfumegraphy-com/reviews/00/00/01/66/26/image1/thumbnail_5180e1a3fd83cb1e.jpg"/>
# </a>
# </li>
# </ul>
# </div>, <div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           딸 생일선물로 구매했는데 너무 잘쓰고 있네요 감사합니다<br/><br/>(2020-11-18 20:28:59 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# </div>, <div class="products_reviews_board_review__message">
# <div class="review_options">
# <div class="review_option">
# <div class="review_option__title">연령대</div>
# <div class="review_option__content">30대</div>
# </div>
# <div class="review_option">
# <div class="review_option__title">성별</div>
# <div class="review_option__content">여</div>
# </div>
# <div class="review_option">
# <div class="review_option__title">선택한 옵션</div>
# <div class="review_option__content">
# <span class="review_option__product_option">
# <span class="review_option__product_option_key">용량:</span>
# <span class="review_option__product_option_value">30ml</span>
# </span>
# </div>
# </div>
# </div>
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#
#
#
#         </div>
# <ul class="products_reviews_board_review__images">
# <li class="products_reviews_board_review__image">
# <a class="js-link-fullscreen-popup" data-url="/perfumegraphy.com/reviews/14349/photo_review_popup?app=0&amp;iframe=1&amp;iframe_id=crema-product-reviews-1&amp;media_index=1&amp;page=6&amp;parent_url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&amp;parent_widget_id=32&amp;product_code=1469&amp;product_id=161&amp;secure_device_token=V281c8ef9fe71647c61b7e5908c3e2cd131479b904aa9876805c46f46e9cb0b841&amp;widget_env=100&amp;widget_style=">
# <img alt="블라인드로 첫 구매한 향수에요!
# " class="js-review-image smooth" src="//assets4.cre.ma/p/perfumegraphy-com/reviews/00/00/01/43/49/image1/thumbnail_a70fc2f75b0b088e.jpg"/>
# </a>
# </li>
# </ul>
# </div>, <div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           최고에요~ 잘 사용하고 있어요<br/><br/><br/>(2020-08-25 11:07:55 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# <ul class="products_reviews_board_review__images">
# <li class="products_reviews_board_review__image">
# <a class="js-link-fullscreen-popup" data-url="/perfumegraphy.com/reviews/14244/photo_review_popup?app=0&amp;iframe=1&amp;iframe_id=crema-product-reviews-1&amp;media_index=1&amp;page=6&amp;parent_url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&amp;parent_widget_id=32&amp;product_code=1469&amp;product_id=161&amp;secure_device_token=V281c8ef9fe71647c61b7e5908c3e2cd131479b904aa9876805c46f46e9cb0b841&amp;widget_env=100&amp;widget_style=">
# <img alt="최고에요~ 잘 사용하고 있어요
# " class="js-review-image smooth" src="//assets4.cre.ma/p/perfumegraphy-com/reviews/00/00/01/42/44/image1/thumbnail_4cb6d2ec930e96a0.jpg"/>
# </a>
# </li>
# </ul>
# </div>]
# 구찌
# 블룸오드퍼퓸테스터
# 30대
# 여
# []
# 오늘 배송 받았는데 뚜껑 열고 뿌리자마자 흔하지 않은 꽃향기가 나서 기분이 좋더라구요 지금부터 쓰면 딱 좋을 것 같은 향수에요
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
# 20대
# 여
# []
# 선물했는데.굉장히 마음에 들어하네요!!! 꽃향이 은은하게.좋아요
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
# 20대
# 여
# []
# 구찌블룸 은은하게 퍼지는 꽃향기가 너무 좋아서 꼭 구매하고 싶었는데 이렇게 좋은 기회로 구매하게 되서 너무 좋았어요. 그리고 구매한 향수 뿐만 아니라 샘플 향수까지 챙겨주셔서 너무 감사합니다. 또 구매하러 올게요😁
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
# 20대
# 여
# []
# 블라인드로 첫 구매한 향수에요!시향기만 보고선 선택한 아이라 나랑 잘 맞을까 걱정을 많이 했는데 왠걸 잘 맞더라구요 :) 누구나 그러겠지만 진향 향수를 오랫동안 맡으면 머리 아프고 향수가 금방 질리는데 이 아이는 시간이 흐를수록 잔향이 더 좋더라고요! 처음 뿌릴 때는 조금 진한 감이 없지 않아 있는데  시간 좀 흐르고 잔향이 너무 부드럽고 좋았어요 ㅎㅎ 표현을 어떻게 해야 모르겠지만, 활짝 핀 꽃들이 있는 나무들을 지나가는 느낌이에요! " 아 내가 인간 구찌 꽃이다." 라는 느낌을 받았어요ㅋㅋㅋㅋㅋㅋㅋ:) 어울린다면 남자들이 써도 괜찮은 향수 같아요! 꽃이지만 그렇다고 너무 페미닌한 느낌을 주지는 않았어요. 그래서 더 좋았습니다 !! 퍼퓸그라피에서 앞으로 자주 구매 할 것 같아요 배송도 빨랐고 무엇보다 가격적인 면에서도 장점이라 생각하고 가품 걱정 할 일은 없어서 믿고 구매해용 :D
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 최고에요~ 잘 사용하고 있어요
# **************************************************
# 6
# [<div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           포장도 꼼꼼하고 깔끔하게 빨리 왔어요!<br/><br/><br/>(2020-08-21 16:43:24 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# <ul class="products_reviews_board_review__images">
# <li class="products_reviews_board_review__image">
# <a class="js-link-fullscreen-popup" data-url="/perfumegraphy.com/reviews/14151/photo_review_popup?app=0&amp;iframe=1&amp;iframe_id=crema-product-reviews-1&amp;media_index=1&amp;page=7&amp;parent_url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&amp;parent_widget_id=32&amp;product_code=1469&amp;product_id=161&amp;secure_device_token=V281c8ef9fe71647c61b7e5908c3e2cd131479b904aa9876805c46f46e9cb0b841&amp;widget_env=100&amp;widget_style=">
# <img alt="포장도 꼼꼼하고 깔끔하게 빨리 왔어요!
# " class="js-review-image smooth" src="//assets4.cre.ma/p/perfumegraphy-com/reviews/00/00/01/41/51/image1/thumbnail_3b9f1de3fc4414a0.jpg"/>
# </a>
# </li>
# </ul>
# </div>, <div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           너무 깔끔하게 와서 깜짝놀랐어요!! 선물 줄거라서 쇼핑백 구겨지면 어쩌나 싶었는데 너무 만족스러워요ㅎㅎ<br/><br/><br/>(2020-08-16 14:17:53 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# <ul class="products_reviews_board_review__images">
# <li class="products_reviews_board_review__image">
# <a class="js-link-fullscreen-popup" data-url="/perfumegraphy.com/reviews/14042/photo_review_popup?app=0&amp;iframe=1&amp;iframe_id=crema-product-reviews-1&amp;media_index=1&amp;page=7&amp;parent_url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&amp;parent_widget_id=32&amp;product_code=1469&amp;product_id=161&amp;secure_device_token=V281c8ef9fe71647c61b7e5908c3e2cd131479b904aa9876805c46f46e9cb0b841&amp;widget_env=100&amp;widget_style=">
# <img alt="너무 깔끔하게 와서 깜짝놀랐어요!! 선물 줄거라서 쇼핑백 구겨지면 어쩌나 싶었는데 너" class="js-review-image smooth" src="//assets4.cre.ma/p/perfumegraphy-com/reviews/00/00/01/40/42/image1/thumbnail_c2458263d7283270.jpg"/>
# </a>
# </li>
# </ul>
# </div>, <div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           만족<br/>선물 받는 분이 좋아하셨어요~~!<br/><br/>(2020-08-14 17:13:58 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# </div>, <div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           배송 정말 빠르게 왔고, 포장도 꼼꼼하게 잘 왔어요! 향수 용량 작은거 샀는데 쇼핑백이 너무 커서 별하나 깎았어요ㅎㅎㅎ 향수사이즈에 맞춰서 쇼핑백 있으면 더 좋을거 같아요! 개인적으로!ㅎㅎㅎ<br/><br/><br/>(2020-08-14 21:13:52 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# <ul class="products_reviews_board_review__images">
# <li class="products_reviews_board_review__image">
# <a class="js-link-fullscreen-popup" data-url="/perfumegraphy.com/reviews/14005/photo_review_popup?app=0&amp;iframe=1&amp;iframe_id=crema-product-reviews-1&amp;media_index=1&amp;page=7&amp;parent_url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&amp;parent_widget_id=32&amp;product_code=1469&amp;product_id=161&amp;secure_device_token=V281c8ef9fe71647c61b7e5908c3e2cd131479b904aa9876805c46f46e9cb0b841&amp;widget_env=100&amp;widget_style=">
# <img alt="배송 정말 빠르게 왔고, 포장도 꼼꼼하게 잘 왔어요! 향수 용량 작은거 샀는데 쇼핑백이" class="js-review-image smooth" src="//assets4.cre.ma/p/perfumegraphy-com/reviews/00/00/01/40/05/image1/thumbnail_95d9b32c75bbc8d8.jpg"/>
# </a>
# </li>
# <li class="products_reviews_board_review__image">
# <a class="js-link-fullscreen-popup" data-url="/perfumegraphy.com/reviews/14005/photo_review_popup?app=0&amp;iframe=1&amp;iframe_id=crema-product-reviews-1&amp;media_index=2&amp;page=7&amp;parent_url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&amp;parent_widget_id=32&amp;product_code=1469&amp;product_id=161&amp;secure_device_token=V281c8ef9fe71647c61b7e5908c3e2cd131479b904aa9876805c46f46e9cb0b841&amp;widget_env=100&amp;widget_style=">
# <img alt="배송 정말 빠르게 왔고, 포장도 꼼꼼하게 잘 왔어요! 향수 용량 작은거 샀는데 쇼핑백이" class="js-review-image smooth" src="//assets4.cre.ma/p/perfumegraphy-com/reviews/00/00/01/40/05/image2/thumbnail_5d4d31b6a4ef8c4b.jpg"/>
# </a>
# </li>
# </ul>
# </div>, <div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           보통<br/>좋아야 좋아요 좋아여<br/><br/>(2020-08-05 22:25:12 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# </div>]
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 포장도 꼼꼼하고 깔끔하게 빨리 왔어요!
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 너무 깔끔하게 와서 깜짝놀랐어요!! 선물 줄거라서 쇼핑백 구겨지면 어쩌나 싶었는데 너무 만족스러워요ㅎㅎ
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 만족선물 받는 분이 좋아하셨어요~~!
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 배송 정말 빠르게 왔고, 포장도 꼼꼼하게 잘 왔어요! 향수 용량 작은거 샀는데 쇼핑백이 너무 커서 별하나 깎았어요ㅎㅎㅎ 향수사이즈에 맞춰서 쇼핑백 있으면 더 좋을거 같아요! 개인적으로!ㅎㅎㅎ
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 보통좋아야 좋아요 좋아여
# **************************************************
# 7
# [<div class="products_reviews_board_review__message">
# <div class="review_options">
# <div class="review_option">
# <div class="review_option__title">연령대</div>
# <div class="review_option__content">20대</div>
# </div>
# <div class="review_option">
# <div class="review_option__title">성별</div>
# <div class="review_option__content">남</div>
# </div>
# <div class="review_option">
# <div class="review_option__title">선택한 옵션</div>
# <div class="review_option__content">
# <span class="review_option__product_option">
# <span class="review_option__product_option_key">용량:</span>
# <span class="review_option__product_option_value">30ml</span>
# </span>
# </div>
# </div>
# </div>
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           선물로 샀는데 은은하고 좋다고 하네요
#
#
#         </div>
# </div>, <div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           만족<br/>친구 생일선물로 샀는데 배송 빠르고 좋아요!<br/><br/>(2020-08-02 17:59:54 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# </div>, <div class="products_reviews_board_review__message">
# <div class="review_options">
# <div class="review_option">
# <div class="review_option__title">연령대</div>
# <div class="review_option__content">30대</div>
# </div>
# <div class="review_option">
# <div class="review_option__title">성별</div>
# <div class="review_option__content">여</div>
# </div>
# <div class="review_option">
# <div class="review_option__title">선택한 옵션</div>
# <div class="review_option__content">
# <span class="review_option__product_option">
# <span class="review_option__product_option_key">용량:</span>
# <span class="review_option__product_option_value">100ml (24%할인)</span>
# </span>
# </div>
# </div>
# </div>
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           생각했던향은 아니였지만<br/>처음보다는<br/>시간이 지나고 나서야 향이좋은것같아요
#
#
#         </div>
# </div>, <div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           만족<br/>너무감사합니다 수고하셨습니다<br/><br/>(2020-07-23 22:23:53 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# </div>, <div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           너무 이뻐서 괜찮았고요 선물용으로 너무 좋습니다<br/><br/><br/>(2020-07-23 04:13:59 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# <ul class="products_reviews_board_review__images">
# <li class="products_reviews_board_review__image">
# <a class="js-link-fullscreen-popup" data-url="/perfumegraphy.com/reviews/13472/photo_review_popup?app=0&amp;iframe=1&amp;iframe_id=crema-product-reviews-1&amp;media_index=1&amp;page=8&amp;parent_url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&amp;parent_widget_id=32&amp;product_code=1469&amp;product_id=161&amp;secure_device_token=V281c8ef9fe71647c61b7e5908c3e2cd131479b904aa9876805c46f46e9cb0b841&amp;widget_env=100&amp;widget_style=">
# <img alt="너무 이뻐서 괜찮았고요 선물용으로 너무 좋습니다
# " class="js-review-image smooth" src="//assets4.cre.ma/p/perfumegraphy-com/reviews/00/00/01/34/72/image1/thumbnail_fd5e40708f3da6bb.jpg"/>
# </a>
# </li>
# </ul>
# </div>]
# 구찌
# 블룸오드퍼퓸테스터
# 20대
# 남
# []
# 선물로 샀는데 은은하고 좋다고 하네요
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 만족친구 생일선물로 샀는데 배송 빠르고 좋아요!
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
# 30대
# 여
# []
# 생각했던향은 아니였지만처음보다는시간이 지나고 나서야 향이좋은것같아요
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 만족너무감사합니다 수고하셨습니다
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 너무 이뻐서 괜찮았고요 선물용으로 너무 좋습니다
# **************************************************
# 8
# [<div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           만족<br/>배송도 빨랐고 선물포장 뽁뽁이 다 만족합니다 다음에 또 구매하겠습니다<br/><br/>(2020-07-22 18:05:47 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# </div>, <div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           냄새좋아용~~~~~~<br/><br/><br/>(2020-07-21 12:48:17 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# <ul class="products_reviews_board_review__images">
# <li class="products_reviews_board_review__image">
# <a class="js-link-fullscreen-popup" data-url="/perfumegraphy.com/reviews/13459/photo_review_popup?app=0&amp;iframe=1&amp;iframe_id=crema-product-reviews-1&amp;media_index=1&amp;page=9&amp;parent_url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&amp;parent_widget_id=32&amp;product_code=1469&amp;product_id=161&amp;secure_device_token=V281c8ef9fe71647c61b7e5908c3e2cd131479b904aa9876805c46f46e9cb0b841&amp;widget_env=100&amp;widget_style=">
# <img alt="냄새좋아용~~~~~~
# " class="js-review-image smooth" src="//assets4.cre.ma/p/perfumegraphy-com/reviews/00/00/01/34/59/image1/thumbnail_9da2b2dcf3ec804a.jpg"/>
# </a>
# </li>
# </ul>
# </div>, <div class="products_reviews_board_review__message">
# <div class="review_options">
# <div class="review_option">
# <div class="review_option__title">선택한 옵션</div>
# <div class="review_option__content">
# <span class="review_option__product_option">
# <span class="review_option__product_option_key">용량:</span>
# <span class="review_option__product_option_value">30ml</span>
# </span>
# </div>
# </div>
# </div>
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           쇼핑백이 백화점에서 구매했을때랑 달라서 향수 제품은 다른건가 해서 주변 지인들 한테 물어봤는데 지인들도 샀을때 원래 구찌 쇼핑백을 받았다고 합니당<br/>근데 이번에 주문해서 받은 쇼핑백이 백화점꺼랑은 다른데 혹시 쇼핑백은 정품이 아닌가요?..선물용으로 급하게ㅜ산건데 쇼핑백이 가품일까봐 걱정되네요
#
#
#         </div>
# </div>, <div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           만족<br/>너무 좋아오오옹 다음엔 다른 향도 도전 해봐야겠네요<br/><br/>(2020-07-14 23:23:10 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# </div>, <div class="products_reviews_board_review__message">
# <div class="products_reviews_board_review__message_expanded js-translate-review-message">
#           빠른배송 너무 감사합니다<br/><br/><br/>(2020-07-12 12:17:28 에 등록된 네이버 페이 구매평)
#
#
#         </div>
# <ul class="products_reviews_board_review__images">
# <li class="products_reviews_board_review__image">
# <a class="js-link-fullscreen-popup" data-url="/perfumegraphy.com/reviews/13257/photo_review_popup?app=0&amp;iframe=1&amp;iframe_id=crema-product-reviews-1&amp;media_index=1&amp;page=9&amp;parent_url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&amp;parent_widget_id=32&amp;product_code=1469&amp;product_id=161&amp;secure_device_token=V281c8ef9fe71647c61b7e5908c3e2cd131479b904aa9876805c46f46e9cb0b841&amp;widget_env=100&amp;widget_style=">
# <img alt="빠른배송 너무 감사합니다
# " class="js-review-image smooth" src="//assets4.cre.ma/p/perfumegraphy-com/reviews/00/00/01/32/57/image1/thumbnail_cbff8ce9bea705d0.jpg"/>
# </a>
# </li>
# </ul>
# </div>]
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 만족배송도 빨랐고 선물포장 뽁뽁이 다 만족합니다 다음에 또 구매하겠습니다
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 냄새좋아용~~~~~~
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 쇼핑백이 백화점에서 구매했을때랑 달라서 향수 제품은 다른건가 해서 주변 지인들 한테 물어봤는데 지인들도 샀을때 원래 구찌 쇼핑백을 받았다고 합니당근데 이번에 주문해서 받은 쇼핑백이 백화점꺼랑은 다른데 혹시 쇼핑백은 정품이 아닌가요?..선물용으로 급하게ㅜ산건데 쇼핑백이 가품일까봐 걱정되네요
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 만족너무 좋아오오옹 다음엔 다른 향도 도전 해봐야겠네요
# **************************************************
# 구찌
# 블룸오드퍼퓸테스터
#
#
# []
# 빠른배송 너무 감사합니다
# **************************************************
# 9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-cf0fdaa8f22c> in <module>
#      14         src = res.content.strip()
#      15         htmls = bsp(src, 'html.parser')
# ---> 16         time.sleep(1)
#      17         try :
#      18             review_list=htmls.find_all(attrs={'class':'products_reviews_board_review__message'})
#
# KeyboardInterrupt:

# %%
def getData(d): # 데이터베이스에 데이터 집어넣기
    dbname='perfume.db'
    with sqlite3.connect(dbname) as conn:
        cursor=conn.cursor()
        sql='INSERT INTO perfumegra (brand_name,name,page,gender,grade,review1) VALUES(?,?,?,?,?,?,? )' 
        res=cursor.execute(sql,d)
        print('.',end='')
