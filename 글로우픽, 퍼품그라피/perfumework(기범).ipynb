# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup as bsp
import matplotlib
import matplotlib.pyplot as plt
import sqlite3
import re
from datetime import datetime, timedelta,date
import sys
from dateutil.parser import parse

# %%
def coupang():
    dbname='coupang.db'
    with sqlite3.connect(dbname) as conn:
        cursor=conn.cursor()
        sql='select * from coupang '
        qry=cursor.execute(sql)
        desc=[row[0] for row in qry.description]
        data=qry.fetchall()
    return((desc,data))

# %%
def glowpick():
    dbname='glowpick.db'
    with sqlite3.connect(dbname) as conn:
        cursor=conn.cursor()
        sql='select * from glow '
        qry=cursor.execute(sql)
        desc=[row[0] for row in qry.description]
        data=qry.fetchall()
    return((desc,data))

# %%
def lohbs():
    
    dbname='Lohbs.db'
    with sqlite3.connect(dbname) as conn:
        cursor=conn.cursor()
        sql='select * from lohbsreview '
        qry=cursor.execute(sql)
        desc=[row[0] for row in qry.description]
        data=qry.fetchall()
    return((desc,data))

# %%
def oliveyoung():
    
    dbname='Oliveyoung.db'
    with sqlite3.connect(dbname) as conn:
        cursor=conn.cursor()
        sql='select * from oliveyoungreview '
        qry=cursor.execute(sql)
        desc=[row[0] for row in qry.description]
        data=qry.fetchall()
    return((desc,data))

# %%
def perfume():
    
    dbname='perfume(transformed).db'
    with sqlite3.connect(dbname) as conn:
        cursor=conn.cursor()
        sql='select * from perfumegra '
        qry=cursor.execute(sql)
        desc=[row[0] for row in qry.description]
        data=qry.fetchall()
    return((desc,data))

# %%
def naver():
    
    dbname='project_naver.db'
    with sqlite3.connect(dbname) as conn:
        cursor=conn.cursor()
        sql='select * from sub '
        qry=cursor.execute(sql)
        desc=[row[0] for row in qry.description]
        data=qry.fetchall()
    return((desc,data))

# %%
def SSG():
    
    dbname='SSG.db'
    with sqlite3.connect(dbname) as conn:
        cursor=conn.cursor()
        sql='select * from SSG '
        qry=cursor.execute(sql)
        desc=[row[0] for row in qry.description]
        data=qry.fetchall()
    return((desc,data))

# %%
cdata=coupang()
gdata=glowpick()
ldata=lohbs()
odata=oliveyoung()
pdata=perfume()
ndata=naver()
sdata=SSG()

# %%
cf=pd.DataFrame(data=cdata[1],columns=cdata[0])
gf=pd.DataFrame(data=gdata[1],columns=gdata[0])
lf=pd.DataFrame(data=ldata[1],columns=ldata[0])
of=pd.DataFrame(data=odata[1],columns=odata[0])
pf=pd.DataFrame(data=pdata[1],columns=pdata[0])
nf=pd.DataFrame(data=ndata[1],columns=ndata[0])
sf=pd.DataFrame(data=sdata[1],columns=sdata[0])

# %%
pnames=[]

# %%
for i in pf['product']:
    a=i.replace('오 드 뚜왈렛','EDT').replace('오드뚜왈렛','EDT').replace('오 드 퍼퓸','EDP').replace('오드퍼퓸','EDP').replace('오드 퍼퓸','EDP').replace('오 드 빠르펭','EDP').replace('코롱','EDC')\
    .replace('엑스트레 드 퍼퓸','PE')
    pnames.append(a)

# %%
pnames

# %%
for i,v in enumerate(pnames):
    pf['product'][i]=v
type(pf['product'][0])
# Out:
# <ipython-input-13-d551fbf3f7d2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pf['product'][i]=v
# str

# %%
def insInfo(d):
    dbname='perfume(unified).db'
    with sqlite3.connect(dbname) as conn:
        cursor=conn.cursor()
        sql='insert into perfumegra (brand,product,gender,rating,review,note,type) values(?,?,?,?,?,?,?)'
        res=cursor.execute(sql,d)
        print('.',end='')

# %% [raw]
# for i in range(len(pf)):
#     brand=pf['brand'][i]
#     product=pf['product'][i]
#     gender=pf['gender'][i]
#     review=pf['review'][i]
#     note=pf['note'][i]
#     type=pf['type'][i]
#     d=(brand,product,gender,review,note,type)
#     #insInfo(d)

# %%
pf
# Out:
#          idx        brand                    product gender  rating  \
# 0          1  SARANGHAEYO     사랑해요 #30 브리즈 오브 샤인 EDP              5
# 1          2  SARANGHAEYO        사랑해요 #71 시리즈 에이 EDP              5
# 2          3  SARANGHAEYO   사랑해요 #51 드라이브 투 선버스트 EDP              5
# 3          4  SARANGHAEYO  사랑해요 #60 소울 오브 더 포레스트 EDP              5
# 4          5           겔랑                 겔랑 베티버 EDT              5
# ...      ...          ...                        ...    ...     ...
# 13931  13932         필로소피         필로소피 어메이징 그레이스 EDT              5
# 13932  13933         필로소피         필로소피 어메이징 그레이스 EDT              5
# 13933  13934         필로소피         필로소피 어메이징 그레이스 EDT              5
# 13934  13935         필로소피         필로소피 어메이징 그레이스 EDT              5
# 13935  13936         필로소피         필로소피 어메이징 그레이스 EDT              5
#
#                                                   review  note  type
# 0      코코넛향 보다는 바닷가 휴양지의 묘한 나무 오두막 느낌이 나요~ 살짝 우디한 느낌인...  None  None
# ...

# %%
def typedecision(i):
    if 'EDP' in i:
        pf['type'][i]='EDP'
    elif 'EDT' in i:
        pf['type'][i]='EDT'
    elif 'EDC' in i:
        pf['type'][i]='EDC'
    else:
        pass

# %%
for i,v in enumerate(pf['product']):
    if 'EDP' in v:
        pf['type'][i]='EDP'
    elif 'EDT' in v:
        pf['type'][i]='EDT'
    elif 'EDC' in v:
        pf['type'][i]='EDC'
    elif 'PE' in v:
        pf['type'][i]='PE'
    else:
        '''
        try:
            found=nf[(nf['product'].str.contains(v))].iloc[0]['product']
            typedecision(found)
        except:
            pass
        '''
        pass
# Out:
# <ipython-input-16-6eb2946b6bca>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pf['type'][i]='EDP'
# <ipython-input-16-6eb2946b6bca>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pf['type'][i]='EDT'
# <ipython-input-16-6eb2946b6bca>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pf['type'][i]='EDC'
# <ipython-input-16-6eb2946b6bca>:9: SettingWithCopyWarning:
# ...

# %%
pf
# Out:
#          idx        brand                    product gender  rating  \
# 0          1  SARANGHAEYO     사랑해요 #30 브리즈 오브 샤인 EDP              5
# 1          2  SARANGHAEYO        사랑해요 #71 시리즈 에이 EDP              5
# 2          3  SARANGHAEYO   사랑해요 #51 드라이브 투 선버스트 EDP              5
# 3          4  SARANGHAEYO  사랑해요 #60 소울 오브 더 포레스트 EDP              5
# 4          5           겔랑                 겔랑 베티버 EDT              5
# ...      ...          ...                        ...    ...     ...
# 13931  13932         필로소피         필로소피 어메이징 그레이스 EDT              5
# 13932  13933         필로소피         필로소피 어메이징 그레이스 EDT              5
# 13933  13934         필로소피         필로소피 어메이징 그레이스 EDT              5
# 13934  13935         필로소피         필로소피 어메이징 그레이스 EDT              5
# 13935  13936         필로소피         필로소피 어메이징 그레이스 EDT              5
#
#                                                   review  note type
# 0      코코넛향 보다는 바닷가 휴양지의 묘한 나무 오두막 느낌이 나요~ 살짝 우디한 느낌인...  None  EDP
# ...

# %%
try:
    found=nf[(nf['product'].str.contains('RBRB'))].iloc[0]['product']
    print(found)
except:
    print('없음')
# Out:
# 없음

# %%
apf=pf.groupby(['product'],as_index=False).agg(lambda x : x.mean() if x.dtype=='int64' else ' '.join(x))
# Out:
#                       product      idx  \
# 0    (리뉴얼) 세르주루텐 라 휘드 베흘랑 EDP   7988.0
# 1       TDC 더 디퍼런트 컴퍼니 쉬브림발키스   1927.5
# 2        TDC 더 디퍼런트 컴퍼니 오스만투스   1915.5
# 3         TDC 더 디퍼런트 컴퍼니 퓨어이브   1921.0
# 4          겔랑 라 쁘띠 로브 느와르 EDP     28.0
# ..                        ...      ...
# 429          필로소피 퓨어 그레이스 EDT  13904.0
# 430    필로소피 퓨어 그레이스 누드 로즈 EDT  13910.0
# 431          해피 쇼파드 레몬 돌치 EDP   7999.5
# 432          해피 쇼파드 비가라디아 EDP   7998.0
# 433        해피 쇼파드 펠리시아 로즈 EDP   7996.5
#
#                                                  brand            gender  \
# 0    세르주루텐 세르주루텐 세르주루텐 세르주루텐 세르주루텐 세르주루텐 세르주루텐 세르주루...
# 1    더 디퍼런트 컴퍼니 더 디퍼런트 컴퍼니 더 디퍼런트 컴퍼니 더 디퍼런트 컴퍼니 더 ...
# 2          더 디퍼런트 컴퍼니 더 디퍼런트 컴퍼니 더 디퍼런트 컴퍼니 더 디퍼런트 컴퍼니
# 3    더 디퍼런트 컴퍼니 더 디퍼런트 컴퍼니 더 디퍼런트 컴퍼니 더 디퍼런트 컴퍼니 더 ...
# 4    겔랑 겔랑 겔랑 겔랑 겔랑 겔랑 겔랑 겔랑 겔랑 겔랑 겔랑 겔랑 겔랑 겔랑 겔랑 겔...
# ..                                                 ...               ...
# 429                                     필로소피 필로소피 필로소피
# ...

# %%
apf
# Out:
#                       product      idx        brand            gender  rating  \
# 0    (리뉴얼) 세르주루텐 라 휘드 베흘랑 EDP   7988.0  SARANGHAEYO                         5
# 1       TDC 더 디퍼런트 컴퍼니 쉬브림발키스   1927.5  SARANGHAEYO                         5
# 2        TDC 더 디퍼런트 컴퍼니 오스만투스   1915.5  SARANGHAEYO                         5
# 3         TDC 더 디퍼런트 컴퍼니 퓨어이브   1921.0  SARANGHAEYO                         5
# 4          겔랑 라 쁘띠 로브 느와르 EDP     28.0           겔랑                         5
# ..                        ...      ...          ...               ...     ...
# 429          필로소피 퓨어 그레이스 EDT  13904.0           구찌                         5
# 430    필로소피 퓨어 그레이스 누드 로즈 EDT  13910.0           구찌                         5
# 431          해피 쇼파드 레몬 돌치 EDP   7999.5           구찌                         5
# 432          해피 쇼파드 비가라디아 EDP   7998.0           구찌                         5
# 433        해피 쇼파드 펠리시아 로즈 EDP   7996.5           구찌                         5
#
# ...

# %%
apf['note']=pf['note']
apf['type']=pf['type']
apf['brand']=pf['brand']
apf
# Out:
#                       product      idx        brand            gender  rating  \
# 0    (리뉴얼) 세르주루텐 라 휘드 베흘랑 EDP   7988.0  SARANGHAEYO                         5
# 1       TDC 더 디퍼런트 컴퍼니 쉬브림발키스   1927.5  SARANGHAEYO                         5
# 2        TDC 더 디퍼런트 컴퍼니 오스만투스   1915.5  SARANGHAEYO                         5
# 3         TDC 더 디퍼런트 컴퍼니 퓨어이브   1921.0  SARANGHAEYO                         5
# 4          겔랑 라 쁘띠 로브 느와르 EDP     28.0           겔랑                         5
# ..                        ...      ...          ...               ...     ...
# 429          필로소피 퓨어 그레이스 EDT  13904.0           구찌                         5
# 430    필로소피 퓨어 그레이스 누드 로즈 EDT  13910.0           구찌                         5
# 431          해피 쇼파드 레몬 돌치 EDP   7999.5           구찌                         5
# 432          해피 쇼파드 비가라디아 EDP   7998.0           구찌                         5
# 433        해피 쇼파드 펠리시아 로즈 EDP   7996.5           구찌                         5
#
# ...

# %% [markdown]
# ### 빈값 다른 디비파일에서 찾아서 넣기

# %%
def typedecision1(i):
    if 'EDP' in i:
        apf['type'][i]='EDP'
    elif 'EDT' in i:
        apf['type'][i]='EDT'
    elif 'EDC' in i:
        apf['type'][i]='EDC'
    else:
        apf['type'][i]='-'

# %%
for i,v in enumerate(apf['product']):
    if 'EDP' in v:
        apf['type'][i]='EDP'
    elif 'EDT' in v:
        apf['type'][i]='EDT'
    elif 'EDC' in v:
        apf['type'][i]='EDC'
    elif 'PE' in v:
        apf['type'][i]='PE'
    else:
       
        try:
            found=nf[(nf['product'].str.contains(v))].iloc[0]['product']
            typedecision1(found)
        except:
            try:
                found=sf[(sf['product'].str.contains(v))].iloc[0]['product']
                typedecision1(found)
            except:
                try:
                    found=of[(of['name'].str.contains(v))].iloc[0]['name']
                    typedecision1(found)
                except:
                    try:
                        found=lf[(lf['name'].str.contains(v))].iloc[0]['name']
                        typedecision1(found)
                    except:
                        try:
                            found=gf[(gf['name'].str.contains(v))].iloc[0]['name']
                            typedecision1(found)
                        except:
                            try:
                                found=cf[(cf['name'].str.contains(v))].iloc[0]['name']
                                typedecision1(found)
                            except:
                                apf['type'][i]='-'
# Out:
# <ipython-input-37-9f4ae55fa805>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apf['type'][i]='EDP'
# <ipython-input-37-9f4ae55fa805>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apf['type'][i]='-'
# <ipython-input-37-9f4ae55fa805>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apf['type'][i]='EDT'
# <ipython-input-25-14e923073b9b>:9: SettingWithCopyWarning:
# ...

# %%
apf
# Out:
#                       product      idx        brand            gender  rating  \
# 0    (리뉴얼) 세르주루텐 라 휘드 베흘랑 EDP   7988.0  SARANGHAEYO                         5
# 1       TDC 더 디퍼런트 컴퍼니 쉬브림발키스   1927.5  SARANGHAEYO                         5
# 2        TDC 더 디퍼런트 컴퍼니 오스만투스   1915.5  SARANGHAEYO                         5
# 3         TDC 더 디퍼런트 컴퍼니 퓨어이브   1921.0  SARANGHAEYO                         5
# 4          겔랑 라 쁘띠 로브 느와르 EDP     28.0           겔랑                         5
# ..                        ...      ...          ...               ...     ...
# 429          필로소피 퓨어 그레이스 EDT  13904.0           구찌                         5
# 430    필로소피 퓨어 그레이스 누드 로즈 EDT  13910.0           구찌                         5
# 431          해피 쇼파드 레몬 돌치 EDP   7999.5           구찌                         5
# 432          해피 쇼파드 비가라디아 EDP   7998.0           구찌                         5
# 433        해피 쇼파드 펠리시아 로즈 EDP   7996.5           구찌                         5
#
# ...

# %%
sf
# Out:
#       index            brand              product  \
# 0         1  몽블랑 (MONTBLANC)          몽블랑 레전드 EDT
# 1         2  몽블랑 (MONTBLANC)          몽블랑 레전드 EDT
# 2         3  몽블랑 (MONTBLANC)          몽블랑 레전드 EDT
# 3         4  몽블랑 (MONTBLANC)          몽블랑 레전드 EDT
# 4         5  몽블랑 (MONTBLANC)          몽블랑 레전드 EDT
# ...     ...              ...                  ...
# 8534   8535               샤넬  코코 마드모아젤 로 프리베 스프레이
# 8535   8536               샤넬  코코 마드모아젤 로 프리베 스프레이
# 8536   8537               샤넬  코코 마드모아젤 로 프리베 스프레이
# 8537   8538               샤넬  코코 마드모아젤 로 프리베 스프레이
# 8538   8539               샤넬  코코 마드모아젤 로 프리베 스프레이
#
#                                                  review rate Frag Frag_time
# 0     몽블랑 을 구입했는데요 향도 오래가고 계속계속 뿌리고싶어져요 어디나갈때 이걸 안쓰면...    5    5         5
# 1                   몽블랑 레젠드 향 굿굿 좋습니다두번사세요 ! 강력히 추천합니다.    5    1         3
# 2     평소 출퇴근 용으로 많이 사용하는 데 정장에 특히 잘 어울리는 느낌이네요. 캐주얼보...    5    1         3
# ...

# %%
try:
    found=nf[(nf['name'].str.contains('겔랑 베티버 오드뚜왈렛'))].iloc[0]['product']
    print(found)
except:
    print('없음')
# Out:
# 없음

# %%
for i,v in enumerate(apf['product']):
    a=v.replace('EDT','').replace('EDP','').replace('PE','').replace('EDC','')
    print(a)
    try:
        apf['gender'][i]=nf[(nf['product'].str.contains(a))].iloc[0]['gender']
    except:
        apf['gender'][i]='-'
# Out:
# (리뉴얼) 세르주루텐 라 휘드 베흘랑
# C:\Users\721\anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# <ipython-input-60-14c5838cdd52>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apf['gender'][i]='-'
# TDC 더 디퍼런트 컴퍼니 쉬브림발키스
# TDC 더 디퍼런트 컴퍼니 오스만투스
# TDC 더 디퍼런트 컴퍼니 퓨어이브
# 겔랑 라 쁘띠 로브 느와르
# <ipython-input-60-14c5838cdd52>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apf['gender'][i]=nf[(nf['product'].str.contains(a))].iloc[0]['gender']
# 겔랑 라쁘띠 로브 느와르
# 겔랑 랭스땅뜨 드 겔랑
# 겔랑 랭스땅뜨 드 겔랑
# ...

# %%
pd.set_option('display.max_row', 500)

# %%
apf
# Out:
#                                    product      idx        brand  gender  \
# 0                 (리뉴얼) 세르주루텐 라 휘드 베흘랑 EDP   7988.0  SARANGHAEYO       -
# 1                    TDC 더 디퍼런트 컴퍼니 쉬브림발키스   1927.5  SARANGHAEYO       -
# 2                     TDC 더 디퍼런트 컴퍼니 오스만투스   1915.5  SARANGHAEYO       -
# 3                      TDC 더 디퍼런트 컴퍼니 퓨어이브   1921.0  SARANGHAEYO       -
# 4                       겔랑 라 쁘띠 로브 느와르 EDP     28.0           겔랑    여성향수
# 5                        겔랑 라쁘띠 로브 느와르 EDT     42.0           겔랑       -
# 6                         겔랑 랭스땅뜨 드 겔랑 EDP     14.5           겔랑       -
# 7                         겔랑 랭스땅뜨 드 겔랑 EDT     18.5           겔랑       -
# 8                              겔랑 몽 겔랑 EDP     59.0           겔랑       -
# 9                              겔랑 몽 겔랑 EDT     17.0           겔랑       -
# 10                              겔랑 베티버 EDT      6.0           겔랑       -
# 11                             겔랑 샹제리제 EDP     64.5           겔랑    여성향수
# ...

# %%
for i in range(len(apf)):
    brand=apf['brand'][i]
    product=apf['product'][i]
    gender=apf['gender'][i]
    rating=apf['rating'][i]
    review=apf['review'][i]
    note=apf['note'][i]
    type=apf['type'][i]
    d=(brand,product,gender,rating,review,note,type)
    insInfo(d)
# Out:
# ..................................................................................................................................................................................................................................................................................................................................................................................................................................................

# %%
def perfume_unified():
    
    dbname='perfume(unified).db'
    with sqlite3.connect(dbname) as conn:
        cursor=conn.cursor()
        sql='select * from perfumegra '
        qry=cursor.execute(sql)
        desc=[row[0] for row in qry.description]
        data=qry.fetchall()
    return((desc,data))

# %%
pdate=perfume_unified()
df=pd.DataFrame(data=pdata[1],columns=pdata[0])

# %% [markdown]
# ### 빈값 네이버 쇼핑 검색

# %%
dpath='C:\\Users\\721\\Downloads\\chromedriver_win32 (1)\\chromedriver'

# %%
from bs4 import BeautifulSoup as bsp
from selenium import webdriver
driver=webdriver.Chrome(dpath)

# %%
url='https://search.shopping.naver.com/search/all?query={}'.format('겔랑 베티버')
driver.get(url)
driver.implicitly_wait(3)
html=driver.page_source
src=bsp(html,'html.parser')
cts=src.select('div.basicList_detail_box__3ta3h a')
# Out:
# '오 드 뚜왈렛'

# %%
type=cts[2].text.replace('종류 : ','')
gender=cts[3].text.replace('성별 : ','').replace('용','')
gender
# Out:
# '남성'

# %%
def fullempty(name):
    url='https://search.shopping.naver.com/search/all?query={}'.format('name')
    driver.get(url)
    driver.implicitly_wait(3)
    html=driver.page_source
    src=bsp(html,'html.parser')
    cts=src.select('div.basicList_detail_box__3ta3h a')
    type_=cts[2].text.replace('종류 : ','')
    gender=cts[3].text.replace('성별 : ','')
    type=type_.replace('오 드 뚜왈렛','EDT').replace('오드뚜왈렛','EDT').replace('오 드 퍼퓸','EDP').replace('오드퍼퓸','EDP').replace('오드 퍼퓸','EDP').replace('오 드 빠르펭','EDP').replace('코롱','EDC')\
    .replace('엑스트레 드 퍼퓸','PE')
    
    return type,gender
