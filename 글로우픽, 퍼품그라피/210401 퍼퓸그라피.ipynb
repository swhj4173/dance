# %% [raw]
# 처음에 셀레니움으로 브랜드 페이지 열고
# url 을 뷰티숩으로 하나씩 도출
# 각 url에 들어가서 (셀레니움으로 들어가서) 그 안에 내용들을 긁는다.
# 셀레니움으로 리뷰 버튼 클릭
# 뷰티풀숩으로 내용 긁기

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup as bsp
import matplotlib
import matplotlib.pyplot as plt
import sqlite3
import re
from datetime import datetime, timedelta,date
import sys
import time
import click
from selenium.webdriver.common.action_chains import ActionChains
import sqlite3

# %% [markdown]
# ### 향수 구찌 페이지 접속

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bsp
from selenium.webdriver.chrome.options import Options

CHROMEDRIVER_PATH = 'C:/asi/project/chromedriver_win32 (3)/chromedriver' # Windows는 chromedriver_78.exe
WINDOW_SIZE = "1920,1080"
chrome_options = Options()
chrome_options.add_argument(f"--window-size={ WINDOW_SIZE }")
chrome_options.add_argument('Content-Type=application/json; charset=utf-8')
driver = webdriver.Chrome( executable_path=CHROMEDRIVER_PATH, chrome_options=chrome_options )
url = ('https://perfumegraphy.com/product/list.html?cate_no=201')
driver.get(url)

#driver = webdriver.Chrome('C:/asi/project/chromedriver_win32 (3)/chromedriver')
#url = ('https://perfumegraphy.com/product/list.html?cate_no=201')
#driver.get(url)
driver.implicitly_wait(3)
html = driver.page_source
src = bsp(html,'html.parser')
# Out:
# <ipython-input-31-1a2aa6ae436e>:10: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome( executable_path=CHROMEDRIVER_PATH, chrome_options=chrome_options )

# %% [markdown]
# ### 향수 url 하나씩 추출

# %%
perurls = src.select('li.xans-record- > div')
for perurl in perurls :
    urls2 = perurl.select('div.prdImg > a')
    print(urls2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-185-ee7efa5caa2f> in <module>
# ----> 1 perurls = src.select('li.xans-record- > div')
#       2 for perurl in perurls :
#       3     urls2 = perurl.select('div.prdImg > a')
#       4     print(urls2)
#
# AttributeError: 'bytes' object has no attribute 'select'

# %%
perurls = src.select('li.xans-record- > div')
#print(perurls)
for perurl in perurls:
    urls2 = perurl.select('div.prdImg > a')[0]
    homepage = urls2['href']
    print(homepage)
    print('#'*100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-184-45a944fbc819> in <module>
# ----> 1 perurls = src.select('li.xans-record- > div')
#       2 #print(perurls)
#       3 for perurl in perurls:
#       4     urls2 = perurl.select('div.prdImg > a')[0]
#       5     homepage = urls2['href']
#
# AttributeError: 'bytes' object has no attribute 'select'

# %% [markdown]
# ### 각 homepage 내용 긁기

# %%
driver = webdriver.Chrome('C:/asi/project/chromedriver_win32 (3)/chromedriver')
##brand_name = 글자 찾기!!!!! 나중에 name_에 replace부분에 brand_name으로 넣기
for perurl in perurls:
    urls = perurl.select('div.prdImg > a')[0]
    homepage ='https://perfumegraphy.com'+ urls['href']+'#review'
    #print(homepage)
    driver.get(homepage)
    time.sleep(3)
    html = driver.page_source
    src = bsp(html,'html.parser')
    name_ = src.select('div.headingArea > h2')[0].text.replace('구찌','').replace('/','').strip()
    name = re.sub('[a-zA-Z0-9]','',name_)
    realname = re.sub('\+.*','',name).strip()
    time.sleep(3)
    print(src)
    print('#'*100)
    print('#'*100)
    print('#'*100)
#     ul_list = src.select('ul.reviews > li.review')
    
#     for ul in ul_list :
#         reviewa = ul.select('a.js-link-expand')
#         print(reviewa)
        #reviewa.click()
    
#     review =
#     age = 
#     gender = 
    
    #print(realname)
#     brand_name = mains.select('p.product-main-info__brand_name')[0].text.strip()
# Out:
# <html lang="ko" xml:lang="ko" xmlns="//www.w3.org/1999/xhtml"><head><script async="" src="https://sdk.bigin.io/v1/bigin.sdk.js"></script><script async="" src="//?v=1617344919719"></script><script async="" src="https://www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/plugins/ua/ec.js" type="text/javascript"></script><script async="" charset="UTF-8" id="crema-jssdk" src="https://assets4.cre.ma/widgets/assets/pc-a203bc81a7260f0c46a4660002fa4a228e85df9b698a07fede5b067f72549260.js"></script><link href="https://assets4.cre.ma/widgets/assets/pc-f68447834ec298d4156fcab650399e5c19d790d844dae7ae60ae80f82aeb0b5c.css" rel="stylesheet" type="text/css"/><script async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://connect.facebook.net/signals/config/493360428344792?v=2.9.33&amp;r=stable"></script><script async="" src="https://connect.facebook.net/signals/config/307140789895227?v=2.9.33&amp;r=stable"></script><script async="" src="https://connect.facebook.net/signals/plugins/identity.js?v=2.9.33"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script async="" id="crema-jssdk" src="//widgets.cre.ma/perfumegraphy.com/init.js"></script><script src="/ind-script/optimizer.php?filename=08_Iz03VNzQq0i8oyk8vSszVLy8v18_MS-EqTi7KLCjRz0oFY57czDyerGIA&amp;type=js&amp;k=f8c449ff82a3977059c3195db755507c2666c339&amp;t=1615919717"></script><script>
# (function(i, s, o, g, r, a, m) {
#     a = s.createElement(o);
#     m = s.getElementsByTagName(o)[0];
#     a.src = g;
#     a.onload = function() {
#         i[r].init('https://js-error-tracer-api.cafe24.com', {"token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..0mzc8XAudgUCUVl_xWtxwJJomXt0wRzOaMdU-gegYSc","collectWindowErrors":true,"preventDuplicateReport":true,"storageKeyPrefix":"EC_JET.PRODUCT_DETAIL"});
#     };
#     m.parentNode.insertBefore(a, m);
# }(window, document, 'script', '/ind-script/optimizer.php?filename=08_Iz03VNzQq0i8oyk8vSszVLy8v18_MS-EqTi7KLCjRz0oFY57czDyerGIA&type=js&k=f8c449ff82a3977059c3195db755507c2666c339&t=1615919717', 'EC_JET'));
# </script><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="telephone=no" name="format-detection"/><!-- PG크로스브라우징필수내용 --><meta content="no-cache" http-equiv="Cache-Control"/><meta content="0" http-equiv="Expires"/><meta content="no-cache" http-equiv="Pragma"/><!-- // PG크로스브라우징필수내용 --><!-- 해당 CSS는 쇼핑몰 전체 페이지에 영향을 줍니다. 삭제와 수정에 주의해주세요. --><link href="https://fonts.googleapis.com/css2?family=Lato:wght@300;400;700&amp;display=swap" rel="stylesheet"/><link href="https://fonts.googleapis.com/css2?family=Noto+Sans+KR:wght@300;400;500&amp;display=swap" rel="stylesheet"/><!-- 스마트디자인에서는 JQuery 1.4.4 버전이 내장되어있습니다. 추가로 호출하면 충돌이 생길 수 있습니다. --><style>.fjx {display:none}</style>
# <!-- Google Shopping -->
# <meta content="R_b3spGgUmEqdLZZ8rznbA3cHmw_falpTi5Jgb-9LHY" name="google-site-verification"/>
# <!-- Google Shopping -->
# <meta content="hbd1vz6zpkjva2wqcci7m7tsxysuhg" name="facebook-domain-verification"/>
# <link href="http://perfumegraphy.com/product/구찌-블룸-오-드-퍼퓸-3050100ml-테스터/1469/" rel="canonical"/>
# <link href="http://m.perfumegraphy.com/product/구찌-블룸-오-드-퍼퓸-3050100ml-테스터/1469/" rel="alternate"/>
# <meta content="http://perfumegraphy.com/product/구찌-블룸-오-드-퍼퓸-3050100ml-테스터/1469/" property="og:url"/>
# <meta content="구찌 블룸 오 드 퍼퓸 30/50/100ml + 테스터" property="og:title"/>
# <meta content="퍼퓸그라피" property="og:site_name"/>
# <meta content="product" property="og:type"/>
# <meta content="https://perfumegraphy.com/web/product/big/202011/7967821af88fc18ca54b7d71848b9616.jpg" property="og:image"/>
# <meta content="75800" property="product:price:amount"/>
# <meta content="KRW" property="product:price:currency"/>
# <meta content="75800" property="product:sale_price:amount"/>
# <meta content="KRW" property="product:sale_price:currency"/>
# <meta content="1469" property="product:productId"/>
# <link href="/web/upload/favicon_20160116195537.ico" rel="shortcut icon"/>
# <script src="/app/Eclog/js/cid.generate.js?vs=a07292b02336ab32ed85247a3041dd00" type="text/javascript"></script>
# <script src="//wcs.naver.net/wcslog.js" type="text/javascript"></script>
# <script type="text/javascript">
#                 var EC_FRONT_EXTERNAL_SCRIPT_VARIABLE_DATA = {"common_member_id_crypt":""};
#             </script>
# <script type="text/javascript">var CAFE24API = { instance : [], MALL_ID : 'pggraphy', SHOP_NO : 1, init : function (appInfo) { if (typeof appInfo == 'object') { if (appInfo.hasOwnProperty('client_id')) { var appKey = appInfo.client_id; } } else { var appKey = appInfo; } if (appKey) { if (!this.instance[appKey]) { CAFE24API.clientId = appKey; if (appInfo.hasOwnProperty('version')) { CAFE24API.version = appInfo.version; } var copyObject = CAFE24API.constructor(); for (var attr in CAFE24API) { if (CAFE24API.hasOwnProperty(attr)) { copyObject[attr] = CAFE24API[attr]; } } this.instance[appKey] = copyObject; } return this.instance[appKey]; } }, initializeXhr : function () { try { return new XMLHttpRequest(); } catch (error) { return new window.ActiveXObject('Microsoft.XMLHTTP'); } }, fullPath: function (url) { var API_PRIVATE_URL = []; for (var i in API_PRIVATE_URL) { var regExp = new RegExp('/api/v2' + API_PRIVATE_URL[i] + '($|[?]|[/]$)'); if (regExp.test(url) == true) { return 'https://' + window.location.hostname + url; } } return url; }, getMemberID: function (callback) { if (!CAPP_ASYNC_METHODS.IS_LOGIN) { callback(null); } else { callback(CAPP_ASYNC_METHODS.AppCommon.getMemberID()); } }, getMemberInfo: function (callback) { callback({'id': CAPP_ASYNC_METHODS.AppCommon.getMemberInfo()}); }, getCustomerIDInfo: function (callback) { if (!CAFE24API.__scopeErr(callback, 'application')) { return; } callback(null, {'id': CAPP_ASYNC_METHODS.AppCommon.getCustomerIDInfo()}); }, getCustomerInfo: function (callback) { if (!CAFE24API.__chkValidSessionScope(callback, 'customer')) { return; } callback(null, {'customer': CAPP_ASYNC_METHODS.AppCommon.getCustomerInfo()}); }, getMileageInfo: function (callback) { if (!CAFE24API.__chkValidSessionScope(callback, 'customer')) { return; } callback(null, {'mileage': CAPP_ASYNC_METHODS.AppCommon.getMileageInfo()}); }, getPointInfo: function (callback) { if (!CAFE24API.__chkValidSessionScope(callback, 'customer')) { return; } callback(null, {'point': CAPP_ASYNC_METHODS.AppCommon.getPointInfo()}); }, getDepositInfo: function (callback) { if (!CAFE24API.__chkValidSessionScope(callback, 'customer')) { return; } callback(null, {'deposit': CAPP_ASYNC_METHODS.AppCommon.getDepositInfo()}); }, getCreditInfo: function (callback) { if (!CAFE24API.__chkValidSessionScope(callback, 'customer')) { return; } callback(null, {'credit': CAPP_ASYNC_METHODS.AppCommon.getCreditInfo()}); }, getCartList: function (callback) { if (!CAFE24API.__chkValidSessionScope(callback, 'personal')) { return; } callback(null, {'carts': CAPP_ASYNC_METHODS.AppCommon.getCartList()}); }, getCartInfo: function (callback) { if (!CAFE24API.__chkValidSessionScope(callback, 'personal')) { return; } callback(null, {'cart': CAPP_ASYNC_METHODS.AppCommon.getCartInfo()}); }, getCartItemList: function (callback) { if (!CAFE24API.__scopeErr(callback, 'order')) { return; } callback(null, {'items': CAPP_ASYNC_METHODS.AppCommon.getCartItemList()}); }, getCartCount: function (callback) { if (!CAFE24API.__chkValidSessionScope(callback, 'personal')) { return; } callback(null, CAPP_ASYNC_METHODS.AppCommon.getCartCount()); }, getCouponCount: function (callback) { if (!CAFE24API.__chkValidSessionScope(callback, 'promotion')) { return; } callback(null, CAPP_ASYNC_METHODS.AppCommon.getCouponCount()); }, getWishCount: function (callback) { if (!CAFE24API.__chkValidSessionScope(callback, 'personal')) { return; } callback(null, CAPP_ASYNC_METHODS.AppCommon.getWishCount()); }, getShopInfo: function (callback) { if (!CAFE24API.__scopeErr(callback, 'store')) { return; } callback(null, {'shop': CAPP_ASYNC_METHODS.AppCommon.getShopInfo()}); }, get : function(url, callback) { return CAFE24API.complete('GET', url, this, null, callback); }, post : function(url, params, callback) { return CAFE24API.complete('POST', url, this, params, callback); }, put : function(url, params, callback) { return CAFE24API.complete('PUT', url, this, params, callback); }, delete : function(url, ca ...
# <script type="text/javascript">
# window.CAFE24 = window.CAFE24 || {};
# var EC_SDE_SHOP_NUM = 1;var SHOP = {getLanguage : function() { return "ko_KR"; },getCurrency : function() { return "KRW"; },getFlagCode : function() { return "KR"; },getTimezone: function() { return "Asia/Seoul" },isMultiShop : function() { return false; },isDefaultShop : function() { return true; },isDefaultLanguageShop : function(sLanguageCode) { return SHOP.isDefaultShop() && SHOP.isLanguageShop(sLanguageCode); },isKR : function() { return true; },isUS : function() { return false; },isJP : function() { return false; },isCN : function() { return false; },isTW : function() { return false; },isES : function() { return false; },isPT : function() { return false; },isVN : function() { return false; },isPH : function() { return false; },getCountryAndLangMap : function() { return {
# "KR": "ko_KR",
# "US": "en_US",
# "JP": "ja_JP",
# "CN": "zh_CN",
# "TW": "zh_TW",
# "VN": "vi_VN",
# "PH": "en_PH"
# }},isLanguageShop : function(sLanguageCode) { return sLanguageCode === "ko_KR"; },getDefaultShopNo : function() { return 1; },getProductVer : function() { return 2; },isSDE : function() { return true; },isMode : function() {return false; },getModeName : function() {return false; },isMobileAdmin : function() {return false; },isExperienceMall : function() { return false; },getAdminID : function() {return ''},getMallID : function() {return 'pggraphy'},getCurrencyFormat : function(sPriceTxt, bIsNumberFormat) {
# sPriceTxt = String(sPriceTxt);
# var aCurrencySymbol = ["","\uc6d0",false];
# if (typeof SHOP_PRICE !== 'undefined' && isNaN(sPriceTxt.replace(/[,]/gi, '')) === false && bIsNumberFormat === true) {
# // bIsNumberFormat 사용하려면 Ui(':libUipackCurrency')->plugin('Currency') 화폐 라이브러리 추가 필요
# sPriceTxt = SHOP_PRICE.toShopPrice(sPriceTxt.replace(/[,]/gi, ''), true, EC_SDE_SHOP_NUM);
# }
# try {
# var sPlusMinusSign = (sPriceTxt.toString()).substr(0, 1);
# if (sPlusMinusSign === '-' || sPlusMinusSign === '+') {
# sPriceTxt = (sPriceTxt.toString()).substr(1);
# return sPlusMinusSign + aCurrencySymbol[0] + sPriceTxt + aCurrencySymbol[1];
# } else {
# return aCurrencySymbol[0] + sPriceTxt + aCurrencySymbol[1];
# }
# } catch (e) {
# return aCurrencySymbol[0] + sPriceTxt + aCurrencySymbol[1];
# }
# }};var EC_COMMON_UTIL = {convertSslForString : function(sString) { return sString.replace(/http:/gi, '');},convertSslForHtml : function(sHtml) { return sHtml.replace(/((?:src|href)\s*=\s*['"])http:(\/\/(?:[a-z0-9\-_\.]+)\/)/ig, '$1$2');},getProtocol : function() { return 'https'; },moveSsl : function() { if (EC_COMMON_UTIL.getProtocol() === 'http') { var oLocation = jQuery(window.location); var sUrl = 'https://' + oLocation.attr('host') + oLocation.attr('pathname') + oLocation.attr('search'); window.location.replace(sUrl); } },setEcCookie : function(sKey, sValue, iExpire) {var exdate = new Date();exdate.setDate(exdate.getDate() + iExpire);var setValue = escape(sValue) + "; domain=." + EC_GLOBAL_INFO.getBaseDomain() + "; path=/;expires=" + exdate.toUTCString();document.cookie = sKey + "=" + setValue;}};var EC_SHOP_LIB_INFO = {getBankInfo : function() {
# var oBankInfo = "";
# $.ajax({
# type: "GET",
# url: "/exec/front/Shop/Bankinfo",
# dataType: "json",
# async: false,
# success: function(oResponse) {
# oBankInfo = oResponse;
# }
# });
# return oBankInfo; }};
# var EC_ROOT_DOMAIN = "cafe24.com";
# var EC_API_DOMAIN = "cafe24api.com";
# var EC_TRANSLATE_LOG_STATUS = "F";
# var EC_GLOBAL_INFO = (function() {
# var oData = {"base_domain":"pggraphy.cafe24.com","root_domain":"cafe24.com","api_domain":"cafe24api.com","is_global":false,"country_code":"KR","language_code":"ko_KR","admin_language_code":"ko_KR"};
# return {
# getBaseDomain: function() {
# return oData['base_domain'];
# },
# getRootDomain: function() {
# return oData['root_domain'];
# },
# getApiDomain: function() {
# return oData['api_domain'];
# },
# isGlobal: function() {
# return oData['is_global'];
# },
# getCountryCode: function() {
# return oData['country_code'];
# },
# getLanguageCode: function() {
# return oData['language_code'];
# },
# getAdminLanguageCode: function() {
# return oData['admin_language_code'];
# }
# };
# })();
# var EC_AVAILABLE_LANGUAGE = ["ko_KR","zh_CN","en_US","zh_TW","es_ES","pt_PT","vi_VN","ja_JP","en_PH"];
# var EC_AVAILABLE_LANGUAGE_CODES = {"ko_KR":"KOR","zh_CN":"CHN","en_US":"ENG","zh_TW":"TWN","es_ES":"ESP","pt_PT":"PRT","vi_VN":"VNM","ja_JP":"JPN","en_PH":"PHL"};
# var EC_GLOBAL_PRODUCT_LANGUAGE_CODES  = {
# sClearanceCategoryCode : '',
# sManualLink : '//serviceguide.cafe24shop.com/ko_KR/PR.PD.GA.html',
# sHsCodePopupLink : 'https://unipass.customs.go.kr/clip/index.do',
# aCustomRegex : '"PHL" : "^[0-9]{8}[A-Z]?$"',
# sCountryCodeData : 'kor',
# sEnglishExampleURlForGlobal : '',
# aReverseAddressCountryCode: ["VNM","PHL"],
# };
# var EC_GLOBAL_ORDER_LANGUAGE_CODES  = {
# aModifyOrderLanguage: {"KR":"ko_KR","JP":"ja_JP","CN":"zh_CN","TW":"zh_TW","VN":"vi_VN","PH":"en_PH"},
# aUseIdCardKeyCountry: ["CN","TW"],
# aLanguageWithCountryCode: {"zh_CN":["CN","CHN","HK","HNK"],"ja_JP":["JP","JPN"],"zh_TW":["TW","TWN"],"ko_KR":["KR","KOR"],"vi_VN":["VN","VNM"],"en_PH":["PH","PHL"]},
# aCheckDisplayRequiredIcon: ["ja_JP","zh_CN","zh_TW","en_US","vi_VN","en_PH"],
# aSetReceiverName: {"zh_CN":{"sCountry":"CN","bUseLastName":true},"zh_TW":{"sCountry":"TW","bUseLastName":false},"ja_JP":{"sCountry":"JP","bUseLastName":true}},
# aSetDeferPaymethodLanguage: {"ja_JP":"\uc77c\ubcf8","zh_CN":"\uc911\uad6d"},
# aUseDeferPaymethod: ["ja_JP","zh_CN"],
# aCheckShippingCompanyAndPaymethod: ["ja_JP","zh_CN"],
# aSetDeferPaymethodLanguageForShipping: {"ja_JP":"\u65e5\u672c","zh_CN":"\uc911\uad6d"},
# aCheckStoreByPaymethod : ["ja_JP","zh_CN"],
# aCheckIsEmailRequiredForJs: ["en_US","zh_CN","zh_TW","ja_JP","vi_VN","en_PH"],
# aSetIdCardKeyCountryLanguage: {"CN":"\uc911\uad6d\uc758","TW":"\ub300\ub9cc\uc758"},
# aReverseGlobalAddress: ["en_PH","vi_VN","PHL","VNM","VN","PH"],
# aNoCheckZipCode: ["KOR","JPN"],
# aNotPostCodeAPICountryList : ["en_US","es_ES","pt_PT","en_PH"],
# aEnableSearchExchangeAddr: ["KR","JP","CN","VN","TW","PH"],
# aDuplicatedBaseAddr : ["TW","JP"],
# aReverseAddressCountryCode: ["VN","PH"],
# aCheckZipCode: ["PHL","en_PH","PH"]
# };
# var EC_GLOBAL_MEMBER_LANGUAGE_CODES  = {
# sAdminWebEditorLanguageCode : 'ko' ,
# oNotAvailDecimalPointLanguages :  ["ko_KR","ja_JP","zh_TW","vi_VN"],
# oAddressCountryCode :  {"KOR":"ko_KR","JPN":"ja_JP","CHN":"zh_CN","TWN":"zh_TW","VNM":"vi_VN","PHL":"en_PH"},
# };
# var EC_GLOBAL_BOARD_LANGUAGE_CODES  = {
# bUseLegacyBoard: true
# };
# var EC_GLOBAL_MALL_LANGUAGE_CODES  = {
# oDesign: {
# oDesignAddReplaceInfo: {"group_id":"SKIN.ADD.ADMIN.DESIGNDETAIL","replacement":{"KR":"KOREAN","US":"ENGLISH","JP":"JAPANESE","CN":"SIMPLIFIED.CHINESE","TW":"TRADITIONAL.CHINESE","ES":"SPANISH","PT":"PORTUGUESE","PH":"ENGLISH"}},
# oDesignDetailLanguageCountryMap: {"KR":"ko_KR","JP":"ja_JP","CN":"zh_CN","TW":"zh_TW","US":"en_US","ES":"es_ES","PT":"pt_PT","PH":"en_PH"},
# oSmartDesignSwitchTipLink: {"edibot":{"img":"\/\/img.echosting.cafe24.com\/smartAdmin\/img\/design\/img_editor_dnd.png","link":"\/\/ecsupport.cafe24.com\/board\/free\/list.html?board_act=list&board_no=12&category_no=9&cate_no=9"},"smart":{"img":"\/\/img.echosting.cafe24.com\/smartAdmin\/img\/design\/ko_KR\/img_editor_smart.png","link":"\/\/sdsupport.cafe24.com"}},
# oSmartDesignDecoShopList: ["ko_KR","ja_JP","zh_CN","en_US","zh_TW","es_ES","pt_PT"],
# oSmartDesignDecoMultilingual: {"list":{"ko_KR":"KOREAN","en_US":"ENGLISH","ja_JP":"JAPANESE","zh_CN":"SIMPLIFIED.CHINESE","zh_TW":"TRADITIONAL.CHINESE","es_ES":"SPANISH","pt_PT":"PORTUGUESE","vi_VN":"VIETNAMESE"},"group_id":"EDITOR.LAYER.EDITING.DECO"},
# aSmartDesignModuleShopList: ["ko_KR","ja_JP","zh_CN","en_US","zh_TW","es_ES","pt_PT"]
# },
# oStore: {
# oMultiShopCurrencyInfo: {"en_US":{"currency":"USD"},"zh_CN":{"currency":"USD","sub_currency":"CNY"},"ja_JP":{"currency":"JPY"},"zh_TW":{"currency":"TWD"},"es_ES":{"currency":"EUR"},"pt_PT":{"currency":"EUR"},"ko_KR":{"currency":"KRW"},"vi_VN":{"currency":"VND"},"en_PH":{"currency":"PHP"}},
# oBrowserRedirectLanguage: {"ko":{"primary":"ko_KR","secondary":"en_US"},"en":{"detail":{"en-ph":{"primary":"en_PH","secondary":"en_US"},"en-us":{"primary":"en_US","secondary":"es_ES"},"default":{"primary":"en_US","secondary":"es_ES"}}},"ja":{"primary":"ja_JP","secondary":"en_US"},"zh":{"detail":{"zh-cn":{"primary":"zh_CN","secondary":"en_US"},"zh-tw":{"primary":"zh_TW","secondary":"zh_CN"},"default":{"primary":"en_US","secondary":"ko_KR"}}},"es":{"primary":"es_ES","secondary":"en_US"},"pt":{"primary":"pt_PT","secondary":"en_US"},"vi":{"primary":"vi_VN","secondary":"en_US"},"default":{"primary":"en_US","secondary":"ko_KR"}},
# aChangeableLanguages: ["vi_VN","en_US","ko_KR"],
# aNoZipCodeLanguage: ["ko_KR","ja_JP"],
# iDomainSettingTreeNo: 162
# },
# oMobile: {
# sSmartWebAppFaqUrl: "https://ecsupport.cafe24.com/board/free/read.html?no=1832&board_no=5&category_no=13&cate_no=13&category_no=13&category_no=13",
# sAmpFaqUrl: "https://ecsupport.cafe24.com/board/free/read.html?no=1864&board_no=5&category_no=13&cate_no=13&category_no=13&category_no=13",
# },
# oPromotion: {
# bQrCodeAvailable: true,
# bSnsMarketingAvailable: true
# },
# oShippingReverseAddressLanguage : ["vi_VN","en_PH"] ,
# getAdminMainLocaleLanguage : function(sSkinLocaleCode) {
# var oLocaleData = [];
# var locale = "";
# var shopLangName = "";
# if (sSkinLocaleCode == "US") {
# locale = "en_US";
# shopLangName = "ENGLISH";
# } else if (sSkinLocaleCode == "JP") {
# locale = "ja_JP";
# shopLangName = "JAPANESE";
# } else if (sSkinLocaleCode == "CN") {
# locale = "zh_CN";
# shopLangName = "SIMPLIFIED.CHINESE";
# } else if (sSkinLocaleCode == "TW") {
# locale = "zh_TW";
# shopLangName = "TRADITIONAL.CHINESE";
# } else if (sSkinLocaleCode == "ES") {
# locale = "es_ES";
# shopLangName = "SPANISH";
# } else if (sSkinLocaleCode == "PT") {
# locale = "pt_PT";
# shopLangName = "PORTUGUESE";
# } else if (sSkinLocaleCode == "VN") {
# locale = "vi_VN";
# shopLangName = "VIETNAMESE";
# } else if(sSkinLocaleCode == "PH") {
# locale = "en_PH";
# shopLangName = "ENGLISH.PH";
# }
# oLocaleData["locale"] = locale;
# oLocaleData["shopLangName"] = shopLangName;
# return  oLocaleData;
# }
# };
# var EC_GLOBAL_DATETIME_INFO = {
# oConstants: {"STANDARD_DATE_REGEX":"\/([12]\\d{3}-(0[1-9]|1[0-2])-(0[1-9]|[12]\\d|3[01]))\/","IN_ZONE":"inZone","OUT_ZONE":"outZone","IN_FORMAT":"inFormat","OUT_FORMAT":"outFormat","IN_DATE_FORMAT":"inDateFormat","IN_TIME_FORMAT":"inTimeFormat","OUT_DATE_FORMAT":"outDateFormat","OUT_TIME_FORMAT":"outTimeFormat","IN_FORMAT_DATE_ONLY":1,"IN_FORMAT_TIME_ONLY":2,"IN_FORMAT_ALL":3,"OUT_FORMAT_DATE_ONLY":1,"OUT_FORMAT_TIME_ONLY":2,"OUT_FORMAT_ALL":3,"DATE_ONLY":"YYYY-MM-DD","TIME_ONLY":"HH:mm:ss","FULL_TIME":"YYYY-MM-DD HH:mm:ss","ISO_8601":"YYYY-MM-DD[T]HH:mm:ssZ","YEAR_ONLY":"YYYY","MONTH_ONLY":"MM","DAY_ONLY":"DD","WEEK_ONLY":"e","TIME_H_I_ONLY":"HH:mm","TIME_HOUR_ONLY":"HH","TIME_MINUTE_ONLY":"mm","POSTGRE_FULL_TIME":"YYYY-MM-DD HH24:MI:SS","POSTGRE_TIME_ONLY":" HH24:MI:SS","MICRO_SECOND_ONLY":"u","SEOUL":"Asia\/Seoul","TOKYO":"Asia\/Tokyo","SHANGHAI":"Asia\/Shanghai","TAIPEI":"Asia\/Taipei","HANOI":"Asia\/Bangkok","LOS_ANGELES":"America\/Los_Angeles","LISBON":"Europe\/Lisbon","MADRID":"Europe\/Madrid","SINGAPORE":"Asia\/Singapore","UTC":"Etc\/UTC","MAX_DATETIME":"9999-12-31 23:59:59"},
# oOptions: {"inZone":"Asia\/Seoul","inFormat":"YYYY-MM-DD HH:mm:ss","inDateFormat":"YYYY-MM-DD","inTimeFormat":"HH:mm:ss","outZone":"Asia\/Seoul","outFormat":"YYYY-MM-DD HH:mm:ss","outDateFormat":"YYYY-MM-DD","outTimeFormat":"HH:mm:ss"},
# oPolicies: {"shop":{"outZone":"Asia\/Seoul","outFormat":"YYYY-MM-DD HH:mm:ss","outDateFormat":"YYYY-MM-DD","outTimeFormat":"HH:mm:ss"}},
# sOverrideTimezone: '',
# sMomentNamespace: 'EC_GLOBAL_MOMENT'
# };
# typeof window.CAFE24 === "undefined" && (window.CAFE24 = {});
# </script>
# <link href="/ind-script/optimizer.php?filename=tZVRTsMwDIbft71yDmtwBCQOwE6QJqY1JHGIE6C3xytMGlRIqE1fIjXy_1n5m_yGgQPC8TZDytxnEyCjcM0WwYrAU-ZYwHIIHA-6cQP_qUe7E_a1EMddxx8LhbWUpU29GTEvkxbTefxDalKC08AJHq8ZDxNDa1y1ZYGyY5PdlQ7tvgpmgdSrNg0jpNp5svuhBA_icO9QqI8gLxTvjhA4Y3wbJ-Lza8U8HsJ9lcLhZDN735m8gn6mBj2ax8sRwWEx5NsyjXN09t-s4epv56qGGiE7NZld3NXEr42WRL18-oG7SltQC7MvlLZAD-g34c5fUju06Smagps4bbotsLMYbEf-kcwtffCbGKxltlFMyjslHRCBYiNg0KUZqnloXRz8PRZX5PZ3j1A1XUQH22mglCj2Z_on&amp;type=css&amp;k=82731639cd419f0443469ed3c4111c110e9c9471&amp;t=1614104930" rel="stylesheet" type="text/css"/>
# <link href="/ind-script/optimizer.php?filename=rc5BDgIhDEDRAzBbz9EYT1RKA2ih2A4m3N5Rb6Cuf_LyoWhjYArT2RxGzoajLBgzSqVQ9ibgiUNir7mD32q_nIHcoWmawiC4dO5A2h8HULUP2o58gq_gMLAnfPsRnf8jfRZ_t6RGQ1twvU-2tTmZikS0l_wE&amp;type=css&amp;k=0e78fbdba287ababf5397acb8392817a4a7eb2f3&amp;t=1600144676" rel="stylesheet" type="text/css"/>
# <style type="text/css">
# #prdDetailContentLazy img[src=""], #prdDetailContentLazy img:not([src]) { visibility: hidden !important; height: 1px !important; }
# </style>
# <title>구찌 블룸 오 드 퍼퓸 Gucci Bloom Eau de Parfum</title>
# <meta content="PRODUCT_DETAIL" name="path_role"/>
# <meta content="퍼퓸그라피 Perfume Graphy" name="author"/>
# <meta content="구찌신상, 패키지만으로도 설레는 4계절 플로럴 향수" name="description"/>
# <meta content="구찌 향수,구찌 블룸,퍼퓸그라피,퍼퓸그라피 구찌,구찌 퍼퓸그라피,구찌 퍼퓸,구찌 여자향수,여자 구찌향수,구찌 블룸 오드퍼퓸,블룸 향수" name="keywords"/>
# <meta content="/product/detail.html" name="design_html_path"/><!--CMC script : tagmanager add - googleads.g.doubleclick.net--><script src="https://www.googletagmanager.com/gtag/js?id=AW-701277965"></script><!--CMC script : tagmanager add - googleads.g.doubleclick.net--><script charset="utf-8" src="https://checkout.naver.com/button/info?callback=nhn.CheckoutButton.jsonp.callback&amp;buttonKey=34D10641-B4CF-49E0-A463-5890B890559A&amp;buttonTypeCode=A_1_2_Y&amp;site_preference=normal" type="text/javascript"></script><script defer="" src="https://cdn.megadata.co.kr/js/socialLink/social_sns_config_min.js" type="text/javascript"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/701277965/?random=1617344919824&amp;cv=9&amp;fst=1617344919824&amp;num=1&amp;bg=ffffff&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;eid=2505059650&amp;u_h=864&amp;u_w=1536&amp;u_ah=824&amp;u_aw=1536&amp;u_cd=24&amp;u_his=2&amp;u_tz=540&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2oa3o0&amp;sendb=1&amp;ig=1&amp;data=event%3Dgtag.config&amp;frm=0&amp;url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&amp;tiba=%EA%B5%AC%EC%B0%8C%20%EB%B8%94%EB%A3%B8%20%EC%98%A4%20%EB%93%9C%20%ED%8D%BC%ED%93%B8%20Gucci%20Bloom%20Eau%20de%20Parfum&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/701277965/?random=1617344919828&amp;cv=9&amp;fst=1617344919828&amp;num=1&amp;bg=ffffff&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;eid=2505059650&amp;u_h=864&amp;u_w=1536&amp;u_ah=824&amp;u_aw=1536&amp;u_cd=24&amp;u_his=2&amp;u_tz=540&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2oa3o0&amp;sendb=1&amp;ig=1&amp;data=event%3Dpage_view%3Becomm_pagetype%3Dproduct%3Becomm_prodid%3D1469%3Becomm_totalvalue%3D75800%3Becomm_category%3DBRAND%20%3E%20%EA%B5%AC%EC%B0%8C&amp;frm=0&amp;url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&amp;tiba=%EA%B5%AC%EC%B0%8C%20%EB%B8%94%EB%A3%B8%20%EC%98%A4%20%EB%93%9C%20%ED%8D%BC%ED%93%B8%20Gucci%20Bloom%20Eau%20de%20Parfum&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script></head><body><div id="wrap">
# <div id="header">
# <div class="h_sec01">
# <div class="add_menu01">
# <!-- 상단 추가 카테고리01 수정하는곳 -->
# <ul><!-- 상단 추가 카테고리01 수정하는곳 --><li><a href="/shopinfo/company.html">#ABOUT US</a></li>
# <li><a href="/board/free/list.html?board_no=5">PARTNERSHIP</a></li>
# <li><a href="/board/product/list.html?board_no=6">Q&amp;A</a></li>
# </ul></div><!-- //add_menu01 -->
# <!-- 상단섹션01 : 상단로고 수정하는곳 -->
# <div class="top_logo"><a href="/"><img src="/morenvyimg/top_logo.png"/></a></div>
# <div class="right_menu">
# <!-- cre.ma / 로그인 회원 정보 / 스크립트를 수정할 경우 연락주세요 (support@cre.ma) -->
# <!-- 상단섹션01 : 로그인메뉴 -->
# <ul class="login"> <li class="xans-element- xans-layout xans-layout-statelogoff "><a href="/member/login.html">로그인</a>
# </li>
# <li class="xans-element- xans-layout xans-layout-statelogoff "><a href="/member/join.html">회원가입</a>
# </li>
# <li><a href="/myshop/order/list.html">주문조회</a></li>
# </ul><!-- //login --><!-- 상단섹션01 : 다국어 메뉴 --><div class="global_menu">
# <span class="ico01"><img src="/morenvyimg/glo_btn01.png"/></span>한국어<span class="ico02"><img src="/morenvyimg/glo_btn02.png"/></span>
# <!-- 해외몰 추가 : 홈 -> 상점관리 -> 멀티쇼핑몰 관리 -> 멀티쇼핑몰 설정 -->
# <!-- 다국어 리스트 -->
# </div><!-- //global_menu -->
# <!-- 상단섹션01 : 장바구니,검색 -->
# <ul class="cart_menu"><li class="top_search"><a href="#none" onclick="openNav()"><img src="/morenvyimg/top_search_w.png"/></a></li>
# <li class="btn_cart"><a href="/order/basket.html"><span class="xans-element- xans-layout xans-layout-orderbasketcount ">0</span>
# <img src="/morenvyimg/top_cart_w.png"/></a></li>
# </ul><!-- //cart_menu --></div><!-- //right_menu -->
# </div><!-- //h_sec01 -->
# <div class="h_sec02 cboth fixed" id="comment_top">
# <div class="inner">
# <div class="top_cate">
# <!-- 상단 카테고리 자동출력 -->
# <div class="gnb_menu_box">
# <!-- 상단 카테고리 수동, 자동출력 -->
# <ul class="top_menu"><div id="mcategory"><!-- 상단 카테고리 자동출력 -->
# <div id="slideCateList">
# <div class="cate_brand">
# <!--
#
# 	※ Designed By PANDASSI ※
#
# 	절대 수정하지 마세요.
# 	판다디자인에만 사용되는 소스입니다.
# 	기본적으로 묶어서 노출되는 파일입니다.
#
# 	||| 모든 저작권은 [ 판다씨 ] 에 있습니다. |||
# 	||| 모든 CSS 파일 및 SCRIPT 파일 무단 도용시 민형사상 책임이 있음을 알려드립니다. |||
# 	||| 공지사항을 확인하시려면, ( http://www.pandassi.com/board/free/list.html?board_no=1 ) |||
# 	||| 디자인 및 소스를 문의하시려면, ( http://www.pandassi.com/board/free/list.html?board_no=1002 ) |||
#
# 	http://www.pandassi.com/
#
# -->
# <!-- 스타일시트 -->
# <!-- 스크립트 -->
# <!-- 추가 스크립트 -->
# <div ajax="outer"><a ajax="true|brand" class="cate" data-ajax="/_panda/_ajax/category_brand.html" data-target="146" href="#none">브랜드별</a></div>
# </div>
# <ul class="categoryList"><!-- 상단 카테고리 수동출력 --><!-- 상단 카테고리 수동출력 --><li class="noChild"><a class="cate" href="/product/list.html?cate_no=186">지금인기</a>
# </li>
# <li class="noChild"><a class="cate" href="/product/list.html?cate_no=327">신상품</a>
# </li>
# <li class="noChild"><a class="cate" href="/product/list.html?cate_no=286">자연적인</a>
# <ul class="slideSubMenu2"><li class="noChild"><a class="nocate" href="/product/list.html?cate_no=294">시트러스</a></li>
# <li class="noChild"><a class="nocate" href="/product/list.html?cate_no=289">우 디</a></li>
# <li class="noChild"><a class="nocate" href="/product/list.html?cate_no=295">플로럴</a></li>
# <li class="noChild"><a class="nocate" href="/product/list.html?cate_no=297">머스크</a></li>
# <li class="noChild"><a class="nocate" href="/product/list.html?cate_no=296">오리엔탈</a></li>
# </ul></li>
# <li class="noChild"><a class="cate" href="/product/list.html?cate_no=287">감각적인</a>
# <ul class="slideSubMenu2"><li class="noChild"><a class="nocate" href="/product/list.html?cate_no=288">우먼 데일리</a></li>
# <li class="noChild"><a class="nocate" href="/product/list.html?cate_no=291">우먼 나이트</a></li>
# <li class="noChild"><a class="nocate" href="/product/list.html?cate_no=292">맨 데일리</a></li>
# <li class="noChild"><a class="nocate" href="/product/list.html?cate_no=293">맨 나이트</a></li>
# </ul></li>
# <li class="noChild"><a class="cate" href="/product/list.html?cate_no=299">스몰럭셔리</a>
# <!--<ul class="slideSubMenu2">
# 		<li class="noChild" id="#"><a href="#" class="nocate">구찌</a></li>
# 	</ul>-->
# </li>
# <li class="noChild"><a class="cate" href="/product/list.html?cate_no=128">센츠하다</a>
# <!--<ul class="slideSubMenu2">
# 		<li class="noChild" id="#"><a href="#" class="nocate">구찌</a></li>
# 	</ul>-->
# </li>
# <li class="noChild"><a class="cate" href="/product/list.html?cate_no=324">디스커버리</a>
# <!--<ul class="slideSubMenu2">
# 		<li class="noChild" id="#"><a href="#" class="nocate">구찌</a></li>
# 	</ul>-->
# </li>
# <li class="noChild"><a class="cate" href="/product/list.html?cate_no=202%22">개인결제창</a>
# </li>
# </ul></div>
# </div><!-- //mcategory -->
# </ul><!-- //top_menu --></div><!-- //gnb_menu_box -->
# <div class="top_add">
# <!-- 상단 추가 카테고리02 수정하는곳 -->
# <!-- 상단 추가 카테고리 수정하는곳 -->
# <ul><li class="top_cate_space"><a href="/board/gallery/list.html?board_no=8">매거진</a></li>
# <li><a href="/board/product/list.html?board_no=2">이벤트</a></li>
# </ul></div><!-- //top_add -->
# </div><!-- //top_cate -->
# </div><!-- //inner -->
# <br/><br/><!-- 상단섹션02 : 핫키워드 --><div class="hot_keyword">
# <div class="swiper-container swiper_hot swiper-container-vertical">
# <div class="swiper-wrapper" style="transition-duration: 0ms; transform: translate3d(0px, -20px, 0px);"><div class="swiper-slide swiper-slide-duplicate swiper-slide-prev" data-swiper-slide-index="9" style="height: 20px;">
# <a href="/product/search.html?banner_action=&amp;keyword=%EB%9E%84%ED%94%84%EB%A1%9C%EB%A0%8C">
# <span class="key1">HOT KEYWORD</span>
# <span class="key2">10</span>
# <span class="key3">랄프로렌</span>
# </a>
# </div>
# <!-- 상단 핫키워드 수정하는 곳 -->
# <!-- 핫키워드 01 수정 -->
# <div class="swiper-slide swiper-slide-active" data-swiper-slide-index="0" style="height: 20px;">
# <a href="/product/search.html?banner_action=&amp;keyword=%EC%94%A8%ED%9D%90%20%ED%8A%B8%EB%A3%A8%EB%8F%99">
# <span class="key1">HOT KEYWORD</span>
# <span class="key2">1</span>
# <span class="key3">씨흐 트루동</span>
# </a>
# </div>
# <!-- 핫키워드 02 수정 -->
# <div class="swiper-slide swiper-slide-next" data-swiper-slide-index="1" style="height: 20px;">
# <a href="/product/search.html?banner_action=&amp;keyword=%EB%A9%94%EC%A2%85%20%ED%94%84%EB%9E%80%EC%8B%9C%EC%8A%A4%20%EC%BB%A4%EC%A0%95">
# <span class="key1">HOT KEYWORD</span>
# <span class="key2">2</span>
# <span class="key3">메종 프란시스 커정</span>
# </a>
# </div>
# <!-- 핫키워드 03 수정 -->
# <div class="swiper-slide" data-swiper-slide-index="2" style="height: 20px;">
# <a href="/product/search.html?banner_action=&amp;keyword=%EC%84%B8%EB%A5%B4%EC%A3%BC%EB%A3%A8%ED%85%90">
# <span class="key1">HOT KEYWORD</span>
# <span class="key2">3</span>
# <span class="key3">세르주루텐</span>
# </a>
# </div>
# <!-- 핫키워드 04 수정 -->
# <div class="swiper-slide" data-swiper-slide-index="3" style="height: 20px;">
# <a href="/product/search.html?banner_action=&amp;keyword=%EB%94%A5%EB%94%94%ED%81%AC">
# <span class="key1">HOT KEYWORD</span>
# <span class="key2">4</span>
# <span class="key3">딥디크</span>
# </a>
# </div>
# <!-- 핫키워드 05 수정 -->
# <div class="swiper-slide" data-swiper-slide-index="4" style="height: 20px;">
# <a href="/product/search.html?banner_action=&amp;keyword=%EC%97%90%EB%A5%B4%EB%A9%94%EC%8A%A4">
# <span class="key1">HOT KEYWORD</span>
# <span class="key2">5</span>
# <span class="key3">에르메스</span>
# </a>
# </div>
# <!-- 핫키워드 06 수정 -->
# <div class="swiper-slide" data-swiper-slide-index="5" style="height: 20px;">
# <a href="/product/search.html?banner_action=&amp;keyword=%EC%95%84%EC%9D%B4%EC%A0%A0%EB%B2%84%EA%B7%B8">
# <span class="key1">HOT KEYWORD</span>
# <span class="key2">6</span>
# <span class="key3">아이젠버그</span>
# </a>
# </div>
# <!-- 핫키워드 07 수정 -->
# <div class="swiper-slide" data-swiper-slide-index="6" style="height: 20px;">
# <a href="/product/search.html?banner_action=&amp;keyword=%EC%95%84%ED%8B%80%EB%A6%AC%EC%97%90%20%EC%BD%94%EB%A1%B1">
# <span class="key1">HOT KEYWORD</span>
# <span class="key2">7</span>
# <span class="key3">아틀리에 코롱</span>
# </a></div>
# <!-- 핫키워드 08 수정 -->
# <div class="swiper-slide" data-swiper-slide-index="7" style="height: 20px;">
# <a href="/product/search.html?banner_action=&amp;keyword=%EC%A1%B0%EB%A7%90%EB%A1%A0">
# <span class="key1">HOT KEYWORD</span>
# <span class="key2">8</span>
# <span class="key3">조말론</span>
# </a>
# </div>
# <!-- 핫키워드 09 수정 -->
# <div class="swiper-slide" data-swiper-slide-index="8" style="height: 20px;">
# <a href="/product/search.html?banner_action=&amp;keyword=%EB%B6%88%EB%A6%AC">
# <span class="key1">HOT KEYWORD</span>
# <span class="key2">9</span>
# <span class="key3">불리</span>
# </a>
# </div>
# <!-- 핫키워드 10 수정 -->
# <div class="swiper-slide swiper-slide-duplicate-prev" data-swiper-slide-index="9" style="height: 20px;">
# <a href="/product/search.html?banner_action=&amp;keyword=%EB%9E%84%ED%94%84%EB%A1%9C%EB%A0%8C">
# <span class="key1">HOT KEYWORD</span>
# <span class="key2">10</span>
# <span class="key3">랄프로렌</span>
# </a>
# </div>
# <div class="swiper-slide swiper-slide-duplicate swiper-slide-duplicate-active" data-swiper-slide-index="0" style="height: 20px;">
# <a href="/product/search.html?banner_action=&amp;keyword=%EC%94%A8%ED%9D%90%20%ED%8A%B8%EB%A3%A8%EB%8F%99">
# <span class="key1">HOT KEYWORD</span>
# <span class="key2">1</span>
# <span class="key3">씨흐 트루동</span>
# </a>
# </div></div>
# <span aria-atomic="true" aria-live="assertive" class="swiper-notification"></span></div>
# </div>
# <div class="slide_search" id="mySearch">
# <a class="closebtn" href="javascript:void(0)" onclick="closeNav()"><img src="/morenvyimg/search_close.png"/></a>
# <div class="search_inner">
# <form action="/product/search.html" enctype="multipart/form-data" id="searchBarForm" method="get" name="" target="_self">
# <input id="banner_action" name="banner_action" type="hidden" value=""/><div class="xans-element- xans-layout xans-layout-searchheader "><!--
# 					$product_page=/product/detail.html
# 					$category_page=/product/list.html
# 					-->
# <!-- 상단 검색창 홍보문구 수정하는 곳 -->
# <!-- 상단 검색창 홍보문구 수정하는 곳 -->
# <fieldset title="검색어를 입력해주세요."> <input class="inputTypeText" fw-filter="" fw-label="검색어" fw-msg="" id="keyword" name="keyword" onmousedown="SEARCH_BANNER.clickSearchForm(this)" placeholder="" type="text" value=""/> <input alt="검색이미지" class="btn-sch" onclick="SEARCH_BANNER.submitSearchBanner(this); return false;" src="/morenvyimg/top_search.png" type="image"/>
# </fieldset>
# </div>
# </form>
# <div class="xans-element- xans-search xans-search-hotkeyword search_pop"><!-- 인기검색어 : 홈 -> 운영관리 -> 상품검색 설정 -> 인기검색어 설정 -->
# <div class="search_title">인기 검색어</div>
# <div class="search_pop_sub">
# <a class="xans-record-" href="/product/search.html?keyword=금주의 향수">#금주의 향수</a>
# <a class="xans-record-" href="/product/search.html?keyword=럭셔리집들이선물">#럭셔리집들이선물</a><a class="xans-record-" href="/product/search.html?keyword=희소성있는해외전용">#희소성있는해외전용</a><a class="xans-record-" href="/product/search.html?keyword=비누향수">#비누향수</a><a class="xans-record-" href="/product/search.html?keyword=하이엔드라인">#하이엔드라인</a><a class="xans-record-" href="/product/search.html?keyword=퍼퓸그라피단독">#퍼퓸그라피단독</a> </div>
# </div>
# <!-- //search_pop -->
# </div><!-- //search_inner -->
# </div><!-- //slide_search -->
# </div><!-- //comment_top -->
# <div id="dimmedSlider"></div></div><!-- //header -->
# <div id="banner" style="top: 2449px;"></div>
# <div id="quick"></div>
# <div id="container">
# <div id="contents">
# <!--
#     $category_page = /product/list.html
#     $project_page = /product/project.html
#     $jointbuy_page = /product/jointbuy.html
# -->
# <style>
#  #container #contents { width:1240px !important; }
#  #container { min-width:0; }
# </style>
# <div class="xans-element- xans-product xans-product-headcategory path detail_path "><span>현재 위치</span>
# <ol>
# <li><a href="/">홈</a></li>
# <li class=""><a href="/category/brand/146/">BRAND</a></li>
# <li class=""><a href="/category/구찌/201/">구찌</a></li>
# <li class="displaynone"><a href=""></a></li>
# <li class="displaynone"><strong><a href=""></a></strong></li>
# </ol>
# </div>
# <div class="xans-element- xans-product xans-product-detail"><!--
# 		$coupon_download_page = /coupon/coupon_productdetail.html
#     -->
# <div class="detailArea ">
# <div class="xans-element- xans-product xans-product-image imgArea"><div class="keyImg ">
# <div class="thumbnail">
# <a alt="P0000CEM" href="/product/image_zoom2.html?product_no=1469&amp;cate_no=201&amp;display_group=1" onclick="window.open(this.href, 'image_zoom2', 'toolbar=no,scrollbars=auto,resizable=yes,width=450,height=693,left=0,top=0', this);return false;">
# <img alt="구찌 블룸" class="BigImage " src="//perfumegraphy.com/web/product/big/202011/7967821af88fc18ca54b7d71848b9616.jpg"/> <span id="zoomMouseGiude" style="display:block; position:relative; width:170px; margin:0 auto;"><img alt="마우스를 올려보세요." id="zoomGuideImage" src="//img.echosting.cafe24.com/design/skin/admin/ko_KR/txt_product_zoom.gif" style="position: absolute; top: -27px; right: 0px;"/></span></a>
# <div id="zoom_wrap"><p class="image_zoom_large" style="display: none;"><span class="image_zoom_large_relative"><img alt="확대 이미지" id="zoom_image" src="//perfumegraphy.com/web/product/big/202011/7967821af88fc18ca54b7d71848b9616.jpg" style="width: 1080px; height: 1080px;"/></span></p></div>
# </div>
# </div>
# <div class="xans-element- xans-product xans-product-addimage listImg cboth"><ul>
# <li class="xans-record-"><img alt="" class="ThumbImage" src="//perfumegraphy.com/web/product/small/202011/e83108a7787e6ea408950bb00965024c.jpg"/></li>
# </ul>
# </div>
# <div class="control displaynone ">
# <a class="btnZoom" href="/product/image_zoom2.html?product_no=1469&amp;cate_no=201&amp;display_group=1" onclick="window.open(this.href, 'image_zoom2', 'toolbar=no,scrollbars=auto,resizable=yes,width=560,height=710,left=0,top=0', this);return false;"><img alt="" src="//img.echosting.cafe24.com/skin/base/common/btn_icon_zoom.gif"/> 확대보기</a>
# </div>
# <div class="color displaynone">
# </div>
# </div>
# <div class="infoArea">
# <div class="headingArea">
# <h2>구찌 블룸 오 드 퍼퓸 30/50/100ml + 테스터</h2>
# <div class="cboth summary_desc"></div>
# <span class="delivery displaynone">(해외배송 가능상품)</span>
# <!-- 공급사 바로가기버튼 영역 -->
# <div class="supply displaynone">
# <span></span>
# <a href="#none" onclick=""><img alt="공급사 바로가기" src=""/></a>
# </div>
# <!-- //공급사 바로가기버튼 영역 -->
# <div class="salebox">
# <div id="sale_bg" style="display: block;"><span class="sale_text">28%</span></div>
# <span class="displaynone hidden_pcustom">105000.00</span>
# <span class="displaynone hidden_pprice">75800</span>
# </div>
# <!-- //salebox -->
# </div>
# <div class="xans-element- xans-product xans-product-detaildesign"><!--
#                     출력 갯수 지정 변수, 없으면 설정된 전체가 나옵니다.
#                     count = 10
#                 -->
# <table border="1" summary="">
# <caption> 기본 정보</caption>
# <tbody>
# <tr class=" xans-record-" rel="상품명">
# <th scope="row"><span style="font-size:11px;color:#222222;">상품명</span></th>
# <td><span style="font-size:11px;color:#222222;">구찌 블룸 오 드 퍼퓸 30/50/100ml + 테스터</span></td>
# </tr>
# <tr class=" xans-record-" rel="소비자가">
# <th scope="row"><span style="font-size:11px;color:#222222;">소비자가</span></th>
# <td><span style="font-size:11px;color:#222222;"><span id="span_product_price_custom"><strike>105,000원</strike></span></span></td>
# </tr>
# <tr class=" xans-record-" rel="판매가">
# <th scope="row"><span style="font-size:11px;color:#222222;">판매가</span></th>
# <td><span style="font-size:11px;color:#222222;"><strong id="span_product_price_text">75,800원</strong><input id="product_price" name="product_price" type="hidden" value=""/> <a href="#none" id="btn_restock" name="btn_restock" onclick="alert('로그인 후 이용가능합니다.');" sms_restock_login_display=""><img alt="재입고 알림 SMS" src="//img.echosting.cafe24.com/design/skin/default/product/btn_sms.gif"/></a></span></td>
# </tr>
# <tr class=" xans-record-" rel="적립금">
# <th scope="row"><span style="font-size:11px;color:#222222;">적립금</span></th>
# <td><span style="font-size:11px;color:#222222;"><span id="span_mileage_text">379원 (0.50%)</span></span></td>
# </tr>
# <tr class=" xans-record-" rel="배송비">
# <th scope="row"><span style="font-size:12px;color:#555555;">배송비</span></th>
# <td><span style="font-size:12px;color:#555555;"><span class="delv_price_B"><input id="delivery_cost_prepaid" name="delivery_cost_prepaid" type="hidden" value="P"/><strong>2,500원</strong> (97,000원 이상 구매 시 무료)</span></span></td>
# </tr>
# </tbody>
# </table>
# </div>
# <table border="1" summary="">
# <caption>SNS 상품홍보</caption>
# <tbody><tr class="">
# <th scope="row">SNS 상품홍보</th>
# <td class="social"><img alt="" onclick="SnsLinkAction('facebook',1469);" src="/web/upload/38498354256988d6797ee2.gif"/> <img alt="" onclick="SnsLinkAction('twitter',1469);" src="/web/upload/65295468756988d6797e2f.gif"/> <ul class="xans-element- xans-product xans-product-customsns xans-record-"><li></li>
# </ul>
# </td>
# </tr></tbody>
# </table>
# <!-- 정기 결재 추가 내용--><div class="regularDelivery displaynone">
# <div class="head">
# <strong class="title">구매방법</strong>
# <label class="gLabel"> 1회구매</label>
# <label class="gLabel"> 정기배송</label>
# </div>
# <div class="shippingCycle displaynone" id="">
# <p class="title">배송주기</p>
# <div class="xans-element- xans-product xans-product-regularperiod button"><label class="gLabel "><span class="txt"></span></label></div>
# </div>
# </div>
# <!-- 정기 결재 추가 내용 끝 -->
# <p class="displaynone"><img alt="개인결제창을 통한 결제 시 네이버 마일리지 적립 및 사용이 가능합니다." src="//img.echosting.cafe24.com/skin/base_ko_KR/product/txt_naver.gif"/></p>
# <table border="1" class="xans-element- xans-product xans-product-option xans-record-" summary=""><caption>상품 옵션</caption>
# <tbody></tbody><tbody class="xans-element- xans-product xans-product-option xans-record-"><tr>
# <th scope="row">용량</th>
# <td><select class="ProductOption0" id="product_option_id1" item_listing_type="C" name="option1" option_product_no="1469" option_select_element="ec-option-select-finder" option_sort_no="1" option_style="select" option_title="용량" option_type="T" product_option_area="product_option_1469_0" product_type="product_option" required="true"><option link_image="" selected="" value="*">- [필수] 옵션을 선택해 주세요 -</option><option disabled="" link_image="" value="**">-------------------</option><optgroup label="용량"><option link_image="" value="P0000CEM00BE">30ml</option><option link_image="" value="P0000CEM00BF">30ml_프로푸모 디 피오리 (+11,700원)</option><option link_image="" value="P0000CEM00BC">50ml [품절]  (+29,000원)</option><option link_image="" value="P0000CEM00BD">100ml (+65,000원)</option></optgroup></select><p class="value"></p>
# </td>
# </tr></tbody>
# <tbody>
# <tr class="displaynone" id="">
# <td class="selectButton" colspan="2"><a class="btnSubmit sizeS" href="#none" onclick="">옵션선택</a></td>
# </tr></tbody>
# </table>
# <div class="guideArea">
# <p class="info ">(최소주문수량 1개 이상<span class="displaynone"> / 최대주문수량 0개 이하</span>)</p>
# <span class="sizeGuide displaynone"><a class="size_guide_info" href="#none" product_no="1469">사이즈 가이드</a></span>
# </div>
# <div class="xans-element- xans-product xans-product-addproduct productSet additional"><div class="title">
# <h3>추가구성상품 <span>추가로 구매를 원하시면 선택하세요.</span>
# </h3>
# <a class="toggle" href="#self"><img alt="추가구성상품 닫기" src="//img.echosting.cafe24.com/skin/base/product/btn_additional_close.gif"/></a>
# </div>
# <ul class="product">
# <li class="xans-record-">
# <div class="information">
# <div class="thumbnail"><a href="/product/선택-쇼핑백/1707/"><img alt="" id="ec-add-product-composed-product-1707" src="//perfumegraphy.com/web/product/tiny/201907/21281dcf7a297fb3d716940ad71437ac.jpg"/></a></div>
# <p class="name" title="상품명"><strong>(선택) 쇼핑백</strong></p>
# <p class="price " title="판매가"><strong class="">2,800원</strong></p>
# <p class="salePrice displaynone" title="할인판매가"></p>
# </div>
# <ul class="option"> <li class="xans-element- xans-product xans-product-option xans-record-"><ul>
# <li>
# <strong class="name">쇼핑백</strong>
# <select id="addproduct_option_id_1707_1" item_listing_type="S" name="addproduct_option_name_1707" option_product_no="1707" option_select_element="ec-option-select-finder" option_sort_no="1" option_style="select" option_title="쇼핑백" option_type="T" product_option_area="addproduct_option_1707" product_type="addproduct_option" required="true"><option link_image="" selected="" value="*">- [필수] 옵션을 선택해 주세요 -</option><option disabled="" link_image="" value="**">-------------------</option><option link_image="" value="구찌 쇼핑백">구찌 쇼핑백</option></select><p class="value"></p>
# </li>
# </ul>
# </li>
# <li class="displaynone selectButton" id="">
# <a class="btnSubmit sizeS" href="#none" onclick="">옵션선택</a>
# </li>
# </ul>
# </li>
# <li class="xans-record-">
# <div class="information">
# <div class="thumbnail"><a href="/product/선택-쇼핑백-선물포장/1945/"><img alt="" id="ec-add-product-composed-product-1945" src="//perfumegraphy.com/web/product/tiny/201907/21281dcf7a297fb3d716940ad71437ac.jpg"/></a></div>
# <p class="name" title="상품명"><strong>(선택) 쇼핑백 &amp; 선물포장</strong></p>
# <p class="price " title="판매가"><strong class="">5,000원</strong></p>
# <p class="salePrice displaynone" title="할인판매가"></p>
# </div>
# <ul class="option"> <li class="xans-element- xans-product xans-product-option xans-record-"><ul>
# <li>
# <strong class="name">쇼핑백 및 선물포장</strong>
# <select id="addproduct_option_id_1945_1" item_listing_type="S" name="addproduct_option_name_1945" option_product_no="1945" option_select_element="ec-option-select-finder" option_sort_no="1" option_style="select" option_title="쇼핑백 및 선물포장" option_type="T" product_option_area="addproduct_option_1945" product_type="addproduct_option" required="true"><option link_image="" selected="" value="*">- [필수] 옵션을 선택해 주세요 -</option><option disabled="" link_image="" value="**">-------------------</option><option link_image="" value="구찌 쇼핑백 + 남성 선물포장">구찌 쇼핑백 + 남성 선물포장</option><option link_image="" value="구찌 쇼핑백 + 여성 선물포장">구찌 쇼핑백 + 여성 선물포장</option></select><p class="value"></p>
# </li>
# </ul>
# </li>
# <li class="displaynone selectButton" id="">
# <a class="btnSubmit sizeS" href="#none" onclick="">옵션선택</a>
# </li>
# </ul>
# </li>
# <li class="xans-record-">
# <div class="information">
# <div class="thumbnail"><a href="/product/선택-수동분사형-공병/1687/"><img alt="" id="ec-add-product-composed-product-1687" src="//perfumegraphy.com/web/product/tiny/201907/b1fa2a3050334feb190f3228f21a8b57.jpg"/></a></div>
# <p class="name" title="상품명"><strong>(선택) 수동분사형 공병</strong></p>
# <p class="price " title="판매가"><strong class="">2,500원</strong></p>
# <p class="salePrice displaynone" title="할인판매가"></p>
# </div>
# <ul class="option"> <li class="xans-element- xans-product xans-product-option xans-record-"><ul>
# <li>
# <strong class="name">추가 공병</strong>
# <select id="addproduct_option_id_1687_1" item_listing_type="S" name="addproduct_option_name_1687" option_product_no="1687" option_select_element="ec-option-select-finder" option_sort_no="1" option_style="select" option_title="추가 공병" option_type="T" product_option_area="addproduct_option_1687" product_type="addproduct_option" required="true"><option link_image="" selected="" value="*">- [필수] 옵션을 선택해 주세요 -</option><option disabled="" link_image="" value="**">-------------------</option><option link_image="" value="모던블랙 (+2500원)">모던블랙 (+2500원)</option><option link_image="" value="펄베이지 (+2500원)">펄베이지 (+2500원)</option><option link_image="" value="화이트실버 (+2500원)">화이트실버 (+2500원)</option><option link_image="" value="파스텔핑크 (+2500원)">파스텔핑크 (+2500원)</option></select><p class="value"></p>
# </li>
# </ul>
# </li>
# <li class="displaynone selectButton" id="">
# <a class="btnSubmit sizeS" href="#none" onclick="">옵션선택</a>
# </li>
# </ul>
# </li>
# <li class="xans-record-">
# <div class="information">
# <div class="thumbnail"><a href="/product/선택-자동충전형-공병/1950/"><img alt="" id="ec-add-product-composed-product-1950" src="//perfumegraphy.com/web/product/tiny/202010/43f22dd4dc2ad20854ef67c27ca165b1.jpg"/></a></div>
# <p class="name" title="상품명"><strong>(선택) 자동충전형 공병</strong></p>
# <p class="price " title="판매가"><strong class="">9,900원</strong></p>
# <p class="salePrice displaynone" title="할인판매가"></p>
# </div>
# <ul class="option"> <li class="xans-element- xans-product xans-product-option xans-record-"><ul>
# <li>
# <strong class="name">추가 공병</strong>
# ...
# var mileage_val = '369';var mileage_generate_calc = '369';
# var basket_type = 'A0000';var product_name = '구찌 길티 블랙 뿌르옴므 오 드 뚜왈렛 50/90ml';var product_max_type = 'F';var has_option = 'T';var mileage_icon = '//img.echosting.cafe24.com/design/skin/admin/ko_KR/ico_product_point.gif';var mileage_icon_alt = '적립금';var price_unit_head = '';var price_unit_tail = '원';var option_push_button = 'F';var product_image_tiny = '201902/61fa35fe3524bcfac0de5bc61a41974d.jpg';var is_adult_product = 'F';var is_individual_buy = 'F';var is_soldout_icon = 'F';var link_product_detail = '/product/구찌-길티-블랙-뿌르옴므-오-드-뚜왈렛-5090ml/1560/display/1/';var sIsNonmemberLimit = 'F';
# var product_min = '1';var order_limit_type = 'O';
# var product_max = '-1';
# var buy_unit_type = 'O';var buy_unit = '1';
# var product_price = '73800';var product_price_content = '';var is_selling_price = 'S';var product_price_mobile = '73800';var mobile_dc_price = '';var isMobileDcStatus = 'F';var product_price_ref = '';var currency_disp_type = 'P';
# var delvtype = 'A';
# $.data(document,'SameImage','F');
# var _iPrdtPriceOrg = 67091;
# var _iPrdtPriceTax = 6709;
# var qrcode_class = 'EC_Qrcode6066b9db18dd3';
# var sSocialUrl="/exec/front/Product/Social/";
# var sIsMileageDisplay = 'T';
# if (typeof EC_SHOP_FRONT_NEW_OPTION_COMMON !== "undefined") {EC_SHOP_FRONT_NEW_OPTION_COMMON.initObject();}
# if (typeof EC_SHOP_FRONT_NEW_OPTION_BIND !== "undefined") {EC_SHOP_FRONT_NEW_OPTION_BIND.initChooseBox();}
# if (typeof EC_SHOP_FRONT_NEW_OPTION_DATA !== "undefined") {EC_SHOP_FRONT_NEW_OPTION_DATA.initData();}
# var sMileageUnit = '[:PRICE:]원';
# var sIsDisplayNonmemberPrice = "F";
# var sNonmemberPrice = '-';
# var _iPrdtPriceOrg = 67091;
# var _iPrdtPriceTax = 6709;
# var option_type = 'T';var option_name_mapper = '용량';var option_stock_data = '{\"P0000CHZ000F\":{\"stock_price\":\"0.00\",\"use_stock\":false,\"use_soldout\":\"F\",\"is_display\":\"T\",\"is_selling\":\"T\",\"option_price\":73800,\"option_name\":\"\\uc6a9\\ub7c9\",\"option_value\":\"50ml\",\"stock_number\":78,\"option_value_orginal\":[\"50ml\"],\"use_stock_original\":\"T\",\"use_soldout_original\":\"F\",\"use_soldout_today_delivery\":\"F\",\"is_auto_soldout\":\"F\",\"is_mandatory\":\"T\",\"option_id\":\"000F\",\"is_reserve_stat\":\"N\",\"item_image_file\":null,\"origin_option_added_price\":\"0.00\"},\"P0000CHZ000G\":{\"stock_price\":\"25000.00\",\"use_stock\":false,\"use_soldout\":\"F\",\"is_display\":\"T\",\"is_selling\":\"T\",\"option_price\":98800,\"option_name\":\"\\uc6a9\\ub7c9\",\"option_value\":\"90ml\",\"stock_number\":0,\"option_value_orginal\":[\"90ml\"],\"use_stock_original\":\"T\",\"use_soldout_original\":\"F\",\"use_soldout_today_delivery\":\"F\",\"is_auto_soldout\":\"F\",\"is_mandatory\":\"T\",\"option_id\":\"000G\",\"is_reserve_stat\":\"N\",\"item_image_file\":null,\"origin_option_added_price\":\"25000.00\"}}';var stock_manage = '1';var item_count = '2';var item_listing_type = 'C';var product_option_price_display = 'T';
# var add_option_name = '';
# var bIsDisplaySoldoutOption =true;
# var aSoldoutDisplay = {"1560":"\ud488\uc808","1950":"\ud488\uc808"};
# var bIsDisplaySoldoutOption =true;
# var aSoldoutDisplay = {"1560":"\ud488\uc808","1950":"\ud488\uc808","1945":"\ud488\uc808"};
# var bIsDisplaySoldoutOption =true;
# var aSoldoutDisplay = {"1560":"\ud488\uc808","1950":"\ud488\uc808","1945":"\ud488\uc808","1707":"\ud488\uc808"};
# var bIsDisplaySoldoutOption =true;
# var aSoldoutDisplay = {"1560":"\ud488\uc808","1950":"\ud488\uc808","1945":"\ud488\uc808","1707":"\ud488\uc808","1687":"\ud488\uc808"};
# var set_option = {"setproduct_require":"setproduct_require","setproduct_option":"setproduct_option","setproduct_add_option":"setproduct_add_option","addproduct_option":"addproduct_option","addproduct_add_option":"addproduct_add_option","code_setproduct":"setproduct","code_addproduct":"addproduct"};
# var add_option_data = '{\"1707\":{\"product_name\":\"(\\uc120\\ud0dd) \\uc1fc\\ud551\\ubc31\",\"has_option\":\"T\",\"quantity\":null,\"product_code\":\"P0000CNR\",\"option_type\":\"T\",\"option_stock_data\":\"{\\\"P0000CNR000A\\\":{\\\"stock_price\\\":\\\"0.00\\\",\\\"use_stock\\\":false,\\\"use_soldout\\\":\\\"F\\\",\\\"is_display\\\":\\\"T\\\",\\\"is_selling\\\":\\\"T\\\",\\\"option_price\\\":2800,\\\"option_name\\\":\\\"\\\\uc1fc\\\\ud551\\\\ubc31\\\",\\\"option_value\\\":\\\"\\\\uad6c\\\\ucc0c \\\\uc1fc\\\\ud551\\\\ubc31\\\",\\\"stock_number\\\":0,\\\"option_value_orginal\\\":[\\\"\\\\uad6c\\\\ucc0c \\\\uc1fc\\\\ud551\\\\ubc31\\\"],\\\"use_stock_original\\\":\\\"T\\\",\\\"use_soldout_original\\\":\\\"F\\\",\\\"use_soldout_today_delivery\\\":\\\"F\\\",\\\"is_auto_soldout\\\":\\\"F\\\",\\\"is_mandatory\\\":\\\"T\\\",\\\"option_id\\\":\\\"000A\\\",\\\"is_reserve_stat\\\":\\\"N\\\",\\\"item_image_file\\\":null,\\\"origin_option_added_price\\\":\\\"0.00\\\"}}\",\"stock_manage\":false,\"option_value_mapper_array\":[[\"\\uad6c\\ucc0c \\uc1fc\\ud551\\ubc31\",\"P0000CNR000A\"]],\"option_value_mapper\":\"{\\\"\\\\uad6c\\\\ucc0c \\\\uc1fc\\\\ud551\\\\ubc31\\\":\\\"P0000CNR000A\\\"}\",\"is_soldout\":false,\"is_display\":true,\"buy_unit\":1,\"product_min\":1,\"product_max\":0,\"product_max_type\":\"F\",\"mileage_val\":14,\"product_price\":\"2800.00\",\"product_sale_price\":2800,\"main_cate_no\":0,\"display_group\":1,\"item_listing_type\":\"S\",\"item_type\":\"addproduct\",\"product_option_price_display\":\"T\",\"product_price_type\":false,\"product_price_content\":\"\",\"buy_unit_type\":\"O\",\"order_limit_type\":\"O\",\"origin_product_price\":null,\"origin_product_sale_price\":null,\"item_count\":1,\"enable_purchase\":true},\"1945\":{\"product_name\":\"(\\uc120\\ud0dd) \\uc1fc\\ud551\\ubc31 & \\uc120\\ubb3c\\ud3ec\\uc7a5\",\"has_option\":\"T\",\"quantity\":null,\"product_code\":\"P0000CWV\",\"option_type\":\"T\",\"option_stock_data\":\"{\\\"P0000CWV000A\\\":{\\\"stock_price\\\":\\\"0.00\\\",\\\"use_stock\\\":false,\\\"use_soldout\\\":\\\"F\\\",\\\"is_display\\\":\\\"T\\\",\\\"is_selling\\\":\\\"T\\\",\\\"option_price\\\":5000,\\\"option_name\\\":\\\"\\\\uc1fc\\\\ud551\\\\ubc31 \\\\ubc0f \\\\uc120\\\\ubb3c\\\\ud3ec\\\\uc7a5\\\",\\\"option_value\\\":\\\"\\\\uad6c\\\\ucc0c \\\\uc1fc\\\\ud551\\\\ubc31 + \\\\ub0a8\\\\uc131 \\\\uc120\\\\ubb3c\\\\ud3ec\\\\uc7a5\\\",\\\"stock_number\\\":0,\\\"option_value_orginal\\\":[\\\"\\\\uad6c\\\\ucc0c \\\\uc1fc\\\\ud551\\\\ubc31 + \\\\ub0a8\\\\uc131 \\\\uc120\\\\ubb3c\\\\ud3ec\\\\uc7a5\\\"],\\\"use_stock_original\\\":\\\"T\\\",\\\"use_soldout_original\\\":\\\"F\\\",\\\"use_soldout_today_delivery\\\":\\\"F\\\",\\\"is_auto_soldout\\\":\\\"F\\\",\\\"is_mandatory\\\":\\\"T\\\",\\\"option_id\\\":\\\"000A\\\",\\\"is_reserve_stat\\\":\\\"N\\\",\\\"item_image_file\\\":null,\\\"origin_option_added_price\\\":\\\"0.00\\\"},\\\"P0000CWV000B\\\":{\\\"stock_price\\\":\\\"0.00\\\",\\\"use_stock\\\":false,\\\"use_soldout\\\":\\\"F\\\",\\\"is_display\\\":\\\"T\\\",\\\"is_selling\\\":\\\"T\\\",\\\"option_price\\\":5000,\\\"option_name\\\":\\\"\\\\uc1fc\\\\ud551\\\\ubc31 \\\\ubc0f \\\\uc120\\\\ubb3c\\\\ud3ec\\\\uc7a5\\\",\\\"option_value\\\":\\\"\\\\uad6c\\\\ucc0c \\\\uc1fc\\\\ud551\\\\ubc31 + \\\\uc5ec\\\\uc131 \\\\uc120\\\\ubb3c\\\\ud3ec\\\\uc7a5\\\",\\\"stock_number\\\":0,\\\"option_value_orginal\\\":[\\\"\\\\uad6c\\\\ucc0c \\\\uc1fc\\\\ud551\\\\ubc31 + \\\\uc5ec\\\\uc131 \\\\uc120\\\\ubb3c\\\\ud3ec\\\\uc7a5\\\"],\\\"use_stock_original\\\":\\\"T\\\",\\\"use_soldout_original\\\":\\\"F\\\",\\\"use_soldout_today_delivery\\\":\\\"F\\\",\\\"is_auto_soldout\\\":\\\"F\\\",\\\"is_mandatory\\\":\\\"T\\\",\\\"option_id\\\":\\\"000B\\\",\\\"is_reserve_stat\\\":\\\"N\\\",\\\"item_image_file\\\":null,\\\"origin_option_added_price\\\":\\\"0.00\\\"}}\",\"stock_manage\":false,\"option_value_mapper_array\":[[\"\\uad6c\\ucc0c \\uc1fc\\ud551\\ubc31 + \\ub0a8\\uc131 \\uc120\\ubb3c\\ud3ec\\uc7a5\",\"P0000CWV000A\"],[\"\\uad6c\\ucc0c \\uc1f ...
# var _isProc = "T";
# var is_order_page = "N";
# nhn.CheckoutButton.apply({
# EMBED_ID: "NaverChk_Button",
# BUTTON_KEY:"34D10641-B4CF-49E0-A463-5890B890559A",
# TYPE: "A",
# COLOR: "1",
# COUNT: "2",
# ENABLE: "Y",
# BUY_BUTTON_HANDLER:nv_add_basket_1_product,
# WISHLIST_BUTTON_HANDLER:nv_add_basket_2_product,
# "":""
# });
# $(document).ready(function()
# {
# var oOptionSelectLayer = parent.document.getElementById("capp-shop-new-product-optionselect-layer");
# if (oOptionSelectLayer) {
# $(oOptionSelectLayer).height($(oOptionSelectLayer).height() + 88);
# }
# });
# var iProductNo = '1560';var iCategoryNo = '201';var iDisplayGroup = '1';var option_msg = '필수 옵션을 선택해 주세요.';var sLoginURL = 'login.html';var bPrdOptLayer = '';var sOptionType = 'T';
# $(function() { EC_FRONT_NEW_PRODUCT_LAZYLOAD.resetDetailContent();});
# $(function() { EC_FRONT_NEW_PRODUCT_LAZYLOAD.resetDetailContent();});
# var aSoldoutDisplay = {"1560":"\ud488\uc808","1950":"\ud488\uc808","1945":"\ud488\uc808","1707":"\ud488\uc808","1687":"\ud488\uc808","1614":"\ud488\uc808"};
# var aSoldoutDisplay = {"1560":"\ud488\uc808","1950":"\ud488\uc808","1945":"\ud488\uc808","1707":"\ud488\uc808","1687":"\ud488\uc808","1614":"\ud488\uc808","1679":"\ud488\uc808"};
# var aSoldoutDisplay = {"1560":"\ud488\uc808","1950":"\ud488\uc808","1945":"\ud488\uc808","1707":"\ud488\uc808","1687":"\ud488\uc808","1614":"\ud488\uc808","1679":"\ud488\uc808","1700":"\ud488\uc808"};
# var aSoldoutDisplay = {"1560":"\ud488\uc808","1950":"\ud488\uc808","1945":"\ud488\uc808","1707":"\ud488\uc808","1687":"\ud488\uc808","1614":"\ud488\uc808","1679":"\ud488\uc808","1700":"\ud488\uc808","1908":"\ud488\uc808"};
# var aSoldoutDisplay = {"1560":"\ud488\uc808","1950":"\ud488\uc808","1945":"\ud488\uc808","1707":"\ud488\uc808","1687":"\ud488\uc808","1614":"\ud488\uc808","1679":"\ud488\uc808","1700":"\ud488\uc808","1908":"\ud488\uc808","1556":"\ud488\uc808"};
# var relation_product = '{\"1614\":{\"buy_unit\":1,\"product_min\":1,\"product_max\":0},\"1679\":{\"buy_unit\":1,\"product_min\":1,\"product_max\":0},\"1700\":{\"buy_unit\":1,\"product_min\":1,\"product_max\":0},\"1908\":{\"buy_unit\":1,\"product_min\":1,\"product_max\":0},\"1556\":{\"buy_unit\":1,\"product_min\":1,\"product_max\":0}}';
# EC$(function() {
# var record = EC$('.xans-record-', '.xans-product-review').first();
# if (record.length < 1 || record.is(':not(:visible)')) {
# EC$('.xans-product-reviewpaging').remove();
# }
# });
# EC$('.xans-product-qna a').each(function(e) {
# var sHrefNoReg = /no=[0-9]{1,}/g;
# var sHrefSpreadReg = /spread_flag=T/g;
# var sHref = EC$(this).attr('href');
# var obj = EC$(this);
# if (sHref != undefined && sHrefNoReg.test(sHref) && sHrefSpreadReg.test(sHref)) {
# setTimeout(function() { QNA.getReadData(obj, 'spread') });
# }
# });
# EC$(function() {
# var record = EC$('.xans-record-', '.xans-product-qna').first();
# if (record.length < 1 || record.is(':not(:visible)')) {
# EC$('.xans-product-qnapaging').remove();
# }
# });
# var aLogData = {"log_server1":"eclog2-200.cafe24.com","log_server2":"eclog2-200.cafe24.com","mid":"pggraphy","stype":"e","domain":"","shop_no":"1","lang":"ko_KR","ver":2,"ca":"","etc":""};
# var sMileageName = '적립금';
# var sMileageUnit = '[:PRICE:]원';
# var sDepositName = '예치금';
# var sDepositUnit = '원';
# var EC_ASYNC_LIVELINKON_ID = '';
# if (EC$('[async_section=before]').length > 0) {
# EC$('[async_section=before]').addClass('displaynone');
# }
# var EC_APPSCRIPT_ASSIGN_DATA = EC_APPSCRIPT_ASSIGN_DATA || [{'src':'https://widgets.cre.ma/cafe24/init.js?vs=20200914114921.1', 'integrity': ''},{'src':'https://server.k8sprd.bigin.io/api/cafe24?projectId=PHVZDA5J2H-C&vs=20201130121759.1', 'integrity': ''}];
# var EC_APPSCRIPT_SDK_DATA = EC_APPSCRIPT_SDK_DATA || ['application','category','community','customer','mileage','order','personal','privacy','product','promotion','store','supply','collection'];
# var EC_FRONT_JS_CONFIG_MANAGE = {"sSmartBannerScriptUrl":"https:\/\/app4you.cafe24.com\/SmartBanner\/tunnel\/scriptTags?vs=1563164396689206","sMallId":"pggraphy","sDefaultAppDomain":"https:\/\/app4you.cafe24.com","sWebLogOffFlag":"F","FW_MANIFEST_CACHE_REVISION":2103311209,"IS_WEB_VIEW":"F"};
# var EC_FRONT_JS_CONFIG_MEMBER = {"sAuthUrl":"https:\/\/i-pin.cafe24.com\/certify\/1.0\/?action=auth"};
# var EC_FRONT_JS_CONFIG_SHOP = {"bDirectBuyOrderForm":false,"bECUseItemSalePrice":false,"sCouponDownloadPage":"\/coupon\/coupon_productdetail.html","aOptionColorchip":[]};
# </script>
# <div id="modalBackpanel"></div><div id="modalContainer">
# <iframe frameborder="0" id="modalContent" scroll="0" scrolling="no"></iframe>
# </div><div id="image_zoom_small" style="width: 250px; height: 250px; display: none;"></div><iframe id="log_realtime" src="/exec/front/eclog/main/?&amp;rloc=https%3A//perfumegraphy.com/product/%25EA%25B5%25AC%25EC%25B0%258C-%25EA%25B8%25B8%25ED%258B%25B0-%25EB%25B8%2594%25EB%259E%2599-%25EB%25BF%258C%25EB%25A5%25B4%25EC%2598%25B4%25EB%25AF%2580-%25EC%2598%25A4-%25EB%2593%259C-%25EB%259A%259C%25EC%2599%2588%25EB%25A0%259B-5090ml/1560/category/201/display/1/%23review&amp;rref=&amp;udim=1536*864&amp;rserv=eclog2-200.cafe24.com&amp;cid=CID221349edef4bcbceee8a3876b40504a4&amp;role_path=PRODUCT_DETAIL&amp;stype=e&amp;shop_no=1&amp;lang=ko_KR&amp;ver=2" style="display: none;"></iframe><script src="https://eclog2-200.cafe24.com/weblog.html?uid=pggraphy&amp;udim=1536*864&amp;uref=&amp;uname=pggraphy&amp;url=https://perfumegraphy.com/product/%EA%B5%AC%EC%B0%8C-%EA%B8%B8%ED%8B%B0-%EB%B8%94%EB%9E%99-%EB%BF%8C%EB%A5%B4%EC%98%B4%EB%AF%80-%EC%98%A4-%EB%93%9C-%EB%9A%9C%EC%99%88%EB%A0%9B-5090ml/1560/category/201/display/1/#review&amp;r_ref=&amp;shop_no=1&amp;t=1617344988995"></script><script id="log_script" src="//eclog2-200.cafe24.com/weblog.js?uid=pggraphy&amp;uname=pggraphy&amp;r_ref=&amp;shop_no=1&amp;t=1617344988995" type="text/javascript"></script><script id="bigdata_log" src="/exec/front/External/Save?referer=&amp;href=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EA%25B8%25B8%25ED%258B%25B0-%25EB%25B8%2594%25EB%259E%2599-%25EB%25BF%258C%25EB%25A5%25B4%25EC%2598%25B4%25EB%25AF%2580-%25EC%2598%25A4-%25EB%2593%259C-%25EB%259A%259C%25EC%2599%2588%25EB%25A0%259B-5090ml%2F1560%2Fcategory%2F201%2Fdisplay%2F1%2F%23review" type="text/javascript"></script><script src="https://server.k8sprd.bigin.io/api/cafe24?projectId=PHVZDA5J2H-C&amp;vs=20201130121759.1"></script><script src="https://widgets.cre.ma/cafe24/init.js?vs=20200914114921.1"></script></body></html>
# 길티 블랙 뿌르옴므 오 드 뚜왈렛
# ---------------------------------------------------------------------------
# UnexpectedAlertPresentException           Traceback (most recent call last)
# <ipython-input-36-1663def1b66b> in <module>
#       7     driver.get(homepage)
#       8     time.sleep(3)
# ----> 9     html = driver.page_source
#      10     src = bsp(html,'html.parser')
#      11     name_ = src.select('div.headingArea > h2')[0].text.replace('구찌','').replace('/','').strip()
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     239             elif 'alert' in value:
#     240                 alert_text = value['alert'].get('text')
# --> 241             raise exception_class(message, screen, stacktrace, alert_text)
#     242         raise exception_class(message, screen, stacktrace)
#     243
#
# UnexpectedAlertPresentException: Alert Text: 로그인이 필요한 서비스입니다. 로그인 하시겠습니까?
# Message: unexpected alert open: {Alert text : 로그인이 필요한 서비스입니다. 로그인 하시겠습니까?}
#   (Session info: chrome=89.0.4389.114)

# %%
for perurl in perurls:
    urls = perurl.select('div.prdImg > a')[0]
    homepage ='https://perfumegraphy.com'+ urls['href']+'#review'
print(homepage)
# Out:
# https://perfumegraphy.com/product/구찌-플로라-글로리어스-만다린-50100ml/1573/category/201/display/1/#review

# %%
driver = webdriver.Chrome('C:/asi/project/chromedriver_win32 (3)/chromedriver')
##brand_name = 글자 찾기!!!!! 나중에 name_에 replace부분에 brand_name으로 넣기
homepage ='http://review4.cre.ma/perfumegraphy.com/products/reviews?product_code=1469&iframe_id=crema-product-reviews-1&widget_id=32&widget_style=&app=0&parent_url=http%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2F&nonmember_token=&secure_device_token=V27fe46a9beacd9408382a8c33619aac056623c68ae3238745492068dceac51019&iframe=1'
#print(homepage)
driver.get(homepage)
time.sleep(3)
html = driver.page_source
src = bsp(html,'html.parser')
# name_ = src.select('div.headingArea > h2')[0].text.replace('구찌','').replace('/','').strip()
# name = re.sub('[a-zA-Z0-9]','',name_)
# realname = re.sub('\+.*','',name).strip()
# time.sleep(3)
print(src)
print('#'*100)
print('#'*100)
print('#'*100)
#     ul_list = src.select('ul.reviews > li.review')
    
#     for ul in ul_list :
#         reviewa = ul.select('a.js-link-expand')
#         print(reviewa)
        #reviewa.click()
    
#     review =
#     age = 
#     gender = 
    
    #print(realname)
#     brand_name = mains.select('p.product-main-info__brand_name')[0].text.strip()
# Out:
# <html class=" js flexbox canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers no-applicationcache svg inlinesvg smil svgclippaths placeholder cssfilters svgfilters"><head>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>상세 - 게시판 위젯</title>
# <!--[if lt IE 9]>
#       <script src="//assets4.cre.ma/m/widgets/javascripts/html5shiv-printshiv.js"></script>
#     <![endif]-->
# <link href="http://assets4.cre.ma/latte/assets/pc/application-e80bebdbb10689db26174193d1ba83882103a15f59e6de14810923df4c823f20.css" media="all" rel="stylesheet"/>
# <style type="text/css">
#       span.star, span.camera, .sprite_comment {
#         background-image: url(//assets4.cre.ma/p/perfumegraphy-com/brand_settings/00/00/00/00/01/sprite/5d68222c69c580b5.png);
#       }
#
#       .mall-link-color {
#         color: #cccccc;
#       }
#
#       .review_comment_color {
#         color: #6db67e;
#       }
#     </style>
# <style type="text/css">/* 갤러리 위젯에서 레이아웃이 깨지는 문제 수정 */
# .photo_review_thumbnail__review_title,
# .photo_review_thumbnail__author_name {
#   min-height: 19px;
# }
# </style>
# <script async="" src="http://www.google-analytics.com/plugins/ua/ecommerce.js" type="text/javascript"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script>
#       function fimg(id, w, h) {
#         var img = document.getElementById(id);
#         if(img && !img.complete) {
#           var width = img.width || img.offsetWidth;
#           img.style.height = Math.round(img.width / w * h) + "px";
#           img.onload = function() {
#             this.style.height = "";
#           }
#         }
#       }
#     </script>
# </head>
# <body class="unknown unknown-89 windows_os products reviews ko-KR " data-action="reviews" data-brand-code="perfumegraphy.com" data-controller="products" data-default-translate-button-status="on" data-device="pc" data-enable-nonmember-evaluation="true" data-facebook-app-id="339825122890117" data-facebook-sdk-version="v2.9" data-fixed-top-menu-height="0" data-gaq-account="UA-45818307-9" data-iframe-id="crema-product-reviews-1" data-is-logged-in="false" data-is-refreshable="true" data-loader-url="//assets4.cre.ma/m/widgets/loader.gif" data-login-alert="로그인이 필요한 서비스입니다. 로그인 하시겠습니까?" data-mall-login-url="http://perfumegraphy.com/member/login.html" data-no-popstate="false" data-parent-url="http://perfumegraphy.com/product/%EA%B5%AC%EC%B0%8C-%EB%B8%94%EB%A3%B8-%EC%98%A4-%EB%93%9C-%ED%8D%BC%ED%93%B8-3050100ml-%ED%85%8C%EC%8A%A4%ED%84%B0/1469/" data-rails-env="production" data-review-message-all-collapsed="false" data-review-message-all-exposed="false" data-shop-builder="cafe24" data-widget-id="32" data-widget-renewed="false" lang="ko-KR">
# <div id="crema-google-translate"></div>
# <div class="watermark">
# </div>
# <div data-app-restrict-image-upload="파일 업로드를 하려면 모바일 기본브라우저에서 쇼핑몰 모바일웹(%{url})으로 접속해주세요." data-close="닫기" data-error-403="접근 권한이 없습니다." data-error-404="요청하신 페이지를 찾을 수 없습니다." data-error-422="요청이 거부되었습니다." data-error-etc="요청을 처리하던 중 오류가 발생했습니다. 조속히 해결하겠습니다." data-image-field-cant-add-photo-with-file-name="이미지 형식의 파일만 첨부할 수 있습니다. (선택된 파일명:%{file_name})" data-image-field-cant-add-photo-with-file-type="선택된 파일이 이미지 형식이 아닙니다. (선택된 형식:%{file_type})" data-image-field-cant-add-photo-without-file="선택된 파일이 없어 사진을 추가할 수 없습니다." data-image-field-cant-add-photo-without-file-input="파일 선택창이 없어 사진을 추가할 수 없습니다." data-image-field-cant-add-photo-without-file-reader="파일 미리 보기가 지원되는 브라우저가 아니어서 사진을 추가할 수 없습니다." data-image-size-too-large="첨부한 이미지 파일이 너무 큽니다. 더 작은 이미지를 첨부해주세요." data-input-prompt="값을 입력해주세요." data-require-update-app="원활한 사진첨부를 위해서 앱 업데이트가 필요합니다. 업데이트 하시겠습니까?" data-review-already-largest-image="현재 이미지가 원본 크기입니다." data-review-already-posted="이미 리뷰를 작성한 상품입니다." id="i18n" style="display: none"></div>
# <div id="content">
# <div class="products_reviews_board">
# <div class="products_reviews_form ">
# <div class="products_reviews_form__head">
# <div class="products_reviews_form__title js-translate-review-message">
# <strong>REVIEW</strong><span class="divider">|</span><span class="weak">문의글 혹은 악의적인 비방글은 무통보 삭제된다는 점 유의해주세요^^</span>
# </div>
# <div class="products_reviews_form__button js-link-iframe" data-url="http://perfumegraphy.com/board/product/list.html?board_no=4">후기게시판</div>
# </div>
# <div class="products_reviews_form__body">
# <form accept-charset="UTF-8" action="/perfumegraphy.com/products/post?widget_env=100&amp;widget_id=32" autocomplete="off" class="review_form js-form-review review_form--new_review " data-alert-requirement="false" data-auto-mileage-use-valid-review-message-length="false" data-client-side-validations='{"html_settings":{"type":"ActionView::Helpers::FormBuilder","input_tag":"\u003cspan id=\"input_tag\"\u003e\u003c/span\u003e\u003cdiv class=\"field_with_errors\"\u003e\u003clabel for=\"\" class=\"message\"\u003e\u003c/label\u003e\u003c/div\u003e","label_tag":"\u003clabel id=\"label_tag\"\u003e\u003c/label\u003e\u003cdiv class=\"field_with_errors\"\u003e\u003clabel for=\"\" class=\"message\"\u003e\u003c/label\u003e\u003c/div\u003e"},"number_format":{"separator":".","delimiter":","},"validators":{"review[message]":{"presence":[{"message":"리뷰 메시지를 입력해주세요."}],"length":[{"messages":{"minimum":"2000자 이하로 작성해주세요.","maximum":"2000자 이하로 작성해주세요."},"minimum":1,"maximum":2000}],"profanity":[{"message":true}]},"review[score]":{"numericality":[{"messages":{"numericality":"평점을 선택해주세요.","greater_than_or_equal_to":"Score는 1과 같거나 그보다 커야 합니다.","less_than_or_equal_to":"Score는 5와 같거나 그보다 작아야 합니다."},"greater_than_or_equal_to":1,"less_than_or_equal_to":5}]}}}' data-confirm-review-message="" data-disable-save-requirement="false" data-login-required="true" data-not-creatable-reason="비회원은 리뷰를 작성할 수 없습니다." data-remote="true" data-review-message-default="" data-valid-message-length-api-url="/perfumegraphy.com/api/v1/reviews/valid_message_length?widget_env=100" enctype="multipart/form-data" id="new_review" method="post" novalidate="novalidate"><input name="utf8" type="hidden" value="✓"/>
# <input id="thumbnail_summary" name="thumbnail_summary" type="hidden"/>
# <div class="review_form__message_field js-limit-count-container ">
# <div class="review_form__option_fields">
# <div class="review_option_fields">
# <div class="review_option_field">
# <input id="review_options_attributes_0_id" name="review[options_attributes][0][id]" type="hidden"/>
# <input id="review_options_attributes_0_review_option_type_id" name="review[options_attributes][0][review_option_type_id]" type="hidden" value="1"/>
# <div class="review_option_field__title" title="연령대">
#             연령대
# </div> <div class="review_option_field__content">
# <div class="select2-container review_option_field__value review_option_field__value--select2 select2" id="s2id_review_options_attributes_0_value"><a class="select2-choice" href="javascript:void(0)" tabindex="-1"> <span class="select2-chosen" id="select2-chosen-1">-연령대 선택-</span><abbr class="select2-search-choice-close"></abbr> <span class="select2-arrow" role="presentation"><b role="presentation"></b></span><span class="sprites-icon-drop-down select2__dropdown_icon"></span></a><label class="select2-offscreen" for="s2id_autogen1"></label><input aria-haspopup="true" aria-labelledby="select2-chosen-1" class="select2-focusser select2-offscreen" id="s2id_autogen1" role="button" type="text"/><div class="select2-drop select2-display-none"> <div class="select2-search select2-search-hidden select2-offscreen"> <label class="select2-offscreen" for="s2id_autogen1_search"></label> <input aria-autocomplete="list" aria-expanded="true" aria-owns="select2-results-1" autocapitalize="off" autocomplete="off" autocorrect="off" class="select2-input" id="s2id_autogen1_search" placeholder="" role="combobox" spellcheck="false" type="text"/> </div> <ul class="select2-results" id="select2-results-1" role="listbox"> </ul></div></div><select class="review_option_field__value review_option_field__value--select2 select2 select2-offscreen" data-message="연령대를 입력해주세요." id="review_options_attributes_0_value" name="review[options_attributes][0][value]" tabindex="-1" title=""><option value="">-연령대 선택-</option>
# <option value="10대">10대</option>
# <option value="20대">20대</option>
# <option value="30대">30대</option>
# <option value="40대 이상">40대 이상</option></select>
# </div>
# </div>
# <div class="review_option_field">
# <input id="review_options_attributes_1_id" name="review[options_attributes][1][id]" type="hidden"/>
# <input id="review_options_attributes_1_review_option_type_id" name="review[options_attributes][1][review_option_type_id]" type="hidden" value="4"/>
# <div class="review_option_field__title" title="성별">
#             성별
# </div> <div class="review_option_field__content">
# <div class="select2-container review_option_field__value review_option_field__value--select2 select2" id="s2id_review_options_attributes_1_value"><a class="select2-choice" href="javascript:void(0)" tabindex="-1"> <span class="select2-chosen" id="select2-chosen-2">-성별 선택-</span><abbr class="select2-search-choice-close"></abbr> <span class="select2-arrow" role="presentation"><b role="presentation"></b></span><span class="sprites-icon-drop-down select2__dropdown_icon"></span></a><label class="select2-offscreen" for="s2id_autogen2"></label><input aria-haspopup="true" aria-labelledby="select2-chosen-2" class="select2-focusser select2-offscreen" id="s2id_autogen2" role="button" type="text"/><div class="select2-drop select2-display-none"> <div class="select2-search select2-search-hidden select2-offscreen"> <label class="select2-offscreen" for="s2id_autogen2_search"></label> <input aria-autocomplete="list" aria-expanded="true" aria-owns="select2-results-2" autocapitalize="off" autocomplete="off" autocorrect="off" class="select2-input" id="s2id_autogen2_search" placeholder="" role="combobox" spellcheck="false" type="text"/> </div> <ul class="select2-results" id="select2-results-2" role="listbox"> </ul></div></div><select class="review_option_field__value review_option_field__value--select2 select2 select2-offscreen" data-message="성별을 입력해주세요." id="review_options_attributes_1_value" name="review[options_attributes][1][value]" tabindex="-1" title=""><option value="">-성별 선택-</option>
# <option value="남">남</option>
# <option value="여">여</option></select>
# </div>
# </div>
# </div>
# </div>
# <textarea class="review_form__message js-input-block autogrow js-review-form-count-limit js-new-review-form" cols="5000" data-login-required="true" data-minimum-message-length="5" data-minimum-message-length-error="5자 보다 길게 써야 합니다." data-minimum-message-length-warning="글자수를 5자 이상 작성하셔야만 적립금이 지급됩니다. 그래도 제출하시겠습니까?" data-up-counter="true" id="review_message" maxlength="2000" name="review[message]" placeholder=""></textarea>
# <div class="js-limit-counter review_form__limit_counter">0</div>
# <div class=" review_form__input_photos js-review-input-photos ">
# <div class="review_form__review_photos">
# <ul class="image_fields_container js-image-fields" data-images-count="0" data-limit-images-count-warning="사진 및 동영상은 합하여 최대 %{max_count}개까지 선택할 수 있으므로 선택한 사진 중 %{count}개만 첨부합니다." data-max-images-count="4" data-max-images-count-warning="리뷰 사진은 최대 4장까지 첨부가능합니다.">
# <li class="image_field js-image-field">
# <div class="image_field__wrap">
# <img alt="" class="image_field__size_support" src="//assets4.cre.ma/m/widgets/transparent.png"/>
# <div class="image_field__input_image_container js-image-field-input-image-container on-list">
# <span class="image_field__sprites_icon_camera sprites-icon-camera inline"></span>
# <div class="image_field__add_image_caption">사진 추가</div>
# </div>
# <input accept="image/*" class="image_field__input_file js-input-file" data-upload-image-url="https://review4.cre.ma/perfumegraphy.com/preview_images/upload?widget_env=100" multiple="multiple" name="review[images][]" type="file"/>
# <div class="image_field__preview_container js-image-field-preview-container hidden">
# <img alt="preview" class="image_field__preview js-image-field-preview" src="//assets4.cre.ma/m/widgets/transparent.png"/>
# <div class="image_field__remove_preview js-remove-preview">
# <div class="image_field__remove_preview_text remove">삭제</div>
# </div>
# </div> </div>
# </li>
# </ul>
# </div>
# </div></div> <div class="review_form__submit_container">
# <div class="review_form__add_image_container js-add-image-container" style="cursor: pointer;">
# <span class="review_form__add_image_icon sprites-icon-camera-black"></span>
# <div class="review_form__add_image_description" data-org-text="+ 사진추가">+ 사진추가</div>
# </div>
# <div class="review_form__score">
# <div class="select2-container review_form__select_rating select_rating" id="s2id_review_score"><a class="select2-choice" href="javascript:void(0)" tabindex="-1"> <span class="select2-chosen" id="select2-chosen-3"><div class="item"><span class="star"></span><span class="star"></span><span class="star"></span><span class="star"></span><span class="star"></span><span class="text">아주 좋아요</span></div></span><abbr class="select2-search-choice-close"></abbr> <span class="select2-arrow" role="presentation"><b role="presentation"></b></span><span class="sprites-icon-drop-down select2__dropdown_icon"></span></a><label class="select2-offscreen" for="s2id_autogen3"></label><input aria-haspopup="true" aria-labelledby="select2-chosen-3" class="select2-focusser select2-offscreen" id="s2id_autogen3" role="button" type="text"/><div class="select2-drop select2-display-none review_form__select_rating_drop"> <div class="select2-search select2-search-hidden select2-offscreen"> <label class="select2-offscreen" for="s2id_autogen3_search"></label> <input aria-autocomplete="list" aria-expanded="true" aria-owns="select2-results-3" autocapitalize="off" autocomplete="off" autocorrect="off" class="select2-input" id="s2id_autogen3_search" placeholder="" role="combobox" spellcheck="false" type="text"/> </div> <ul class="select2-results" id="select2-results-3" role="listbox"> </ul></div></div><select class="review_form__select_rating select_rating select2-offscreen" data-dropdown-css-class="review_form__select_rating_drop" id="review_score" name="review[score]" tabindex="-1" title=""><option selected="selected" value="5">아주 좋아요</option>
# <option value="4">맘에 들어요</option>
# <option value="3">보통이에요</option>
# <option value="2">그냥 그래요</option>
# <option value="1">별로에요</option></select>
# </div>
# <input id="review_product_id" name="review[product_id]" type="hidden" value="161"/>
# <input id="review_review_source" name="review[review_source]" type="hidden" value="24"/>
# <input id="review_social_media_type" name="review[social_media_type]" type="hidden" value="0"/>
# <input id="review_sub_order_id" name="review[sub_order_id]" type="hidden"/>
# <input id="review_position" name="review[position]" type="hidden"/>
# <button class="review_form__submit js-review-form-submit" data-disable-with="저장 중..." type="button">
# <span class="review_form__submit_title_icon fa fa-check-circle-o"></span>
# <span class="review_form__post_review_label">리뷰 등록하기</span>
# </button>
# </div>
# <script id="new-image-field" type="text/x-jquery-tmpl">
#     <li class="image_field js-image-field">
#   <div class="image_field__wrap">
#     <img class="image_field__size_support" alt="" src="//assets4.cre.ma/m/widgets/transparent.png" />
#     <div class="image_field__input_image_container js-image-field-input-image-container on-list">
#       <span class="image_field__sprites_icon_camera sprites-icon-camera inline"></span>
#       <div class="image_field__add_image_caption">사진 추가</div>
#     </div>
#       <input type="file" name="review[images][]" class="image_field__input_file js-input-file" accept="image/*" multiple="multiple" data-upload-image-url="https://review4.cre.ma/perfumegraphy.com/preview_images/upload?widget_env=100" />
#       <div class="image_field__preview_container js-image-field-preview-container hidden">
#         <img class="image_field__preview js-image-field-preview" alt="preview" src="//assets4.cre.ma/m/widgets/transparent.png" />
#         <div class="image_field__remove_preview js-remove-preview">
#           <div class="image_field__remove_preview_text remove">삭제</div>
#         </div>
#       </div>
#   </div>
# </li>
#
#   </script>
# </form>
# </div>
# </div>
# <div class="products_reviews_summary products_reviews_summary--small_with_score " data-url="/perfumegraphy.com/products/reviews?app=0&amp;atarget=reviews&amp;iframe=1&amp;iframe_id=crema-product-reviews-1&amp;parent_url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&amp;product_code=1469&amp;secure_device_token=V281c8ef9fe71647c61b7e5908c3e2cd131479b904aa9876805c46f46e9cb0b841&amp;widget_env=100&amp;widget_id=32&amp;widget_style=">
# <div class="products_reviews_summary__inner">
# <div class="products_reviews_summary__lcontent">
# <div class="score_summary score_summary--board">
# <div class="score_summary__body">
# <div class="score_summary__avg_score">
# <div class="score_summary__average">4.8</div>
# <div class="score_summary__reviews_count">281개 리뷰 평점</div>
# </div>
# <ul class="score_summary__score_filters">
# <li class="score_summary__score_filter " data-score="5">
# <a class="js-link-score">
# <div class="score_summary__score_filter__title">5 Stars</div>
# <div class="score_summary__score_filter__status">
# <div class="score_summary__score_filter__count">(243)</div>
# <div class="score_summary__score_filter__check sprites-check"></div>
# </div>
# <div class="score_summary__score_filter__gauge">
# <div class="percentile" style="width: 86%"></div>
# </div>
# </a>
# </li>
# <li class="score_summary__score_filter " data-score="4">
# <a class="js-link-score">
# <div class="score_summary__score_filter__title">4 Stars</div>
# <div class="score_summary__score_filter__status">
# <div class="score_summary__score_filter__count">(9)</div>
# <div class="score_summary__score_filter__check sprites-check"></div>
# </div>
# <div class="score_summary__score_filter__gauge">
# <div class="percentile" style="width: 3%"></div>
# </div>
# </a>
# </li>
# <li class="score_summary__score_filter " data-score="3">
# <a class="js-link-score">
# <div class="score_summary__score_filter__title">3 Stars</div>
# <div class="score_summary__score_filter__status">
# <div class="score_summary__score_filter__count">(28)</div>
# <div class="score_summary__score_filter__check sprites-check"></div>
# </div>
# <div class="score_summary__score_filter__gauge">
# <div class="percentile" style="width: 10%"></div>
# </div>
# </a>
# </li>
# <li class="score_summary__score_filter " data-score="2">
# <a class="js-link-score">
# <div class="score_summary__score_filter__title">2 Stars</div>
# <div class="score_summary__score_filter__status">
# <div class="score_summary__score_filter__count">(0)</div>
# <div class="score_summary__score_filter__check sprites-check"></div>
# </div>
# <div class="score_summary__score_filter__gauge">
# <div class="percentile" style="width: 0%"></div>
# </div>
# </a>
# </li>
# <li class="score_summary__score_filter " data-score="1">
# <a class="js-link-score">
# <div class="score_summary__score_filter__title">1 Star</div>
# <div class="score_summary__score_filter__status">
# <div class="score_summary__score_filter__count">(1)</div>
# <div class="score_summary__score_filter__check sprites-check"></div>
# </div>
# <div class="score_summary__score_filter__gauge">
# <div class="percentile" style="width: 0%"></div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# <div class="score_summary__footer">
# <span class="percentage">100%</span>
#     의 구매자들이 이 상품을 좋아합니다.
#
#
#     <span class="score_summary__likes_count">( 281명 중 280명 )</span>
# </div>
# </div>
# </div>
# <div class="products_reviews_summary__rcontent">
# <div class="products_reviews_summary_thumbnail_small_with_score">
# <div class="products_reviews_summary_thumbnail_small_with_score__items">
# <ul class="products_reviews_summary_thumbnail_small_with_score__item_row">
# <li class="products_reviews_summary_thumbnail_small_with_score__item">
# </li></ul></div></div></div></div></div></div></div></body></html>
# ####################################################################################################
# ####################################################################################################
# ####################################################################################################

# %%
driver = webdriver.Chrome('C:/asi/project/chromedriver_win32 (3)/chromedriver')
driver.get(url)

# %%
ur = 'https://perfumegraphy.com/product/list.html?cate_no=201/#review'
driver.get(ur)
#res = requests.get(ur, params=params)
time.sleep(3)
html2 = driver.page_source
src = bsp(html2,'html.parser')
ul_list = src.select('ul.reviews  li.review')
for ul in ul_list:
    review = ul.select('a.js-link-expand').text
    print(review)
    https://perfumegraphy.com/product/%EA%B5%AC%EC%B0%8C-%EB%B8%94%EB%A3%B8-%EC%98%A4-%EB%93%9C-%ED%8D%BC%ED%93%B8-3050100ml-%ED%85%8C%EC%8A%A4%ED%84%B0/1469/category/201/display/1/?
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-28-fccba19f7e66> in <module>
#       1 ur = 'https://perfumegraphy.com/product/list.html?cate_no=201/#review'
# ----> 2 driver.get(ur)
#       3 time.sleep(3)
#       4 html2 = driver.page_source
#       5 src = bsp(html2,'html.parser')
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=89.0.4389.114)

# %%
http://review4.cre.ma/perfumegraphy.com/products/reviews?product_code=1469&iframe_id=crema-product-reviews-&widget_id=32&widget_style=&app=0&parent_url=http%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2F&nonmember_token=&secure_device_token=V27fe46a9beacd9408382a8c33619aac056623c68ae3238745492068dceac51019&iframe=1

# %%
i = 1
while True:
    url='http://review4.cre.ma/perfumegraphy.com/products/reviews?app=0&iframe=1&iframe_id=crema-product-reviews-1&page={}&parent_url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&product_code=1469&secure_device_token=V281c8ef9fe71647c61b7e5908c3e2cd131479b904aa9876805c46f46e9cb0b841&widget_env=100&widget_id=32&widget_style='.format(i)   
    headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36'}
    res = requests.get(url,headers=headers)
    src = res.content.strip()
    htmls = bsp(src, 'html.parser')
    time.sleep(1)
    review_list=htmls.find_all(attrs={'class':'products_reviews_board_review__message'})
    #print(review_list)
    for review in review_list:
        review_ = review.select('div.products_reviews_board_review__message_expanded')[0].text.strip()
        review1 = re.sub('\([^)]*\)','',review_)
        if len(review.select('div.review_options > div.review_option')) == 3:
            if review.select('div.review_options > div.review_option > div.review_option__title')[0].text == '연령대':
                age = review.select('div.review_options > div.review_option > div.review_option__content')[0].text
                gender = review.select('div.review_options > div.review_option > div.review_option__content')[1].text
        elif len(review.select('div.review_options > div.review_option')) == 2:
            if review.select('div.review_options > div.review_option > div.review_option__title')[0].text == '연령대':
                age = review.select('div.review_options > div.review_option > div.review_option__content')[0].text
                if review.select('div.review_options > div.review_option > div.review_option__title')[1].text == '성별':
                    gender = review.select('div.review_options > div.review_option > div.review_option__content')[1].text
                else:
                    gender = ''
            elif review.select('div.review_options > div.review_option > div.review_option__title')[0].text == '성별':
                gender = review.select('div.review_options > div.review_option > div.review_option__content')[0].text
                age = ''    
        elif len(review.select('div.review_options > div.review_option')) == 1:
            if review.select('div.review_options > div.review_option > div.review_option__title')[0].text == '연령대':
                age = review.select('div.review_options > div.review_option > div.review_option__content')[0].text
                gender = ''
            elif review.select('div.review_options > div.review_option > div.review_option__title')[0].text == '성별':
                gender = review.select('div.review_options > div.review_option > div.review_option__content')[0].text
                age = ''
            else :
                age = ''
                gender = ''       
        else:
            age = ''
            gender = ''  
        print('구찌')
        print(age)
        print(gender)
        print(review1)
        time.sleep(1)
    if htmls.select('a.pagination__button'):
        print(i)
        i+=1
    else :
        break
# Out:
# 구찌
# 20대
# 여
# 선물용으로 너무 좋아요~
# 구찌
# 30대
# 여
# 배송이 너무 빠르고 맘에들어요 ㅋㅋ 향수가 엄정좋아 사은품도 냄새가 좋아요 굿굿
# 구찌
#
#
# 친언니 선물해줬어요. 넘버5 100미리사고싶었는데 품절이라. 이걸로샀어요. 향수는 100미리죠ㅋㅋ
# 구찌
#
#
# 리뷰보고선물했는데 너무너무좋데요~
# 구찌
#
#
# 조심스럽게 포장되있는게 얼만큼 신경써서 보냈는지 알겠더라구요 샘플향수도 넘 향이 좋아요  감사합니다
# 1
# 구찌
#
#
# 향이 아주 여성여성해요 너무 맘에 들어요 나에게 주는 선물 ㅎ
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-124-b21b9ad0637c> in <module>
#      43         print(gender)
#      44         print(review1)
# ---> 45         time.sleep(1)
#      46     if htmls.select('a.pagination__button'):
#      47         print(i)
#
# KeyboardInterrupt:

# %%
i = 1
while True:
    perurls = src.select('li.xans-record- > div')
    for perurl in perurls:
        urls = perurl.select('div.prdImg > a')[0]
        homepage = urls['href']
        print('https://perfumegraphy.com'+homepage)
        print('#'*100)
        for url in 
    url='http://review4.cre.ma/perfumegraphy.com/products/reviews?app=0&iframe=1&iframe_id=crema-product-reviews-1&page={}&parent_url=https%3A%2F%2Fperfumegraphy.com%2Fproduct%2F%25EA%25B5%25AC%25EC%25B0%258C-%25EB%25B8%2594%25EB%25A3%25B8-%25EC%2598%25A4-%25EB%2593%259C-%25ED%258D%25BC%25ED%2593%25B8-3050100ml-%25ED%2585%258C%25EC%258A%25A4%25ED%2584%25B0%2F1469%2Fcategory%2F201%2Fdisplay%2F1%2F&product_code=1469&secure_device_token=V281c8ef9fe71647c61b7e5908c3e2cd131479b904aa9876805c46f46e9cb0b841&widget_env=100&widget_id=32&widget_style='.format(i)   
    headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36'}
    res = requests.get(url,headers=headers)
    src = res.content.strip()
    htmls = bsp(src, 'html.parser')
    time.sleep(1)
    review_all = htmls.find_all(attrs={'class':'review products_reviews_board__tr'})
    #print(review_all)
    #print('-'*100)
    for review2 in review_all:
        scores = review2.select('span.star')
        #print(len(scores))
        review_ = review2.select('div.products_reviews_board_review__message_expanded')[0].text.strip()
        #print(review_)
        review1 = re.sub('\([^)]*\)','',review_)
        #print(review1)
        if len(review2.select('div.review_options > div.review_option')) == 3:
            #print(review2.select('div.review_options > div.review_option'))
            #print(review2.select('div.review_option__title'))
            if review2.select('div.review_options > div.review_option > div.review_option__title')[0].text == '연령대':
                age = review2.select('div.review_options > div.review_option > div.review_option__content')[0].text
                #print(age)
                gender = review2.select('div.review_options > div.review_option > div.review_option__content')[1].text
                #print(age,gender)
        elif len(review2.select('div.review_options > div.review_option')) == 2:
            if review2.select('div.review_options > div.review_option > div.review_option__title')[0].text == '연령대':  
                age = review2.select('div.review_options > div.review_option > div.review_option__content')[0].text
                #print(age)
                if review2.select('div.review_options > div.review_option > div.review_option__title')[1].text == '성별':
                    gender = review2.select('div.review_options > div.review_option > div.review_option__content')[1].text
                else:
                    gender = ''
            elif review2.select('div.review_options > div.review_option > div.review_option__title')[0].text == '성별':
                gender = review2.select('div.review_options > div.review_option > div.review_option__content')[1].text
                age = ''    
        elif len(review2.select('div.review_options > div.review_option')) == 1:
            if review2.select('div.review_options > div.review_option > div.review_option__title')[0].text == '연령대':
                age = review2.select('div.review_options > div.review_option > div.review_option__content')[0].text
                gender = ''
            elif review2.select('div.review_options > div.review_option > div.review_option__title')[0].text == '성별':
                gender = review2.select('div.review_options > div.review_option > div.review_option__content')[0].text
                age = ''
            else :
                age = ''
                gender = ''       
        else:
            age = ''
            gender = ''  
        print('구찌')
        print(age)
        print(gender)
        print(review1)
        print(len(scores))
        print('*'*50)
        time.sleep(1)
    if htmls.select('a.pagination__button'):
        print(i)
        i+=1
    else :
        break
# Out:
# 구찌
# 20대
# 여
# 선물용으로 너무 좋아요~
# 5
# **************************************************
# 구찌
# 30대
# 여
# 배송이 너무 빠르고 맘에들어요 ㅋㅋ 향수가 엄정좋아 사은품도 냄새가 좋아요 굿굿
# 5
# **************************************************
# 구찌
#
#
# 친언니 선물해줬어요. 넘버5 100미리사고싶었는데 품절이라. 이걸로샀어요. 향수는 100미리죠ㅋㅋ
# 5
# **************************************************
# 구찌
#
#
# 리뷰보고선물했는데 너무너무좋데요~
# 5
# **************************************************
# 구찌
#
#
# 조심스럽게 포장되있는게 얼만큼 신경써서 보냈는지 알겠더라구요 샘플향수도 넘 향이 좋아요  감사합니다
# 5
# **************************************************
# 1
# 구찌
#
#
# 향이 아주 여성여성해요 너무 맘에 들어요 나에게 주는 선물 ㅎ
# 5
# **************************************************
# 구찌
#
#
# 딸 생일선물로 구매했는데 너무 잘쓰고 있네요 감사합니다
# 5
# **************************************************
# 구찌
# 30대
# 여
# 며칠전 백화점을 지나다가다 어디서 좋은 향이나는데.어딘질 모르겠더라구요.킁킁거리며 계속 비슷한 자리를 와리가리했었어요.열심히 레이저로 탐지하며 찾아보니👀 구찌매장에서향긋한 향이 나더라구요!!진짜 너어무 좋아서 무작정 들어가서 만나게 된 블룸..♥️ 호불호 있어서 걱정했었는데 제가 화이트플라워 계열을좋아하는 편이라 착향해보곤 그렇게 거부감 있지는 않았어요..!탑의 장미향같은 예쁘고 싱그러운 향은 잠시..시간지날수록 남는 파우더? 향과 자스민의 꼬릿함때문에구메릉 포기하고 돌아섰었는데요...이틀뒤인가 남자친구가 옷에 벤 블룸 잔향이 너무좋다고해서 믿을수있는 퍼퓸그라피에서 구매했어용ㅋㅋㅋ저도 계속 맡다보니 익숙한 향인데 블룸의 탑이너무 좋아서 포기할수가 없네요♥️바틀도 너무이쁘구 30ml로도 오래 쓸 수있을것 같아요. 어린 분들보단 20대 후반부터가 어울리는것 같아요배송도 로켓배송수준으로 .. 하루만에 받았어요 ㅋㅋㅋㅋㅋ세상에.. 서비스로 주신 모하비와 프라다 시향종이도감사합니다. 겔랑 미니 샘플도 주셨어요^^혜자퍼퓸그라피...😘다음에도 향수구매할땐 여기서 구매할거에용!
# 5
# **************************************************
# 구찌
#
#
# 발향도좋고 구찌계열은 항상 믿고씀니당
# 5
# **************************************************
# 구찌
#
#
# 배송너무빠르고 친절해요 감사합니다
# 5
# **************************************************
# 2
# 구찌
# 30대
# 남
# 감사합니다 선물로 줬는데 너무 만족합니다
# 5
# **************************************************
# 구찌
#
#
# 향이 좋아요 잘 쓸게요
# 5
# **************************************************
# 구찌
#
#
# 배송도 빠르고 향도 좋아요. 50짜리가 없어서 큰걸 샀는데 기분전환용으로 틈틈이 뿌리고있어요.
# 5
# **************************************************
# 구찌
#
#
# 심플하고가지고다니기좋습니다
# 5
# **************************************************
# 구찌
#
#
# 오프매장에서 시향해보고 구매했어요~ 해외배송인데 빠르네요 ㅋ 향 너무 좋아요~
# 5
# **************************************************
# 3
# 구찌
#
#
# 향이 너누너무 좋아요!!
# 5
# **************************************************
# 구찌
#
#
# 향이 너무좋아서 계속 쓰고있어요~
# 5
# **************************************************
# 구찌
#
#
# 향기좋고 배송빠르고 굿입니다^**^
# 5
# **************************************************
# 구찌
#
#
# 늘 쓰던 향수라 또 샀어요 포장도 꼼꼼하고 배송이 하루만에 되어서 넘 좋았어용
# 5
# **************************************************
# 구찌
#
#
# 배송 빠르고 좋네요
# 5
# **************************************************
# 4
# 구찌
#
#
# 좋아요 선물했는데 만족이여
# 5
# **************************************************
# 구찌
#
#
# 선물포장도 고급스럽고 택배포장도 뾱뾱이로 2중으로 와서 안전하게 잘 받았습니다. 향은 약간.. 백화점 화장실에서 날 듯한 산뜻한 향?
# 5
# **************************************************
# 구찌
#
#
# 만족잘 쓰고 있습니다!!
# 5
# **************************************************
# 구찌
#
#
# 저는 잔향이 좋은것 같아요 자신감 뿜뿜이네요
# 5
# **************************************************
# 구찌
#
#
# 만족향 좋아서 선물했는데 만족합니다!!
# 5
# **************************************************
# 5
# 구찌
# 30대
# 여
# 오늘 배송 받았는데 뚜껑 열고 뿌리자마자 흔하지 않은 꽃향기가 나서 기분이 좋더라구요 지금부터 쓰면 딱 좋을 것 같은 향수에요
# 5
# **************************************************
# 구찌
# 20대
# 여
# 선물했는데.굉장히 마음에 들어하네요!!! 꽃향이 은은하게.좋아요
# 5
# **************************************************
# 구찌
# 20대
# 여
# 구찌블룸 은은하게 퍼지는 꽃향기가 너무 좋아서 꼭 구매하고 싶었는데 이렇게 좋은 기회로 구매하게 되서 너무 좋았어요. 그리고 구매한 향수 뿐만 아니라 샘플 향수까지 챙겨주셔서 너무 감사합니다. 또 구매하러 올게요😁
# 5
# **************************************************
# 구찌
# 20대
# 여
# 블라인드로 첫 구매한 향수에요!시향기만 보고선 선택한 아이라 나랑 잘 맞을까 걱정을 많이 했는데 왠걸 잘 맞더라구요 :) 누구나 그러겠지만 진향 향수를 오랫동안 맡으면 머리 아프고 향수가 금방 질리는데 이 아이는 시간이 흐를수록 잔향이 더 좋더라고요! 처음 뿌릴 때는 조금 진한 감이 없지 않아 있는데  시간 좀 흐르고 잔향이 너무 부드럽고 좋았어요 ㅎㅎ 표현을 어떻게 해야 모르겠지만, 활짝 핀 꽃들이 있는 나무들을 지나가는 느낌이에요! " 아 내가 인간 구찌 꽃이다." 라는 느낌을 받았어요ㅋㅋㅋㅋㅋㅋㅋ:) 어울린다면 남자들이 써도 괜찮은 향수 같아요! 꽃이지만 그렇다고 너무 페미닌한 느낌을 주지는 않았어요. 그래서 더 좋았습니다 !! 퍼퓸그라피에서 앞으로 자주 구매 할 것 같아요 배송도 빨랐고 무엇보다 가격적인 면에서도 장점이라 생각하고 가품 걱정 할 일은 없어서 믿고 구매해용 :D
# 5
# **************************************************
# 구찌
#
#
# 최고에요~ 잘 사용하고 있어요
# 5
# **************************************************
# 6
# 구찌
#
#
# 포장도 꼼꼼하고 깔끔하게 빨리 왔어요!
# 5
# **************************************************
# 구찌
#
#
# 너무 깔끔하게 와서 깜짝놀랐어요!! 선물 줄거라서 쇼핑백 구겨지면 어쩌나 싶었는데 너무 만족스러워요ㅎㅎ
# 5
# **************************************************
# 구찌
#
#
# 만족선물 받는 분이 좋아하셨어요~~!
# 5
# **************************************************
# 구찌
#
#
# 배송 정말 빠르게 왔고, 포장도 꼼꼼하게 잘 왔어요! 향수 용량 작은거 샀는데 쇼핑백이 너무 커서 별하나 깎았어요ㅎㅎㅎ 향수사이즈에 맞춰서 쇼핑백 있으면 더 좋을거 같아요! 개인적으로!ㅎㅎㅎ
# 5
# **************************************************
# 구찌
#
#
# 보통좋아야 좋아요 좋아여
# 5
# **************************************************
# 7
# 구찌
# 20대
# 남
# 선물로 샀는데 은은하고 좋다고 하네요
# 5
# **************************************************
# 구찌
#
#
# 만족친구 생일선물로 샀는데 배송 빠르고 좋아요!
# 5
# **************************************************
# 구찌
# 30대
# 여
# 생각했던향은 아니였지만처음보다는시간이 지나고 나서야 향이좋은것같아요
# 5
# **************************************************
# 구찌
#
#
# 만족너무감사합니다 수고하셨습니다
# 5
# **************************************************
# 구찌
#
#
# 너무 이뻐서 괜찮았고요 선물용으로 너무 좋습니다
# 5
# **************************************************
# 8
# 구찌
#
#
# 만족배송도 빨랐고 선물포장 뽁뽁이 다 만족합니다 다음에 또 구매하겠습니다
# 5
# **************************************************
# 구찌
#
#
# 냄새좋아용~~~~~~
# 5
# **************************************************
# 구찌
#
#
# 쇼핑백이 백화점에서 구매했을때랑 달라서 향수 제품은 다른건가 해서 주변 지인들 한테 물어봤는데 지인들도 샀을때 원래 구찌 쇼핑백을 받았다고 합니당근데 이번에 주문해서 받은 쇼핑백이 백화점꺼랑은 다른데 혹시 쇼핑백은 정품이 아닌가요?..선물용으로 급하게ㅜ산건데 쇼핑백이 가품일까봐 걱정되네요
# 5
# **************************************************
# 구찌
#
#
# 만족너무 좋아오오옹 다음엔 다른 향도 도전 해봐야겠네요
# 5
# **************************************************
# 구찌
#
#
# 빠른배송 너무 감사합니다
# 5
# **************************************************
# 9
# 구찌
# 20대
# 여
# 좋습니다!!오래가지 않지만 기다린만큼 굿굿
# 5
# **************************************************
# 구찌
#
#
# 보통제조기간이 오래되서 조금 신경쓰이네요 가격이 저럼한덴 이유가있었어요 ;;
# 5
# **************************************************
# 구찌
# 20대
# 여
# 여친 선물로 구매했습니다. 향수라는 것이 호불호가 갈리는 제품이다보니 살짝 걱정도 했는데, 다행히 선물 받은 사람이 만족하네요.
# 5
# **************************************************
# 구찌
#
#
# 만족진짜 너무너무 좋아요
# 5
# **************************************************
# 구찌
#
#
# 만족여자친구 선물해줬습니다. 포장지도 깔끔하고 센스있게 잘 왔고요 향도 은은한 꽃향기라 강한 향수냄새를 부담스러워하는 사람들에게도 좋을거같네요
# 5
# **************************************************
# 10
# 구찌
#
#
# 만족향이 너무좋아요 ᆢ재구매 필수입니나^^
# 5
# **************************************************
# 구찌
# 40대 이상
# 여
# 시향을 못하구 구매했는데..저의 개인적으로는 별로에요. 좋아하지 않는 향이랍니다. 좀 무거운듯해요~그래도 소장용으로 두려구요.
# 5
# **************************************************
# 구찌
#
#
# 만족정말감사합니다 수고하셨습니다
# 5
# **************************************************
# 구찌
#
#
# 만족너무 향~~~굿이애요^^
# 5
# **************************************************
# 구찌
#
#
# 만족잘받았습니다 조아요
# 5
# **************************************************
# 11
# 구찌
# 30대
# 여
# 작년쯤 처음 구찌블룸잔향에 뿅간이후로 떨어져갈때쯤남친에게서 생일 선물로받았는데배송도빠르구 포장도꼼꼼히해서오구 받은테스터들향도너무좋아요^^ 질리지않고너무만족합니다 감사합니다~~
# 5
# **************************************************
# 구찌
#
#
# 만족아들 성년의날 선물로 준비 했습니다.배송 빨랐고 향은 남녀 공용으로 쓸수 있을 정도로 무난하고 겨울보다는 지금부터 가을까지 좋을것 같아요.
# 5
# **************************************************
# 구찌
#
#
# 만족너무좋아요ㆍ앞으로향수는여기서~~^^
# 5
# **************************************************
# 구찌
#
#
# 만족아직 선물전이지만 포장도이쁘고 좋네요
# 5
# **************************************************
# 구찌
#
#
# 만족배솔 빠르고 좋아요!
# 5
# **************************************************
# 12
# 구찌
#
#
# 만족좋아요스 선물했는데 기뻐하네요 ㅎㅎ
# 5
# **************************************************
# 구찌
# 40대 이상
# 여
# 샤넬 No5 향수만 사용하다가 구매후기가 좋아 구찌 향수는 후기만 믿고 처음 구입했는데 향이 상큼하고 지금부터 사용하기에 어울리는 향수같아요. 아주 마음에 들어요. 너무 강한 향은 머리가 아파서 싫어하는데 너무 강하지도않고 자주 애용할 것 같아요. 배송도 빠르고 퍼퓸그라피 단골이 될 것같은 예감입니다. 시향샘플도 감사드려요. 여러가지 향을 맡아보는 재미도 쏠쏠합니다. 여러가지 향을 접하다보면 제가 좋아하는 향을 또 발견할 수 있겠죠?
# 5
# **************************************************
# 구찌
#
#
# 만족향 도손이랑 비슷하고 포장도 쇼핑백도 이뻐요
# 5
# **************************************************
# 구찌
#
#
# 만족선물용이에요 깔끔해요
# 5
# **************************************************
# 구찌
# 20대
# 남
# 여자친구가 아주 맘에 들어하네요! ㅎㅎ자주 애용하겠습니다!
# 5
# **************************************************
# 13
# 구찌
#
#
# 보통빠른 배송 감사합니다
# 5
# **************************************************
# 구찌
# 20대
# 여
# 시향 해보고 구매했는데 역시나 향이 너무 좋습니다 ^ ^ 지속력이 약해서 아쉽긴하지만 잔향이 매력적이라서 놓칠수 없어요 다음번에는 더 큰 사이즈로 구매해야겠어요
# 5
# **************************************************
# 구찌
#
#
# 만족예쁘게 선물했습니다ㅎ!
# 5
# **************************************************
# 구찌
#
#
# 생각했던 향은 아니지만 여름에 뿌리기 괜찮은것같아요~ 어버이날 선물로 드렸는데 좋아하셨어요 배송빠르고 샘플로 준 향수들도 잘쓰겠습니다
# 5
# **************************************************
# 구찌
# 30대
# 여
# 첫향이 너무 쎄서 놀랐고 잔향이 꽃향이라 또 놀랐어요~ 제가 순하고 부드러운 향수들을 선호 하다가 평이 너무 좋아서 도전하는 마음으로 구매했기 때문에 예상 밖에 강한 향에 거부감이 있었는데잔향에 사람들이 왜 좋아하는지는 알것 같아용!
# 5
# **************************************************
# 14
# 구찌
#
#
# 크 냄새가 상당히 향기롭습니다! 향이 제 기분을 업시켜주네요!! 첫 구찌향수인데 실패하지않았숩니다~
# 5
# **************************************************
# 구찌
#
#
# 만족선물로 딱이네용 향도 넘좋구 값어치합니다 역시~ 포장도 배송도 깔끔신속!!
# 5
# **************************************************
# 구찌
#
#
# 만족받는 사람이 너무 좋아했어요 친구생일 선물로 줬는데 향도 좋고 용기도 너무 이쁘다고 좋아하네요 선물용으로 정말 좋은 것 같아요
# 5
# **************************************************
# 구찌
# 30대
# 여
# 좋아요! 배송도 빠르고 향도 마음에 듭니다. 종이가방도 구김 없이 잘왔어요
# 5
# **************************************************
# 구찌
#
#
# 배송빠르고 향도 좋습니다
# 5
# **************************************************
# 15
# 구찌
# 40대 이상
# 여
# 향수설명과 후기에 기대어 처음 사용해봤습니다.케이스 자체도 워낙 심플해서 맘에 쏙 들었는데, 향도 너무 좋네요. 처음 뿌리고 나간 모임에서 뭘 뿌렸냐는 질문 많이 받았습니다. ㅎㅎ분사구가 잘 만들어진것같아요, 찍! 이아니고, 치이이익~~~~~ 입니다.포근하면서도 무게감있는 섹시함...짙은장미향이라고하기엔 복잡한 향기로움이 있는데...제 표현력이 딸리네요.암튼. 완전만족하고 있습니다.
# 5
# **************************************************
# 구찌
#
#
# 만족쇼핑백을 같이 구매했는데 안와서 따로 받았어요ㅜㅜ 선물할거라 늦게 올까봐 미리 주문한건데 다행이네여
# 5
# **************************************************
# 구찌
#
#
# 향기좋아요! 포장도 진짜 꼼꼼하고 예쁘게 해주셔서 기분좋았습니다
# 5
# **************************************************
# 구찌
#
#
# 만족포장상태가 너무나도 좋았어요. 선물용으로 최고인거같아요
# 5
# **************************************************
# 구찌
# 20대
# 여
# 꽃향기 너무너무 만족해여 ㅠㅠㅠㅠㅠ 봄에 너무나도 잘어울려영 !!!!
# 5
# **************************************************
# 16
# 구찌
#
#
# 보통좋아요 ㅎㅎ 튜베로즈향 ㅋㅋ 카날보다 덜 부담스럽네요
# 5
# **************************************************
# 구찌
# 20대
#
# 여자친구한테 선물했는데 좋아해요! 냄세도 좋아요😊
# 5
# **************************************************
# 구찌
#
#
# 향이아주좋아요 무난한게 좋네요 또구매할것같아요
# 5
# **************************************************
# 구찌
#
#
# 만족향이너무좋아요 잘쓸게여
# 5
# **************************************************
# 구찌
# 30대
# 여
# 평소 딥디크 도손향을 엄청 좋아하는데 후기를 보니 향이 비슷하다는 평이 있어서 궁금해서 사봤어요많이 비슷하긴한데 제느낌에는 도손보다 좀더 가볍다고 해야되나 여성스러운 느낌이에요 좋네요^^
# 5
# **************************************************
# 17
# 구찌
# 30대
# 남
# 블라인드로 샀는데 너무 만족했습니다포장도 예쁘고 첫 구매인데너무 만족했습니당!!
# 5
# **************************************************
# 구찌
#
#
# 향 최고에요 ... 배송도 빠르소 10점 만점에 100점❤
# 5
# **************************************************
# 구찌
# 20대
# 남
# 여자친구 화이트데이 선물로해줬는데요블라인드로 구매하게되었는데 생각보다 기대이상으로 향이너무좋아용!!!향은 딥디크에도손이랑 향이 많이 비슷한거같아요남자보다는 여성분들한테 잘어울리는 향인거같습니다
# 5
# **************************************************
# 구찌
#
#
# 만족친구 생일 선물로 준건데 진짜 좋은가봐요 ㅎ 5병쨐ㅋㅋ선물포장도 깔끔하고 맘에드네요 감사합니당
# 5
# **************************************************
# 구찌
#
#
# 만족4계절향수라고하니까 써보고재주문할게요
# 5
# **************************************************
# 18
# 구찌
#
#
# 깨지지않게 꼼꼼하게 보내주셨어요! 향수를 택배로 선물보낸게 처음이라 걱정했는데 너무 잘해주셨고 선물포...깨지지않게 꼼꼼하게 보내주셨어요! 향수를 택배로 선물보낸게 처음이라 걱정했는데 너무 잘해주셨고 선물포장도 했는데 너무 고급스럽게 이쁘게 다 해주셔가지고ㅠㅠ 너무 좋아하셔서 저도 기분이 좋았네요! 너무 감사해요~이제 향수는 여기서 구매해야겠네요!
# 5
# **************************************************
# 구찌
# 40대 이상
# 여
# 향수에 관심을 가지면서 하나씩 사고 있는데이 향수는 향이 좋은 로션 냄새 같아요많이 맡아 본 냄새네요봄에 가끔 사용하면 될것 같아요
# 5
# **************************************************
# 구찌
#
#
# 만족진짜 배송 너무 좋아요ㅎㅎ
# 5
# **************************************************
# 구찌
#
#
# 만족잘뿌리고 다닐게욥 ㅎㅎ
# 5
# **************************************************
# 구찌
#
#
# 보통향이 너무 좋아요~ 만족입니다!
# 5
# **************************************************
# 19
# 구찌
# 20대
# 남
# 여자친구 생일선물로 사줬는데 너무너무 좋아하고향도 너무 좋아요!
# 5
# **************************************************
# 구찌
#
#
# 만족배송도 빠르고 좋아요~~ ㅎㅎ
# 5
# **************************************************
# 구찌
#
#
# 보통배송도 빠르고 만족합니다!!
# 5
# **************************************************
# 구찌
#
#
# 만족포장도 깔끔하고 이뻐서 여자친구 선물인데 좋아할거 같아요 !!
# 5
# **************************************************
# 구찌
# 20대
# 여
# 진짜ㅜㅠㅡ향 넘 취저에요봄가을에 잘어울리는 항수네요ㅎㅎ지속력도 꽤 오래가서 뿌린지 4시간 지낫는데 그대로네요~
# 5
# **************************************************
# 20
# 구찌
#
#
# 만족좋아요 진짜 좋아하는 향이에요
# 5
# **************************************************
# 구찌
#
#
# 만족선물했는데 너무 좋아하더라구용ㅎㅎ
# 5
# **************************************************
# 구찌
# 20대
# 여
# 포장이 너무 이뻐서 선물하기 전부터 설레이네요^^사진 막 찍은건데.. 실물이 더 이뻐요빠르게보내주셔서 감사합니다. 선물 잘 하겠습니다.
# 5
# **************************************************
# 구찌
#
#
# 불만족사용안하고있음..왜냐고물으시면... 전에 도손 향수썼는데 요아이랑향이너무똑같아요.우리 딸아이도그러더군요.완전똑같다구ㅜㅜ
# 5
# **************************************************
# 구찌
#
#
# 보통선물이에요 ㅎㅎ 흐리어라라
# 5
# **************************************************
# 21
# 구찌
# 20대
# 남
# 여자친구한테 선물해줬더니 좋아하더라고요 ㅎㅎ 포장 이쁘게해주셔서 감사합니다
# 5
# **************************************************
# 구찌
#
#
# 만족포장도 마음에들고 향도 좋네요
# 5
# **************************************************
# 구찌
#
#
# 보통포장도 이쁘고 배송도 빨라서 좋아요~
# 5
# **************************************************
# 구찌
# 20대
# 여
# 주변에서 딥디크 도손이랑 비슷한 향취라고 하던데 개인적으로더 파우더리해서 좋아요!향이 무겁거나 쎄지않은데 오드퍼퓸이라 지속시간도 긴 편이에요독하지않은 플로럴향 좋아하시는 분들께 추천드려요!!
# 5
# **************************************************
# 구찌
#
#
# 만족은은해서 오래가고 좋아요
# 5
# **************************************************
# 22
# 구찌
#
#
# 만족시향했던대로 페미닌함이 가득한 향수입니다. 추가 샘플도 보내주시고, 100ML라서 푹푹 마음껏 뿌리고 다니면서 기분 전환하려고요!
# 5
# **************************************************
# 구찌
#
#
# 보통ㅡ.ㅡ 향이..첨 딱뿌렸는데 어?! 도손 향하고똑같아요..울딸아이도그러네요 완전똑같다구ㅜㅜ그래서별3개만줌요
# 5
# **************************************************
# 구찌
# 30대
# 남
# 배송이 너무 늦음..
# 5
# **************************************************
# 구찌
# 20대
# 남
# 여자친구 선물로 구매했는데 향이 아주 좋아요 ㅎㅎ
# 5
# **************************************************
# 구찌
#
#
# 만족향이 모던할수있다는걸 느낄정도로 무드있는향이에요
# 5
# **************************************************
# 23
# 구찌
#
#
# 만족여친이 좋아합니다 빠른배송 감사합니다. 테스터 귀엽네여
# 5
# **************************************************
# 구찌
#
#
# 만족선물용으로 샀는데 향기가 너무 좋아요
# 5
# **************************************************
# 구찌
#
#
# 만족생일선물로 구매했는데 너무 만족스러워요 깔끔하게 포장해서 보내주셔서 감사해요
# 5
# **************************************************
# 구찌
#
#
# 배송정말 빠르고 친절하세요!
# 5
# **************************************************
# 구찌
#
#
# 만족인터넷으로주문하기에금액이있어서조심스러웠는데...이향수향이...정~~말맘에쏙!!듭니다 은은하게잔향이계속..고급지게나요ㅋ 다쓰고나면담에또구매하겠습니다^^
# 5
# **************************************************
# 24
# 구찌
#
#
# 보통감사합니다아 조ㅛ아요
# 5
# **************************************************
# 구찌
#
#
# 만족친구선물로좋았어요^^
# 5
# **************************************************
# 구찌
# 30대
# 여
# 시누이 선물로 삿는데 고급지고 예뻐요 아주조금 아쉬운점은 쇼핑백 접히는 부분이 살짝 벌어져있어서 약해보여서 불안한느낌 ㅠㅠ 그래도 넘 포장도 이쁘고 서비스도 많이 주셨어요 다음에 또 구매의하러올게용♡
# 5
# **************************************************
# 구찌
# 40대 이상
# 여
# 프레쉬한 꽃향기를 좋아하는분께 강추!!
# 5
# **************************************************
# 구찌
#
#
# 보통댓글 달려있는 것처럼 향이조으네요
# 5
# **************************************************
# 25
# 구찌
# 20대
#
# 좋아요
# 5
# **************************************************
# 구찌
# 40대 이상
# 남
# 향이 참 좋네요
# 5
# **************************************************
# 구찌
#
#
# 만족아직까지 잘 뿌리고 잇답니다
# 5
# **************************************************
# 구찌
#
#
# 만족
# 5
# **************************************************
# 구찌
#
#
# 만족여기서 처음 구매해보는데 괜찮은것같아요!
# 5
# **************************************************
# 26
# 구찌
#
#
# 만족선물용구매 넘감사합니다
# 5
# **************************************************
# 구찌
#
#
# 만족칼배송에 포장도 마음에 들어요.
# 5
# **************************************************
# 구찌
# 30대
# 여
# 완전봄봄봄하고좋아요
# 5
# **************************************************
# 구찌
#
#
# 만족테스터후 구매한거라서 만족 인생향수찾았네요^^
# 5
# **************************************************
# 구찌
# 40대 이상
# 여
# 선물 받아서 다사용하고..요녀석의 잔향이 넘 좋아서 찾아서 구매햇어용ㅋ여자여자한 향ㅋ 블리블리한 향. 제가 뿌리고 움직일때마다 코끗에서 스치는 향ㅇㅣ 기분까지 조아용ㅋㅋ
# 5
# **************************************************
# 27
# 구찌
#
#
# 만족선물받은 사람이 만족했습니다
# 5
# **************************************************
# 구찌
# 20대
# 남
# 구찌 블룸이 오늘 도착하여 시향을 해봤습니다 구찌 블룸이라 블라인드로 구매를했습니다 구찌 블룸을 시향을 안해보고 바로 구매를 한 상태에서 옛날 패션브랜드의 향수의 냄새가 날꺼라 생각을 했었는데 의외였습니다 첫노트향이 딥디크 도손의 첫향과 매우 흡사했습니다 구찌 블룸하고 딥디크 도손의 향을 전혀 맡아보시지 않은 분들에게 물어봤을때 헷갈릴 수 있을 정도에요 딥디크 도손하고 구찌 블룸하고의 차이가 있는데 그것은 바로 딥디크 도손에는 구찌 블룸하고 비슷한 튜베로즈 계열인데 딥디크 도손에는 매운감인 핑크페퍼가 있고 구찌 블룸에 비해 조금강력하고 조금거친느낌이 있어요 그런데 구찌 블룸은 부드러워요 구찌 블룸과 딥디크 도손 2가지만 놓고 봤을때 구찌 블룸은 조금더 여성적인 느낌이 있고 딥디크 도손은 조금더 남성적인 느낌이 있는것 같아요 그래서 저는 개인적으로 딥디크 도손하고 구찌 블룸둘중에 사용하라고 하면 구찌 블룸에 손이 더 갈 것 같아요역시 퍼퓸 마스터 알베르토 모리야스의 작품은 인정합니다
# 5
# **************************************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-181-b2e421904a3f> in <module>
#      55         print(len(scores))
#      56         print('*'*50)
# ---> 57         time.sleep(1)
#      58     if htmls.select('a.pagination__button'):
#      59         print(i)
#
# KeyboardInterrupt:

# %%
def getData(d): # 데이터베이스에 데이터 집어넣기
    dbname='perfume.db'
    with sqlite3.connect(dbname) as conn:
        cursor=conn.cursor()
        sql='INSERT INTO perfumegra (pbrand_name,pname,page,pgender,pgrade,pcoment) VALUES(?,?,?,?,?,?,? )' 
        res=cursor.execute(sql,d)
        print('.',end='')
