# %%
import sqlite3
import sys
import numpy as np
np.set_printoptions(threshold=sys.maxsize)
import pandas as pd
pd.set_option('display.max_rows', 2000)
import requests
import re
from bs4 import BeautifulSoup as bsp
import matplotlib as mpl
import matplotlib.pyplot as plt
import sqlite3

# %%
con = sqlite3.connect('perfume_all2 (2).db')
cursor = con.cursor()
cursor.execute("SELECT brand,product FROM reviews")
print(cursor.fetchall())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
conn = sqlite3.connect("C:/asi/perfume_all2 (2).db")
db = conn.cursor()
db.execute("SELECT * FROM reviews ")
print(db.fetchall())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
f = open('perfume_all2 (2).db','r')

# %%
ddb = db.execute(f.read())

# %%
dbname='./perfume_all2 (2).db'
def getDB(sql='select brand,product from reviews'):
    with sqlite3.connect(dbname) as conn:
        cur=conn.cursor()
        qry=cur.execute(sql)
        data=qry.fetchall()
    return((data))

# %%
getDB()
# Out:
# [('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
#  ('캘빈클라인', '캘빈클라인 CK ONE EDT'),
# ...

# %%
dbname='./perfume_all2 (2).db'
def getDB():
    with sqlite3.connect(dbname) as conn:
        cur=conn.cursor()
        sql='select * from reviews'
        qry=cur.execute(sql)
        data=qry.fetchall()
    return(data)

# %%
alldata=getDB()

# %%
alldata=getDB()
pd.set_option('display.max_rows',630000)
dfo=pd.DataFrame(alldata,columns=['idx','brand','product','gender','type','note','review','rating'])
#dfo = dfo.groupby(by=["BrandE",'ProdK']).count()
dfo
# Out:
#            idx  brand           product gender type  \
# 0            1  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT
# 1            2  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT
# 2            3  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT
# 3            4  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT
# 4            5  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT
# ...        ...    ...               ...    ...  ...
# 635682  658767    프레쉬    프레쉬 브라운 슈가 EDP      여  EDP
# 635683  658768    프레쉬    프레쉬 브라운 슈가 EDP      여  EDP
# 635684  658769    프레쉬    프레쉬 브라운 슈가 EDP      여  EDP
# 635685  658770     겔랑     겔랑 옴므 이데알 EDT      남  EDT
# 635686  658771     겔랑     겔랑 옴므 이데알 EDT      남  EDT
#
#                                                      note  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 635682  톡 쏘는 시칠리안 레몬, 은은하게 퍼지는 매그놀리아, 그리고 마지막에 깔리는 웜 엠...
# 635683  톡 쏘는 시칠리안 레몬, 은은하게 퍼지는 매그놀리아, 그리고 마지막에 깔리는 웜 엠...
# 635684  톡 쏘는 시칠리안 레몬, 은은하게 퍼지는 매그놀리아, 그리고 마지막에 깔리는 웜 엠...
# ...

# %%
product_group = dfo.groupby(by=['product'], as_index=False)
product_group

# %%
print(product_group)

# %%
pg = dfo['product'].str.strip().unique()
print(pg)
# Out:
# ['캘빈클라인 CK ONE EDT' '존바바토스 아티산 EDT' '엘리자베스아덴 그린티 센트 EDT' '클린 웜 코튼 EDP'
#  '엘리자베스아덴 5번가 EDP' '그라펜 딜라이트 EDP' '캘빈클라인 CK BE EDT' '딥디크 도 손 EDP'
#  '파코라반 원 밀리언 EDT' '존바바토스 아티산 블루 EDT' '조마드 옴므 블루밍나잇 남성 EDP'
#  '레르드사봉 이노센트 타임 EDT' '몽블랑 레전드 EDT' '나인포인트 리미티드 P&B 페로몬 블랙 EDT'
#  '다비도프 쿨 워터 맨 EDT' '베르사체 에로스 맨 EDT' '불가리 뿌르 옴므 익스트림 EDT' '페라리 라이트 에센스 EDT'
#  '바이레도 블랑쉬 EDP' '존바바토스 아티산 퓨어 EDT' '그라펜 오베이션 EDP' '피오라 러브포이즌 포 우먼 EDP'
#  '엘리자베스 아덴 그린티 라벤더 EDT' '토스 베이비 토스 EDC' '조말론 잉글리쉬 페어 앤 프리지아 EDC'
#  '파코라반 원 밀리언 럭키 EDT' '클린 쿨 코튼 EDP' '몽블랑 익스플로러 EDP' '몽블랑 스타워커 EDT'
#  '코치 맨 플래티넘 EDP' '조말론 블랙베리 앤 베이 EDC' '버버리 브릿 쉬어 EDT' '불가리 블루 뿌르 옴므 EDT'
#  '페라리 스쿠데리아 페라리 블랙 EDT' '돌체앤가바나 라이트블루 뿌르 옴므 EDT' '베르사체 오 프레쉬 맨 EDT'
#  '베르사체 에로스 EDT' '더바디샵 화이트 머스크 로 EDT' '겐조 로 겐조 뿌르 옴므 EDT' '베르사체 뿌르 옴므 EDT'
#  '베르사체 맨 오 프레쉬 EDT' '샤넬 알뤼르 옴므 스포츠 EDT' '더샘 어반 브리즈 베리야드 EDP'
#  '모스키노 토이2 EDP' '몽블랑 엠블럼 EDT' '라포르테 뚜쉐 페로몬 EDP' '구찌 길티 블랙 뿌르 옴므 EDT'
#  '폴스미스 익스트림 포 맨 EDT' '바이레도 집시 워터 EDP' '데메테르 클린 솝 EDT'
# ...
