# %%
import pandas as pd

# %%
df1=pd.read_csv("./reviews.csv")

# %%
df1
# Out:
#            idx  brand           product gender type  \
# 0            1  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT
# 1            2  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT
# 2            3  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT
# 3            4  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT
# 4            5  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT
# ...        ...    ...               ...    ...  ...
# 629297  658767    프레쉬    프레쉬 브라운 슈가 EDP      여  EDP
# 629298  658768    프레쉬    프레쉬 브라운 슈가 EDP      여  EDP
# 629299  658769    프레쉬    프레쉬 브라운 슈가 EDP      여  EDP
# 629300  658770     겔랑     겔랑 옴므 이데알 EDT      남  EDT
# 629301  658771     겔랑     겔랑 옴므 이데알 EDT      남  EDT
#
#                                                      note  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# ...

# %%
df2=pd.read_csv("./dict.csv")

# %%
df2
# Out:
#      brand_kor                     product_kor  brand_eng  \
# 0         4711                 4711 누보 콜로뉴 EDC       4711
# 1         4711       4711 리믹스 콜로뉴 2018 에디션 EDC       4711
# 2         4711      4711 아쿠아 콜로니아 라임 앤 너트맥 EDC       4711
# 3         4711       4711 아쿠아 콜로니아 레몬 앤 진저 EDC       4711
# 4         4711  4711 아쿠아 콜로니아 블러드 오렌지 앤 바질 EDC       4711
# ...        ...                             ...        ...
# 2815      휴고보스            휴고보스 보스 오렌지 포 우먼 EDT  Hugo Boss
# 2816      휴고보스                    휴고보스 보틀드 EDT  Hugo Boss
# 2817      휴고보스                  휴고보스 에너자이즈 EDT  Hugo Boss
# 2818      휴고보스               휴고보스 퓨어 퍼플 우먼 EDP  Hugo Boss
# 2819      휴고보스                   휴고보스 휴고 맨 EDT  Hugo Boss
#
#                                             product_eng
# 0                  4711 Nouveau Cologne  by 4711 (2011)
# 1               4711 Remix Cologne 2018  by 4711 (2018)
# 2           Acqua Colonia Lime & Nutmeg  by 4711 (2015)
# ...

# %%
df2.columns
# Out:
# Index(['brand_kor', 'product_kor', 'brand_eng', 'product_eng'], dtype='object')

# %%
df2[df2['product_kor'] =='4711 누보 콜로뉴 EDC']
# Out:
#   brand_kor      product_kor brand_eng                           product_eng
# 0      4711  4711 누보 콜로뉴 EDC      4711  4711 Nouveau Cologne  by 4711 (2011)

# %%
df2.columns=['brand_kor', 'product', 'brand_eng', 'product_eng']

# %%
df2
# Out:
#      brand_kor                         product  brand_eng  \
# 0         4711                 4711 누보 콜로뉴 EDC       4711
# 1         4711       4711 리믹스 콜로뉴 2018 에디션 EDC       4711
# 2         4711      4711 아쿠아 콜로니아 라임 앤 너트맥 EDC       4711
# 3         4711       4711 아쿠아 콜로니아 레몬 앤 진저 EDC       4711
# 4         4711  4711 아쿠아 콜로니아 블러드 오렌지 앤 바질 EDC       4711
# ...        ...                             ...        ...
# 2815      휴고보스            휴고보스 보스 오렌지 포 우먼 EDT  Hugo Boss
# 2816      휴고보스                    휴고보스 보틀드 EDT  Hugo Boss
# 2817      휴고보스                  휴고보스 에너자이즈 EDT  Hugo Boss
# 2818      휴고보스               휴고보스 퓨어 퍼플 우먼 EDP  Hugo Boss
# 2819      휴고보스                   휴고보스 휴고 맨 EDT  Hugo Boss
#
#                                             product_eng
# 0                  4711 Nouveau Cologne  by 4711 (2011)
# 1               4711 Remix Cologne 2018  by 4711 (2018)
# 2           Acqua Colonia Lime & Nutmeg  by 4711 (2015)
# ...

# %%
df3=pd.merge(df1,df2,on='product',how='outer')

# %%
df3
# Out:
#         idx  brand                product gender type note  \
# 0       1.0  캘빈클라인       캘빈클라인 CK ONE EDT      남  EDT  NaN
# 1       2.0  캘빈클라인       캘빈클라인 CK ONE EDT      남  EDT  NaN
# 2       3.0  캘빈클라인       캘빈클라인 CK ONE EDT      남  EDT  NaN
# 3       4.0  캘빈클라인       캘빈클라인 CK ONE EDT      남  EDT  NaN
# 4       5.0  캘빈클라인       캘빈클라인 CK ONE EDT      남  EDT  NaN
# ...     ...    ...                    ...    ...  ...  ...
# 630049  NaN    NaN         헤라 익셉셔널 팜므 EDP    NaN  NaN  NaN
# 630050  NaN    NaN              헤라 지일 EDP    NaN  NaN  NaN
# 630051  NaN    NaN       헬로키티 콜미 프린세스 EDT    NaN  NaN  NaN
# 630052  NaN    NaN       홀리스터 웨이브 포 힘 EDT    NaN  NaN  NaN
# 630053  NaN    NaN  휴고보스 보스 보틀드 스포츠 맨 EDT    NaN  NaN  NaN
#
#                                                    review  rating brand_kor  \
# 0       향수계의 스테디셀러 ck oneck one 향수는 아직 향수에 입문하지 않은 향린이...     5.0     캘빈클라인
# 1       정품 맞는 듯 재구매 할래요반신반의했지만 로켓와우 배송제품이기에 쿠팡 자체물류센터에...     5.0     캘빈클라인
# ...

# %%
import re

# %%
df3.review
# Out:
# 0         향수계의 스테디셀러 ck oneck one 향수는 아직 향수에 입문하지 않은 향린이...
# 1         정품 맞는 듯 재구매 할래요반신반의했지만 로켓와우 배송제품이기에 쿠팡 자체물류센터에...
# 2         가성비최고 입문용 향수여전히 향은 똑같네요.아빠가 젊었을 적 향수 모으는게 취미였어...
# 3         향수입문자 분들께 강추 드립니다! 은은한 잔향이 매력은은한 향기로 예전에 대부분의 ...
# 4         산뜻하며 부담스럽지 않은 스테디셀러 향수!1. 로켓 배송 제품이라 믿고 구입했습니다...
#                                 ...
# 630049                                                  NaN
# 630050                                                  NaN
# 630051                                                  NaN
# 630052                                                  NaN
# 630053                                                  NaN
# Name: review, Length: 630054, dtype: object

# %%
df3_test=df3[0:10000]

# %%
df3_test.review
# Out:
# 0       향수계의 스테디셀러 ck oneck one 향수는 아직 향수에 입문하지 않은 향린이...
# 1       정품 맞는 듯 재구매 할래요반신반의했지만 로켓와우 배송제품이기에 쿠팡 자체물류센터에...
# 2       가성비최고 입문용 향수여전히 향은 똑같네요.아빠가 젊었을 적 향수 모으는게 취미였어...
# 3       향수입문자 분들께 강추 드립니다! 은은한 잔향이 매력은은한 향기로 예전에 대부분의 ...
# 4       산뜻하며 부담스럽지 않은 스테디셀러 향수!1. 로켓 배송 제품이라 믿고 구입했습니다...
#                               ...
# 9995                                     남녀 공용이라 맘에 듭니다..
# 9996                                        가격대비 매우 만족합니다
# 9997    향이 은근히 좋아요.시간이 지날수록 은근한 향이 나요가격도 다른 곳에 비해 조금 싸...
# 9998                                   조아요조아요조아요조아요조아요조아요
# 9999    은은하고 좋네요.. 남편이 좋아라해요..근데 향수뚜껑은 스프레이대를 꽂으면 안 닫히...
# Name: review, Length: 10000, dtype: object

# %%
def match1():
    compile_val = re.compile(r'남성|남편|남자')
    for i in df3_test.review:
        if compile_val.search(i):
            print(i)
        else:
            print('False')
match1()
# Out:
# False
# False
# 가성비최고 입문용 향수여전히 향은 똑같네요.아빠가 젊었을 적 향수 모으는게 취미였어요.옛날에 어렴풋이 본 향수입니다.추억이 돋아 구매하게 되었구요.아빠한테 가격을 이야기하니 떨이냐며 샀습니다ㅋㅋㅋ*제 나이가 벌써 29이고, 아빠는 59가 되었네요.지금 뿌려보니 옛날 생각도 나고,뿌리기 좋은 계절이 여름-봄-가을-겨울이지 싶습니다.아빠가 회사원이었던 시절,출근전 칙칙 뿌리고 나갈때 저는 어린이집간다고아빠손잡고 나가던 길에 맡던 향이에요.그 향을 아직도 기억하고 있냐고 하겠지만,어릴때부터 냄새에 민감했어요.현재는 외출 후 옷에 탈취제를 매일같이 뿌릴정도입니다.아빠는 흡연자라 냄새를 감추기 위한 용도였겠지만,저는 이 향수 자체에 남는 향이 참 좋았어요.지금은 남자 여자 관계없이 가볍게 뿌리기 좋다는 것도알게 되었고, 이 향수는 잔형이 좋다고들 하시네요.처음엔 좀 시원한 향이 강해서 남자향수가 아니냐는 고찰이 생기지만, 있다보면 중성적인 느낌이라 가볍게 뿌리기 좋다고 생각합니다.
# 향수입문자 분들께 강추 드립니다! 은은한 잔향이 매력은은한 향기로 예전에 대부분의 남자분들이 많이 쓰셨던 향수여서 약간 망설이긴 했지만 중성적인 향이기도 해서 도전했는데 여전히 좋으네요. 가격도 가격이지만 한때 국민 향수였던 만큼 이유있는 좋은향기예요. 어차피 향수는 같아도 뿌리는 사람에 따라 다른향이 나니, 처음 향수 쓰시는 분들께 무난하게 강추 해 봅니다.
# False
# 은은한 꽃 향기가 널리, 오래 퍼져요.후각이 예민한 울 조카가 어릴 때 이모부 냄새라며 유독 다른 이모부들보다 더 친하게 지내게 된 원인이 된 향수네요. 향이 보통 남자들 향수처럼 진하지 않고 뿌린 듯 안 뿌린 듯 은은한 향수예요.지금은 진한 향수 뿌리는데, 옛날을 기억한 제 여동생이 형부 생일 선물로 이걸 주문했네요.저도 오랜만에 맡으니, 그래 이 향이었지, 하는 생각과 추억이 새록새록.은은하게 널리 퍼지는 이 향수, 한 번 써 보세요 남자 여러분!
# False
# ...

# %%
df3_test['Name'] = df3_test['review'].str.extract('(\w*\s\w*)', expand=True)
# Out:
# <ipython-input-333-fc65beb1a9ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_test['Name'] = df3_test['review'].str.extract('(\w*\s\w*)', expand=True)

# %%
df3_test['Name']
# Out:
# 0       향수계의 스테디셀러
# 1            정품 맞는
# 2        가성비최고 입문용
# 3        향수입문자 분들께
# 4       산뜻하며 부담스럽지
#            ...
# 9995       남녀 공용이라
# 9996       가격대비 매우
# 9997        향이 은근히
# 9998           NaN
# 9999      은은하고 좋네요
# Name: Name, Length: 10000, dtype: object

# %%
df3_test
# Out:
#            idx  brand           product gender type note  \
# 0          1.0  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT  NaN
# 1          2.0  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT  NaN
# 2          3.0  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT  NaN
# 3          4.0  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT  NaN
# 4          5.0  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT  NaN
# ...        ...    ...               ...    ...  ...  ...
# 9995  255588.0  캘빈클라인  캘빈클라인 CK ONE EDT     공용  EDT    -
# 9996  255589.0  캘빈클라인  캘빈클라인 CK ONE EDT     공용  EDT    -
# 9997  255590.0  캘빈클라인  캘빈클라인 CK ONE EDT     공용  EDT    -
# 9998  255591.0  캘빈클라인  캘빈클라인 CK ONE EDT     공용  EDT    -
# 9999  255592.0  캘빈클라인  캘빈클라인 CK ONE EDT     공용  EDT    -
#
#                                                  review  rating brand_kor  \
# 0     향수계의 스테디셀러 ck oneck one 향수는 아직 향수에 입문하지 않은 향린이...     5.0     캘빈클라인
# 1     정품 맞는 듯 재구매 할래요반신반의했지만 로켓와우 배송제품이기에 쿠팡 자체물류센터에...     5.0     캘빈클라인
# ...

# %%
df3_test
# Out:
#            idx  brand           product gender type note  \
# 0          1.0  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT  NaN
# 1          2.0  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT  NaN
# 2          3.0  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT  NaN
# 3          4.0  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT  NaN
# 4          5.0  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT  NaN
# ...        ...    ...               ...    ...  ...  ...
# 9995  255588.0  캘빈클라인  캘빈클라인 CK ONE EDT     공용  EDT    -
# 9996  255589.0  캘빈클라인  캘빈클라인 CK ONE EDT     공용  EDT    -
# 9997  255590.0  캘빈클라인  캘빈클라인 CK ONE EDT     공용  EDT    -
# 9998  255591.0  캘빈클라인  캘빈클라인 CK ONE EDT     공용  EDT    -
# 9999  255592.0  캘빈클라인  캘빈클라인 CK ONE EDT     공용  EDT    -
#
#                                                  review  rating brand_kor  \
# 0     향수계의 스테디셀러 ck oneck one 향수는 아직 향수에 입문하지 않은 향린이...     5.0     캘빈클라인
# 1     정품 맞는 듯 재구매 할래요반신반의했지만 로켓와우 배송제품이기에 쿠팡 자체물류센터에...     5.0     캘빈클라인
# ...

# %%
df3_test['good_text'] =list(map(lambda x: x.count("남"), df3_test['review']))
# Out:
# <ipython-input-381-af021eab220d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_test['good_text'] =list(map(lambda x: x.count("남"), df3_test['review']))

# %%
df3_test['good_text']
# Out:
# 0       2
# 1       0
# 2       3
# 3       1
# 4       0
#        ..
# 9995    1
# 9996    0
# 9997    0
# 9998    0
# 9999    1
# Name: good_text, Length: 10000, dtype: int64

# %%
df3_test['Index_name'] = list(map(lambda x: x.find('향수'), df3_test['review']))
# Out:
# <ipython-input-383-940922819c34>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_test['Index_name'] = list(map(lambda x: x.find('향수'), df3_test['review']))

# %%
df3_test['Index_name']
# Out:
# 0         0
# 1       277
# 2        10
# 3         0
# 4        20
#        ...
# 9995     -1
# 9996     -1
# 9997     -1
# 9998     -1
# 9999     25
# Name: Index_name, Length: 10000, dtype: int64

# %%
df3_test['review'].str.split(" ", expand = True)
# Out:
#                      0      1        2          3           4       5    \
# 0                   향수계의  스테디셀러       ck      oneck         one     향수는
# 1                     정품     맞는        듯        재구매  할래요반신반의했지만    로켓와우
# 2                  가성비최고    입문용    향수여전히         향은    똑같네요.아빠가     젊었을
# 3                  향수입문자    분들께       강추      드립니다!         은은한     잔향이
# 4                   산뜻하며  부담스럽지       않은      스테디셀러       향수!1.      로켓
# ...                  ...    ...      ...        ...         ...     ...
# 9995                  남녀   공용이라       맘에      듭니다..        None    None
# 9996                가격대비     매우    만족합니다       None        None    None
# 9997                  향이    은근히  좋아요.시간이       지날수록         은근한      향이
# 9998  조아요조아요조아요조아요조아요조아요   None     None       None        None    None
# 9999                은은하고  좋네요..      남편이  좋아라해요..근데       향수뚜껑은  스프레이대를
#
#           6     7         8          9    ...   375   376   377   378   379  \
# ...

# %%
def find_at_word(text):
    word=re.findall(r'(?<=남)\w+',text)
    return " ".join(word)

df3_test['review_txt']=df3_test['review'].apply(lambda x: find_at_word(x))
# Out:
# <ipython-input-390-6ccd3977984a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_test['review_txt']=df3_test['review'].apply(lambda x: find_at_word(x))

# %%
df3_test['review_txt']
# Out:
# 0          녀노소 는
# 1
# 2       는 자 자향수가
# 3           자분들이
# 4
#           ...
# 9995           녀
# 9996
# 9997
# 9998
# 9999          편이
# Name: review_txt, Length: 10000, dtype: object

# %%
def test_and_cond(text):
    result = re.findall(r'(?=.*향.)(?=.*좋).*', text) 
    return " ".join(result)
df3_test['check_two_words']=df3_test['review'].apply(lambda x : test_and_cond(x))
# Out:
# <ipython-input-405-16b10387a910>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_test['check_two_words']=df3_test['review'].apply(lambda x : test_and_cond(x))

# %%
df3_test['check_two_words']
# Out:
# 0
# 1
# 2       가성비최고 입문용 향수여전히 향은 똑같네요.아빠가 젊었을 적 향수 모으는게 취미였어...
# 3       향수입문자 분들께 강추 드립니다! 은은한 잔향이 매력은은한 향기로 예전에 대부분의 ...
# 4
#                               ...
# 9995
# 9996
# 9997    향이 은근히 좋아요.시간이 지날수록 은근한 향이 나요가격도 다른 곳에 비해 조금 싸...
# 9998
# 9999    은은하고 좋네요.. 남편이 좋아라해요..근데 향수뚜껑은 스프레이대를 꽂으면 안 닫히...
# Name: check_two_words, Length: 10000, dtype: object

# %%
df3_test
# Out:
#            idx  brand           product gender type note  \
# 0          1.0  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT  NaN
# 1          2.0  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT  NaN
# 2          3.0  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT  NaN
# 3          4.0  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT  NaN
# 4          5.0  캘빈클라인  캘빈클라인 CK ONE EDT      남  EDT  NaN
# ...        ...    ...               ...    ...  ...  ...
# 9995  255588.0  캘빈클라인  캘빈클라인 CK ONE EDT     공용  EDT    -
# 9996  255589.0  캘빈클라인  캘빈클라인 CK ONE EDT     공용  EDT    -
# 9997  255590.0  캘빈클라인  캘빈클라인 CK ONE EDT     공용  EDT    -
# 9998  255591.0  캘빈클라인  캘빈클라인 CK ONE EDT     공용  EDT    -
# 9999  255592.0  캘빈클라인  캘빈클라인 CK ONE EDT     공용  EDT    -
#
#                                                  review  rating brand_kor  \
# 0     향수계의 스테디셀러 ck oneck one 향수는 아직 향수에 입문하지 않은 향린이...     5.0     캘빈클라인
# 1     정품 맞는 듯 재구매 할래요반신반의했지만 로켓와우 배송제품이기에 쿠팡 자체물류센터에...     5.0     캘빈클라인
# ...

# %%
def test_and_cond(text):
    result = re.findall(r'(?=.*향.)(?=.*좋).*', text) 
    return result
df3_test['check']=df3_test['review'].apply(lambda x : True if test_and_cond(x) else False)
# True if ( 조건문) else False
# Out:
# <ipython-input-425-62ea183580d2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_test['check']=df3_test['review'].apply(lambda x : True if test_and_cond(x) else False)

# %%
df3_test['check']
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997     True
# 9998    False
# 9999     True
# Name: check, Length: 10000, dtype: bool
