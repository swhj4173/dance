# %%
import pandas as pd
import warnings
import numpy as np

# %%
warnings.simplefilter('ignore')

# %%
df = pd.read_csv("./hotel_booking.csv")

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df_drop_row = df.dropna(axis=0)

# %%
df_drop_row
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2392    Resort Hotel            0          6               2015
# 2697    Resort Hotel            0         24               2015
# 2867    Resort Hotel            0         24               2015
# 2877    Resort Hotel            0         24               2015
# 2878    Resort Hotel            0         24               2015
# ...              ...          ...        ...                ...
# 112499    City Hotel            0         13               2017
# 113046    City Hotel            0         13               2017
# 113082    City Hotel            0         13               2017
# 113627    City Hotel            0        210               2017
# 116451    City Hotel            0        191               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2392              October                        42
# 2697              October                        44
# ...

# %%
df_stay_zero = df[df['stays_in_weekend_nights']==0].index # 1박미만인 사람은 예약한 것이 아니기 때문에 제거 필요

# %%
df.drop(df_stay_zero, inplace=True)

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 20      Resort Hotel            0         37               2015
# 21      Resort Hotel            0         72               2015
# 22      Resort Hotel            0         72               2015
# 23      Resort Hotel            0         72               2015
# 24      Resort Hotel            0        127               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 20                   July                        27
# 21                   July                        27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67392 entries, 20 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           67392 non-null  object
#  1   is_canceled                     67392 non-null  int64
#  2   lead_time                       67392 non-null  int64
#  3   arrival_date_year               67392 non-null  int64
#  4   arrival_date_month              67392 non-null  object
#  5   arrival_date_week_number        67392 non-null  int64
#  6   arrival_date_day_of_month       67392 non-null  int64
#  7   stays_in_weekend_nights         67392 non-null  int64
#  8   stays_in_week_nights            67392 non-null  int64
#  9   adults                          67392 non-null  int64
#  10  children                        67390 non-null  float64
#  11  babies                          67392 non-null  int64
# ...

# %%
df_adr = df[df['adr']==0].index #adr(하루평균 숙박비용) == 0이면 무료로 이용한것이기 때문에 이상치(제거 필요)

# %%
df_adr = df[df['adr']=='-6.38'].index  #adr -값 제거

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 20      Resort Hotel            0         37               2015
# 21      Resort Hotel            0         72               2015
# 22      Resort Hotel            0         72               2015
# 23      Resort Hotel            0         72               2015
# 24      Resort Hotel            0        127               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 20                   July                        27
# 21                   July                        27
# ...

# %%
df.drop(df_adr, inplace=True)

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 20      Resort Hotel            0         37               2015
# 21      Resort Hotel            0         72               2015
# 22      Resort Hotel            0         72               2015
# 23      Resort Hotel            0         72               2015
# 24      Resort Hotel            0        127               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 20                   July                        27
# 21                   July                        27
# ...

# %%
df_agent = df[df['agent']=='NaN'].index  #agent NAN값 제거

# %%
df.drop(df_agent, inplace=True)

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 20      Resort Hotel            0         37               2015
# 21      Resort Hotel            0         72               2015
# 22      Resort Hotel            0         72               2015
# 23      Resort Hotel            0         72               2015
# 24      Resort Hotel            0        127               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 20                   July                        27
# 21                   July                        27
# ...

# %%
from matplotlib import pyplot as plt

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'market_segment', 'distribution_channel', 'is_repeated_guest',
#        'previous_cancellations', 'previous_bookings_not_canceled',
#        'reserved_room_type', 'assigned_room_type', 'booking_changes',
#        'deposit_type', 'agent', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
lead_time_count = df['lead_time'].value_counts().sort_index()

# %%
lead_time_count
# Out:
# 0      1995
# 1       954
# 2       683
# 3       947
# 4       820
#        ...
# 532       1
# 542      22
# 605      30
# 626      30
# 709       1
# Name: lead_time, Length: 426, dtype: int64

# %%
babies_count = df['babies'].value_counts().sort_index()

# %%
babies_count
# Out:
# 0    66326
# 1      594
# 2       11
# 9        1
# Name: babies, dtype: int64

# %%
adr_count = df['adr'].value_counts().sort_index()

# %%
adr_count
# Out:
# -6.38       1
#  0.26       1
#  0.50       1
#  1.00      10
#  1.29       1
#            ..
#  402.00     1
#  426.25     1
#  437.00     1
#  450.00     1
#  451.50     1
# Name: adr, Length: 8048, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
xs = np.array(np.linspace(start=-10, stop=1000, num=1001))
df= pd.DataFrame(xs,columns=['lead_time'])

# %%
plt.figure(figsize=(7,6))
boxplot = df.boxplot(column=['lead_time'])

plt.show()

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.boxplot(dfa=df['lead_time'],color='r')
plt.show()
